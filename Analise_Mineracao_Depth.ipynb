# %% [markdown]
# ### Esta parte do código é para unir os diferentes bancos de dados da ANM
# ### O banco de dado da ANM segue a lógica de Modelo Entidade Relacionamento (https://app.anm.gov.br/dadosabertos/SCM/microdados/mer-microdados-scm.pdf)

# %%
#Importando Pacotes
import pandas as pd
import numpy as np
from collections import ChainMap

# %% [markdown]
# ### Para Base ProcessoTitulo

# %%
#Montando a base para ProcessoTitulo
processo_titulo=pd.read_csv('E:\\Mineracao\\ProcessoTitulo.txt', sep=';', encoding='latin1')
doc_legal = pd.read_csv('E:\\Mineracao\\DocumentoLegal.txt', sep=';', encoding='latin1')
tipo_doc_legal = pd.read_csv('E:\\Mineracao\TipoDocumentoLegal.txt', sep=';', encoding='latin1')
situ_doc_legal = pd.read_csv('E:\\Mineracao\SituacaoDocumentoLegal.txt', sep=';', encoding='latin1')

# %%
situ_doc_legal
# Out:
#     IDSituacaoDocumentoLegal      DSSituacaoDocumentoLegal
# 0                          1                     Outorgado
# 1                          2                      Renovado
# 2                          3                    Prorrogado
# 3                          4                    Retificado
# 4                          5                          Nulo
# 5                          6    Caduco/Sem efeito/Revogado
# 6                          7                     Cancelado
# 7                          8                       Cassado
# 8                          9                      Suspenso
# 9                         10           Suspensão encerrada
# 10                        11         Prorrogado - Covid 19
# 11                        99  Concedido (anterior à carga)

# %%
#Em processo titulo, montando para DocumentoLegal
dict_doclegal={}
for i in range(74):
    dict_doclegal[i]={doc_legal['IDDocumentoLegal'][i]:doc_legal['DSDocumentoLegal'][i]}
##############
for i in dict_doclegal:
   
    dict_doclegal[0].update(dict_doclegal[i])
dict_doclegal=dict_doclegal[0]

processo_titulo['Documento_Legal']=processo_titulo['IDDocumentoLegal'].map(dict_doclegal)

# %%
#Em processo_titulo, montando para tipo_doc_legal
dict_tipo_doc_legal={}
for i in range(12):
    dict_tipo_doc_legal[i]={tipo_doc_legal['IDTipoDocumentoLegal'][i]:tipo_doc_legal['DSTipoDocumentoLegal'][i]}
##############
for i in dict_tipo_doc_legal:
   
    dict_tipo_doc_legal[0].update(dict_tipo_doc_legal[i])
dict_tipo_doc_legal=dict_tipo_doc_legal[0]

processo_titulo['Tipo_Documento_Legal']=processo_titulo['IDTipoDocumentoLegal'].map(dict_tipo_doc_legal)

# %%
#em processo_titulo, montando para SituacaoDocumentoLegal
dict_situ_doc_legal={}
for i in range(12):
    dict_situ_doc_legal[i]={situ_doc_legal['IDSituacaoDocumentoLegal'][i]:situ_doc_legal['DSSituacaoDocumentoLegal'][i]}
##############
for i in dict_situ_doc_legal:
   
    dict_situ_doc_legal[0].update(dict_situ_doc_legal[i])
dict_situ_doc_legal=dict_situ_doc_legal[0]

processo_titulo['Situacao_Documento_Legal']=processo_titulo['IDSituacaoDocumentoLegal'].map(dict_situ_doc_legal)

# %%
processo_titulo.to_csv('Processo_Titulo.csv')

# %% [markdown]
# ### Para Base ProcessoPessoa

# %%
ProcessoPessoa=pd.read_csv('E:\\Mineracao\\ProcessoPessoa.txt', sep=';', encoding='latin1')
Pessoa = pd.read_csv('E:\\Mineracao\\Pessoa.txt', sep=';', encoding='latin1')
TipoRelacao = pd.read_csv('E:\\Mineracao\\TipoRelacao.txt', sep=';', encoding='latin1')
TipoResponsabilidadeTecnica = pd.read_csv('E:\\Mineracao\\TipoResponsabilidadeTecnica.txt', sep=';', encoding='latin1')
TipoRepresentacaoLegal = pd.read_csv('E:\\Mineracao\\TipoRepresentacaoLegal.txt', sep=';', encoding='latin1')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4184\1539751045.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   ProcessoPessoa=pd.read_csv('E:\\Mineracao\\ProcessoPessoa.txt', sep=';', encoding='latin1')

# %%
#Linkando pessoa:
dict_pessoa={}
for i in range(366019):
    dict_pessoa[i]={Pessoa['IDPessoa'][i]:Pessoa['TPPessoa'][i]}
##############
for i in dict_pessoa:
   
    dict_pessoa[0].update(dict_pessoa[i])
dict_pessoa=dict_pessoa[0]

ProcessoPessoa['Pessoa']=ProcessoPessoa['IDPessoa'].map(dict_pessoa)

# %%
#Linkando NOME PESSOA
dict_pessoa_nome={}
for i in range(366019):
    dict_pessoa_nome[i]={Pessoa['IDPessoa'][i]:Pessoa['NMPessoa'][i]}
##############
for i in dict_pessoa_nome:
   
    dict_pessoa_nome[0].update(dict_pessoa_nome[i])
dict_pessoa_nome=dict_pessoa_nome[0]

ProcessoPessoa['Pessoa_NOME']=ProcessoPessoa['IDPessoa'].map(dict_pessoa_nome)

# %%
#Linkando TipoRelacao
dict_TipoRelacao={}
for i in range(11):
    dict_TipoRelacao[i]={TipoRelacao['IDTipoRelacao'][i]:TipoRelacao['DSTipoRelacao'][i]}
##############
for i in dict_TipoRelacao:
   
    dict_TipoRelacao[0].update(dict_TipoRelacao[i])
dict_TipoRelacao=dict_TipoRelacao[0]

ProcessoPessoa['TipoRelacao']=ProcessoPessoa['IDTipoRelacao'].map(dict_TipoRelacao)

# %%
#Linkando TipoResponsabilidadeTecnica
dict_TipoResponsabilidadeTecnica={}
for i in range(6):
    dict_TipoResponsabilidadeTecnica[i]={TipoResponsabilidadeTecnica['IDTipoResponsabilidadeTecnica'][i]:TipoResponsabilidadeTecnica['DSTipoResponsabilidadeTecnica'][i]}
##############
for i in dict_TipoResponsabilidadeTecnica:
   
    dict_TipoResponsabilidadeTecnica[0].update(dict_TipoResponsabilidadeTecnica[i])
dict_TipoResponsabilidadeTecnica=dict_TipoResponsabilidadeTecnica[0]

ProcessoPessoa['Responsa_tecnica']=ProcessoPessoa['IDTipoResponsabilidadeTecnica'].map(dict_TipoResponsabilidadeTecnica)

# %%
#Linkando TipoRepresentacaoLegal:
dict_TipoRepresentacaoLegal={}
for i in range(4):
    dict_TipoRepresentacaoLegal[i]={TipoRepresentacaoLegal['IDTipoRepresentacaoLegal'][i]:TipoRepresentacaoLegal['DSTipoRepresentacaoLegal'][i]}
##############
for i in dict_TipoRepresentacaoLegal:
   
    dict_TipoRepresentacaoLegal[0].update(dict_TipoRepresentacaoLegal[i])
dict_TipoRepresentacaoLegal=dict_TipoRepresentacaoLegal[0]

ProcessoPessoa['Representacao_Legal']=ProcessoPessoa['IDTipoRepresentacaoLegal'].map(dict_TipoRepresentacaoLegal)

# %%
ProcessoPessoa.to_csv('ProcessoPessoa.csv')

# %% [markdown]
# ### Para ProcessoSubstancia

# %%
ProcessoSubstancia=pd.read_csv('E:\\Mineracao\\ProcessoSubstancia.txt', sep=';', encoding='latin1')
Substancia = pd.read_csv('E:\\Mineracao\\Substancia.txt', sep=';', encoding='latin1')
TipoUsoSubstancia = pd.read_csv('E:\\Mineracao\\TipoUsoSubstancia.txt', sep=';', encoding='latin1')
MotivoEncerramentoSubstancia = pd.read_csv('E:\\Mineracao\\MotivoEncerramentoSubstancia.txt', sep=';', encoding='latin1')

# %%
# Out:
#            DSProcesso  IDSubstancia  IDTipoUsoSubstancia  \
# 1500     860.696/1999        104900                    8
# 1673     860.699/2011        104900                   21
# 1675     860.699/2011        706100                    9
# 2327     860.712/2005        104900                   21
# 4090     860.745/2003        103500                   21
# ...               ...           ...                  ...
# 1070120  861.292/2016        701400                   21
# 1070939  890.253/2001        706100                   21
# 1073418  860.058/2019        200200                    1
# 1074377  860.026/2010        104900                   21
# 1075941  860.073/2009        104900                   21
#
#          IDMotivoEncerramentoSubstancia DTInicioVigencia DTFimVigencia  \
# 1500                                2.0       2000-02-22    2007-03-06
# 1673                                2.0       2011-04-11    2012-06-29
# 1675                                2.0       2011-08-18    2012-06-29
# 2327                                2.0       2005-04-20    2008-10-28
# 4090                                2.0       2003-08-01    2008-11-12
# ...                                 ...              ...           ...
# 1070120                             2.0       2016-10-27    2019-04-22
# 1070939                             2.0       2001-07-11    2010-03-22
# 1073418                             2.0       2019-01-10    2019-04-17
# 1074377                             2.0       2010-01-14    2013-07-24
# 1075941                             2.0       2009-01-22    2012-06-29
#
#                  Substancia Tipo_Uso_Substancia           Motivo_Encerramento
# 1500        MINÉRIO DE OURO          Metalurgia  Falta de interesse comercial
# 1673        MINÉRIO DE OURO          Industrial  Falta de interesse comercial
# 1675                GRANITO               Brita  Falta de interesse comercial
# 2327        MINÉRIO DE OURO          Industrial  Falta de interesse comercial
# 4090     MINÉRIO DE TITÂNIO          Industrial  Falta de interesse comercial
# ...                     ...                 ...                           ...
# 1070120              ARGILA          Industrial  Falta de interesse comercial
# 1070939             GRANITO          Industrial  Falta de interesse comercial
# 1073418               AREIA    Construção civil  Falta de interesse comercial
# 1074377     MINÉRIO DE OURO          Industrial  Falta de interesse comercial
# 1075941     MINÉRIO DE OURO          Industrial  Falta de interesse comercial
#
# [1387 rows x 9 columns]

# %%
#Linkando Substancia:
dict_Substancia={}
for i in range(862):
    dict_Substancia[i]={Substancia['IDSubstancia'][i]:Substancia['NMSubstancia'][i]}
##############
for i in dict_Substancia:
   
    dict_Substancia[0].update(dict_Substancia[i])
dict_Substancia=dict_Substancia[0]

ProcessoSubstancia['Substancia']=ProcessoSubstancia['IDSubstancia'].map(dict_Substancia)

# %%
#Linkando TipoUsoSubstancia:
dict_TipoUsoSubstancia={}
for i in range(26):
    dict_TipoUsoSubstancia[i]={TipoUsoSubstancia['IDTipoUsoSubstancia'][i]:TipoUsoSubstancia['DSTipoUsoSubstancia'][i]}
##############
for i in dict_TipoUsoSubstancia:   
    dict_TipoUsoSubstancia[0].update(dict_TipoUsoSubstancia[i])
    
dict_TipoUsoSubstancia=dict_TipoUsoSubstancia[0]

ProcessoSubstancia['Tipo_Uso_Substancia']=ProcessoSubstancia['IDTipoUsoSubstancia'].map(dict_TipoUsoSubstancia)

# %%
#Linkando MotivoEncerramentoSubstancia:
dict_MotivoEncerramentoSubstancia={}
for i in range(3):
    dict_MotivoEncerramentoSubstancia[i]={MotivoEncerramentoSubstancia['IDMotivoEncerramentoSubstancia'][i]:MotivoEncerramentoSubstancia['DSMotivoEncerramentoSubstancia'][i]}

for i in dict_MotivoEncerramentoSubstancia:   
    dict_MotivoEncerramentoSubstancia[0].update(dict_MotivoEncerramentoSubstancia[i])
    
dict_MotivoEncerramentoSubstancia=dict_MotivoEncerramentoSubstancia[0]

ProcessoSubstancia['Motivo_Encerramento']=ProcessoSubstancia['IDMotivoEncerramentoSubstancia'].map(dict_MotivoEncerramentoSubstancia)

# %%
ProcessoSubstancia.to_csv('ProcessoSubstancia.csv')

# %% [markdown]
# ### Para ProcessoPropriedadeSolo

# %%
ProcessoPropriedadeSolo=pd.read_csv('E:\\Mineracao\\ProcessoPropriedadeSolo.txt', sep=';', encoding='latin1')
CondicaoPropriedadeSolo = pd.read_csv('E:\\Mineracao\\CondicaoPropriedadeSolo.txt', sep=';', encoding='latin1')

# %%
ProcessoPropriedadeSolo
# Out:
#           DSProcesso  IDCondicaoPropriedadeSolo Condicao_propriedade_Solo
# 0       832.231/2003                          3  Propriedade de terceiros
# 1       832.231/2004                          3  Propriedade de terceiros
# 2       832.231/2005                          3  Propriedade de terceiros
# 3       832.231/2006                          3  Propriedade de terceiros
# 4       832.231/2007                          3  Propriedade de terceiros
# ...              ...                        ...                       ...
# 443871  890.249/2004                          3  Propriedade de terceiros
# 443872  890.249/2005                          3  Propriedade de terceiros
# 443873  890.249/2006                         50          Terreno da União
# 443874  890.249/2007                          5      Proprietário da área
# 443875  890.249/2008                          3  Propriedade de terceiros
#
# [443876 rows x 3 columns]

# %%
#Linkando CondicaoPropriedadeSolo:
dictCondicaoPropriedadeSolo={}
for i in range(8):
    dictCondicaoPropriedadeSolo[i]={CondicaoPropriedadeSolo['IDCondicaoPropriedadeSolo'][i]:CondicaoPropriedadeSolo['DSCondicaoPropriedadeSolo'][i]}

for i in dictCondicaoPropriedadeSolo:
   
    dictCondicaoPropriedadeSolo[0].update(dictCondicaoPropriedadeSolo[i])
dictCondicaoPropriedadeSolo=dictCondicaoPropriedadeSolo[0]

ProcessoPropriedadeSolo['Condicao_propriedade_Solo']=ProcessoPropriedadeSolo['IDCondicaoPropriedadeSolo'].map(dictCondicaoPropriedadeSolo)

# %%
ProcessoPropriedadeSolo.to_csv('ProcessoPropriedadeSolo.csv')

# %% [markdown]
# ### Para ProcessoAssociacao

# %%
ProcessoAssociacao=pd.read_csv('E:\\Mineracao\\ProcessoAssociacao.txt', sep=';', encoding='latin1')
TipoAssociacao = pd.read_csv('E:\\Mineracao\\TipoAssociacao.txt', sep=';', encoding='latin1')

# %%
ProcessoAssociacao
# Out:
#          DSProcesso DSProcessoAssociado  IDTipoAssociacao DTAssociacao  \
# 0      000.022/1994        000.448/1952                 4   2000-04-05
# 1      000.022/1994        001.316/1946                 4   2000-04-05
# 2      000.038/2017        003.264/1953                 1   2017-08-28
# 3      000.070/1961        840.297/2015                 8   2015-11-20
# 4      000.071/1961        840.021/2016                 8   2016-02-01
# ...             ...                 ...               ...          ...
# 58116  896.379/2005        302.249/2015                 8   2015-04-24
# 58117  896.379/2005        896.014/2013                 2   2013-01-16
# 58118  896.380/2003        302.979/2015                 8   2015-11-25
# 58119  896.380/2008        896.114/2010                 2   2010-04-26
# 58120  896.380/2010        896.794/2008                 9   2010-11-19
#
#       DTDesassociacao OBAssociacao     Tipo_Associacao
# 0                 NaN            *  Grupamento Mineiro
# 1                 NaN            *  Grupamento Mineiro
# 2                 NaN            *            Original
# 3                 NaN            *     Disponibilidade
# 4                 NaN            *     Disponibilidade
# ...               ...          ...                 ...
# 58116             NaN            *     Disponibilidade
# 58117             NaN            *      Cessão Parcial
# 58118             NaN            *     Disponibilidade
# 58119             NaN            *      Cessão Parcial
# 58120             NaN            *   Mudança de Regime
#
# [58121 rows x 7 columns]

# %%
#Linkando TipoAssociacao:
dicTipoAssociacao={}
for i in range(len(TipoAssociacao)):
    dicTipoAssociacao[i]={TipoAssociacao['IDTipoAssociacao'][i]:TipoAssociacao['DSTipoAssociacao'][i]}

for i in dicTipoAssociacao:
   
    dicTipoAssociacao[0].update(dicTipoAssociacao[i])
dicTipoAssociacao=dicTipoAssociacao[0]

ProcessoAssociacao['Tipo_Associacao']=ProcessoAssociacao['IDTipoAssociacao'].map(dicTipoAssociacao)

# %%
ProcessoAssociacao.to_csv('ProcessoAssociacao.csv')

# %% [markdown]
# ### Para ProcessoDocumentacao

# %%
ProcessoDocumentacao=pd.read_csv('E:\\Mineracao\\ProcessoDocumentacao.txt', sep=';', encoding='latin1')
TipoDocumento = pd.read_csv('E:\\Mineracao\\TipoDocumento.txt', sep=';', encoding='latin1')

# %%
ProcessoDocumentacao
# Out:
#            DSProcesso  IDTipoDocumento DTProtocolo  \
# 0        815.877/2015               37  2015-11-12
# 1        815.877/2015               38  2015-11-12
# 2        815.877/2015               39  2015-11-12
# 3        815.877/2016                1  2016-12-12
# 4        815.877/2016                2  2016-12-12
# ...               ...              ...         ...
# 3433593  996.932/2009               17  2009-11-06
# 3433594  996.932/2009               18  2009-11-06
# 3433595  996.932/2009               38  2009-11-06
# 3433596  996.932/2009               39  2009-11-06
# 3433597  996.932/2009               51  2009-11-06
#
#                                             Tipo_Documento
# 0                              A.R.T. do plano de pesquisa
# 1                            A.R.T. do memorial descritivo
# 2                    A.R.T. da planta de situação/detalhe
# 3                                      Memorial descritivo
# 4                               Planta de situação da área
# ...                                                    ...
# 3433593                        Licença do órgão  ambiental
# 3433594            Memorial explicativo grupamento mineiro
# 3433595                      A.R.T. do memorial descritivo
# 3433596              A.R.T. da planta de situação/detalhe
# 3433597  Plano Integrado de Aproveitamento Economico da...
#
# [3433598 rows x 4 columns]

# %%
#Linkando TipoDocumento:
dicTipoDocumento={}
for i in range(len(TipoDocumento)):
    dicTipoDocumento[i]={TipoDocumento['IDTipoDocumento'][i]:TipoDocumento['DSTipoDocumento'][i]}

for i in dicTipoDocumento:
   
    dicTipoDocumento[0].update(dicTipoDocumento[i])
dicTipoDocumento=dicTipoDocumento[0]

ProcessoDocumentacao['Tipo_Documento']=ProcessoDocumentacao['IDTipoDocumento'].map(dicTipoDocumento)

# %%
ProcessoDocumentacao.to_csv('ProcessoDocumentacao.csv')

# %% [markdown]
# ### Para ProcessoEvento

# %%
ProcessoEvento=pd.read_csv('E:\\Mineracao\\ProcessoEvento.txt', sep=';', encoding='latin1')
Evento = pd.read_csv('E:\\Mineracao\\Evento.txt', sep=';', encoding='latin1')

# %%
Evento
# Out:
#       IDEvento                                           DSEvento
# 0            1          PROCESSO LOCALIZADO EM FAIXA DE FRONTEIRA
# 1            2                    DOCUMENTO DIVERSO PROTOCOLIZADO
# 2            3                                EXIGÊNCIA PUBLICADA
# 3            4                CUMPRIMENTO EXIGÊNCIA PROTOCOLIZADA
# 4            5                    DÉBITO INSCRITO NA DÍVIDA ATIVA
# 5            6              RECONSTITUIÇÃO DE PROCESSO AUTORIZADA
# 6            7                        PROCESSO COM PRAZO SUSPENSO
# 7           10             RECONH GEOL/REQUERIMENTO PROTOCOLIZADO
# 8           15           RECONH GEOL/INDEFERIMENTO DE PLANO PUBLI
# 9           16           RECONH GEOL/INDEFERIMENTO AREA LIVRE PUB
# 10          20                      RECONH GEOL/ASSENTIMENTO EMFA
# 11          21                         AUTO DE INFRAÇÃO MULTA-RAL
# 12          22                   TORNA S/EFEITO AUTO INFRAÇÃO-RAL
# 13          23                     ARQUIVAMENTO AUTO INFRAÇÃO-RAL
# 14          24                                 MULTA APLICADA-RAL
# 15          25                    PAGAMENTO DA MULTA EFETUADO-RAL
# 16          26                  TORNA S/EFEITO MULTA APLICADA-RAL
# 17          27       EXIGÊNCIA PARA APRESENTAÇÃO DE RAL PUBLICADA
# 18          30                    RECONH GEOL/PERMISSAO PUBLICADA
# 19          50             RECONH GEOL/RELATORIO RG PROTOCOLIZADO
# 20          99        DISPONIB/ÁREA S/PRETEN PROC  ARQ ÁREA LIVRE
# 21         100       REQ PESQ/REQUERIMENTO PESQUISA PROTOCOLIZADO
# 22         101   REQ PESQ/INDEFERIMENTO DE PLANO CAPUT ART 17 PUB
# 23         102           REQ PESQ/INDEFERIMENTO "DE PLANO" PUBLIC
# 24         103     AUT PESQ/TRANSF DIREITOS -CESSÃO TOTAL ANULADA
# 25         104           REQ PESQ/REQ PESQUISA INCOMPLETO PROTOCO
# 26         105           REQ PESQ/COMPLEMENTACAO REQ PESQ PROTOCO
# 27         106             AUT PESQ/TORNA S/EFEITO MULTA APLICADA
# 28         107           REQ PESQ/ACORDO C/SUPERFICIARIO PROTOCOL
# 29         108            REQ PESQ/PEDIDO INCORPORCAO/CESSÃO PROT
# 30         109           AUT PESQ/TORNA S/EFEITO AUTO INFRAÇÃO PU
# 31         110               REQ PESQ/ASSENTIMENTO CDN SOLICITADO
# 32         111                REQ PESQ/CONSULTA FUNAI ENCAMINHADA
# 33         112            REQ PESQ/CONSULTA M MARINHA ENCAMINHADA
# 34         113           REQ PESQ/CONSULTA ORGÃOS DIVERS ENCAMINH
# 35         114  AUT PESQ/HOMOLOGA DESISTENCIA PRORROGAÇÃO  PRA...
# 36         115           REQ PESQ/DENÚNCIA C/REQUERENTE PROTOCOLI
# 37         116           REQ PESQ/DENÚNCIA C/REQUERENTE IMPROCEDE
# 38         117           REQ PESQ/DENÚNCIA C/REQUERENTE PROCEDENT
# 39         118          REQ PESQ/AVERB INCORPOR/CESSÃO APROV PUBL
# 40         119           REQ PESQ/AVERB INCORPOR/CESSÃO EFETIVADA
# 41         120   REQ PESQ/INDEFERIMENTO INTERFER AREA GARIMPO PUB
# 42         121      REQ PESQ/INDEFERIMENTO ART 18 PAR 1 PUBLICADO
# 43         122  REQ PESQ/INDEFERIMENTO P/ NAO CUMPRIMENTO EXIG...
# 44         123          REQ PESQ/INDEF ART 23 E 18 II B PUBLICADO
# 45         124              REQ PESQ/INDEF ART 20 PAR 3 PUBLICADO
# 46         125        REQ PESQ/INDEFERIMENTO ART 21 PAR 3 RCM PUB
# 47         126   REQ PESQ/INDEFERIMENTO ART 20 PAR 5 RCM -MAX PUB
# 48         127   REQ PESQ/INDEFERIMENTO ART 20 PAR 5 RCM -MIN PUB
# 49         128            REQ PESQ/INDEF ART 20 VII RCM PUBLICADO
# 50         129           REQ PESQ/INDEF ART 26 E 18 IIB PUBLICADO
# 51         130        REQ PESQ/REQUERIMENTO RETIFICAÇÃO ÁREA PROT
# 52         131                       REQ PESQ/EXIGÊNCIA PUBLICADA
# 53         132    REQ PESQ/PRORROGAÇÃO PRAZO EXIGÊNCIA SOLICITADO
# 54         133     REQ PESQ/PRORROGAÇÃO PRAZO EXIGÊNCIA CONCEDIDO
# 55         134        REQ PESQ/PRORROGAÇÃO PRAZO EXIGÊNCIA NEGADA
# 56         135           REQ PESQ/CUMPRIMENTO EXIGÊNCIA PROTOCOLI
# 57         136           REQ PESQ/DOCUMENTO DIVERSO PROTOCOLIZADO
# 58         137           REQ PESQ/TORNA S/EFEITO EXIGÊNCIA PUBLIC
# 59         138           REQ PESQ/CONVITE PAGAM TAXA ALVARÁ PUBLI
# 60         139     REQ PESQ/TORNA S/EFEITO DESPACHO INDEFERIMENTO
# 61         140           REQ PESQ/COMPROV PAGAM TAXA ALVARÁ PROTO
# 62         141             REQ PESQ/ASSENTIMENTO FUNAI AUTORIZADO
# 63         142           REQ PESQ/ASSENTIMENTO M MARINHA AUTORIZA
# 64         143               REQ PESQ/ASSENTIMENTO CDN AUTORIZADO
# 65         144           REQ PESQ/ASSENTI ORGÃOS DIVERSOS AUTORIZ
# 66         145           REQ PESQ/ASSENTIMENTO FUNAI NÃO AUTORIZA
# 67         146           REQ PESQ/ASSENTIM M MARINHA NÃO AUTORIZD
# 68         147           REQ PESQ/ASSENTIMENTO CDN NÃO AUTORIZADO
# 69         148           REQ PESQ/ASSENT ORGAOS DIVERS NÃO AUTORI
# 70         149           REQ PESQ/NEGA ANUÊNCIA CESSAO TOT DIR PU
# 71         150        REQ PESQ/DESISTENCIA REQ PESQ PROTOCOLIZADA
# 72         151           REQ PESQ/PEDIDO DE DESCONSID DESIST PROT
# 73         152          REQ PESQ/NEGA ANUÊNCIA CESSAO PARC DIR PU
# 74         153          REQ PESQ/TORNA SEM EFEITO ANUÊNCIA CESSÃO
# 75         154            TORNA S/EFEITO NOTIF ADM I PGTO DÉB TAH
# 76         155           REQ PESQ/ARQUIVAMENTO PROCESSO PUBLICADO
# 77         156                REQ PESQ/DESPACHO DIVERSO PUBLICADO
# 78         157       REQ PESQ/DESISTÊNCIA REQ PESQ HOMOLOGADA PUB
# 79         158                   REQ PESQ/ÁREA LIVRE A PARTIR DE:
# 80         159      REQ PESQ/ÁREA LIVRE 30 DIAS APÓS A PUBLICAÇÃO
# 81         160                 REQ PESQ/ÁREA NÃO ONERAD PUBLICADO
# 82         161           REQ PESQ/TORNA S/EFEITO HOMOL DESIST PUB
# 83         162  REQ PESQ/OPÇÃO REGIME LICENCIAMENTO PROTOCOLIZADO
# 84         163  REQ PESQ/TORNA S/EFEITO DESPACHO ARQUIVAMENTO ...
# 85         164            REQ PESQ/PED RECON IND PROR EXIG NEGADO
# 86         165         REQ PESQ/OPÇÃO REGIME LICENCIAMENTO NEGADO
# 87         166        REQ PESQ/INDEFERIMENTO ART 20 PAR 6 RCM PUB
# 88         167          REQ LAV/CESSÃO-INCORP REQUERIMENTO LAV PU
# 89         168  REQ PESQ/INDEFERIMENTO INCISO 7º  PORT 50/1998...
# 90         169              AUT PESQ/ÁREA BLOQUEADA ART 42 CM PUB
# 91         170    REQ PESQ/INDEFERIMENTO MOTIVO DIVERSO PUBLICADO
# 92         171           REQ PESQ/ÁREA BLOQUEADA ART 42 CM PUBLIC
# 93         172              REQ PESQ/ÁREA BLOQUEADA-INUNDACAO PUB
# 94         173  REQ PESQ/INDEFERIMENTO ÁREA EM PARQUE NAC EST MUN
# 95         174           REQ PESQ/IND ART 1 LEI 6567/78 PUBLICADO
# 96         175  AUT PESQ/TRANSF DIREITOS -CESSÃO PARCIAL APROVADA
# 97         176          AUT PESQ/ALVARÁ DE PESQUISA DE CESSÃO PUB
# 98         177           AUT PESQ/TORNA S/EFEITO DESP ARQ REL PUB
# 99         178         AUT PESQ/NOTIFICAÇÃO ADM L PGTO DÉBITO TAH
# 100        179                   NOTIFICAÇÃO DÉBITO  CFEM (NFLDP)
# 101        180       REQ PESQ/PEDIDO RECONSIDERAÇÃO PROTOCOLIZADO
# 102        181              REQ PESQ/PEDIDO RECONSIDERAÇÃO NEGADA
# 103        182             REQ PESQ/PEDIDO RECONSIDERAÇÃO PROVIDA
# 104        183  REQ PESQ/TORNA S/EFEITO RECONSIDERAÇÃO INDEFER...
# 105        184  REQ PESQ/TORNA S/EFEITO DESPACHO NEGA RECONSID...
# 106        185         REQ PESQ/RECURSO AO MINISTRO PROTOCOLIZADO
# 107        186        AUT PESQ/OPÇÃO REGIME LICENC INDEFERIDO PUB
# 108        187                  REQ PESQ/RECURSO NEGADO PUBLICADO
# 109        188                 REQ PESQ/RECURSO PROVIDO PUBLICADO
# 110        189         REQ LAV/TORNA S/EFEITO DESP CAD DIR REQ LA
# 111        190           AUT PESQ/TORNA S/EFEITO PROC ADM CAD/NUL
# 112        191         AUT PESQ/TORNA S/EFEITO DESP NÃO APROV REL
# 113        192        AUT PESQ/TORNA S/EFEITO DESPACHO  PUBLICADO
# 114        193      AUT PESQ/TRANSF DIREITOS -CESSÃO TOTAL NEGADA
# 115        194    AUT PESQ/TRANSF DIREITOS -CESSÃO PARCIAL NEGADA
# 116        195          AUT PESQ/TORNA S/EFEITO DESP PRORR ALV PU
# 117        196         AUT PESQ/TORNA S/EFEITO DESP APROV REL PUB
# 118        197    AUT PESQ/INDEFERIMENTO PRORROGAÇÃO PRAZO ALVARA
# 119        198           AUT PESQ/OPÇÃO REGIME LICENCIAMENTO PROT
# 120        199              AUT PESQ/TORNA S/EFEITO EXIGÊNCIA PUB
# 121        200               AUT PESQ/REDUÇÃO DE AREA ART 26 PUBL
# 122        201              AUT PESQ/ALVARÁ DE PESQUISA PUBLICADO
# 123        202             AUT PESQ/OFICIO C/ COPIA AUTO INFRAÇÃO
# 124        203           AUT PESQ/AREA LIVRE 30 DIAS APÓS PUBLICA
# 125        204           AUT PESQ/ACORDO C/SUPERFICIARIO PROTOCOL
# 126        205           AUT PESQ/OFICIO C/ COPIA IMPOS ADV/MULTA
# 127        206           AUT PESQ/EMOLUMENTOS P/RENOV ALVARA PAGO
# 128        207                    AUT PESQ/OFICIO AO JUIZ ENVIADO
# 129        208                 AUT PESQ/INGRESSO JUDICIAL NA ÁREA
# 130        209             AUT PESQ/INICIO DE PESQUISA COMUNICADO
# 131        210          AUT PESQ/PLANO UNICO PESQUISA APRESENTADO
# 132        211       AUT PESQ/PLANO UNICO PESQUISA APROVADO PUBLI
# 133        212    AUT PESQ/PLANO UNICO PESQUISA NÃO APROVADO PUBL
# 134        213            AUT PESQ/SUSPENSAO TRAB PESQ SOLICITADO
# 135        214         AUT PESQ/COMUNICACAO OCORR OUTRA SUBSTANCI
# 136        215  AUT PESQ/VISTORIA REALIZADA -REEMBOLSO PROTOCO...
# 137        216           AUT PESQ/VERIFICACAO IN LOCO PESQ NORMAL
# 138        217     AUT PESQ/VERIFICAÇÃO IN LOCO PESQ NÃO INICIADA
# 139        218        AUT PESQ/VERIFICAÇÃO IN LOCO PESQ IRREGULAR
# 140        219           AUT PESQ/SUSPENSAO TRAB PESQ AUTORIZ PUB
# 141        220           AUT PESQ/INTERDICAO TRABALHO PESQ PUBLIC
# 142        221           AUT PESQ/AUTO INFRAÇÃO ADVERTENCIA PUBLI
# 143        222                     AUT PESQ/ADVERTENCIA PUBLICADA
# 144        223           AUT PESQ/CONVITE PAG TAXA RENOV ALV PUBL
# 145        224             AUT PESQ/AUTO INFRAÇÃO MULTA PUBLICADA
# 146        225                  AUT PESQ/MULTA APLICADA PUBLICADA
# 147        226           AUT PESQ/SEGUNDA IMPOSICAO DE MULTA PUBL
# 148        227                 AUT PESQ/PAGAMENTO  MULTA EFETUADO
# 149        228           AUT PESQ/SOLICITA ANULAÇÃO AUTO INFRACAO
# 150        229                AUT PESQ/COBRANCA JUDICIAL DE MULTA
# 151        230           AUT PESQ/ARQUIVAMENTO AUTO INFRACAO PUBL
# 152        231           AUT PESQ/DENÚNCIA CONTRA TITULAR DE PESQ
# 153        232           AUT PESQ/DENÚNCIA IMPROCEDENTE PUBLICADA
# 154        233             AUT PESQ/DENÚNCIA PROCEDENTE PUBLICADA
# 155        234           AUT PESQ/SUSPENSAO TRAB PESQ NEGADA PUBL
# 156        235         AUT PESQ/PAGAMENTO TAXA ALVARA  RENOV PROT
# 157        236           AUT PESQ/DOCUMENTO DIVERSO PROTOCOLIZADO
# 158        237  AUT PESQ/INSTAURA PROC ADM  CAD/NULID ALVARÁ PUBL
# 159        238    AUT PESQ/ARQUIVAMENTO PROC ADM CAD/NUL ALV PUBL
# 160        239               AUT PESQ/DENÚNCIA DE INVASÃO DA ÁREA
# 161        240                        AUT PESQ/DEFESA APRESENTADA
# 162        241                   AUT PESQ/DEFESA ACEITA PUBLICADA
# 163        242               AUT PESQ/DEFESA NÃO ACEITA PUBLICADA
# 164        243                     AUT PESQ/RECURSO PROTOCOLIZADO
# 165        244                  AUT PESQ/RECURSO NEGADO PUBLICADO
# 166        245                 AUT PESQ/RECURSO PROVIDO PUBLICADO
# 167        246                  AUT PESQ/ÁREA SERVIDÃO SOLICITADA
# 168        247           AUT PESQ/ÁREA SERVIDÃO NÃO CONCEDIDA PUB
# 169        248           AUT PESQ/ÁREA SERVIDÃO CONCEDIDA PUBLICA
# 170        249  AUT PESQ/TRANSF DIREITOS -CESSÃO TOTAL PROTOCO...
# 171        250                       AUT PESQ/EXIGÊNCIA PUBLICADA
# 172        251    AUT PESQ/PRORROGAÇÃO PRAZO EXIGÊNCIA SOLICITADO
# 173        252     AUT PESQ/PRORROGAÇÃO PRAZO EXIGÊNCIA CONCEDIDO
# 174        253        AUT PESQ/PRORROGAÇÃO PRAZO EXIGÊNCIA NEGADO
# 175        254                   AUT PESQ/ÁREA LIVRE A PARTIR DE:
# 176        255           AUT PESQ/CUMPRIMENTO EXIGÊNCIA PROTOCOLI
# 177        256                        AUT PESQ/DESPACHO PUBLICADO
# 178        257                 AUT PESQ/REL ART 43 CONSTIT PROTOC
# 179        258             AUT PESQ/REL ART 43 CONSTIT ACEITO PUB
# 180        259           AUT PESQ/REL ART 43 CONST NÃO ACEITO PUB
# 181        260  AUT PESQ/TORNA S/EFEITO ALVARA DE PESQUISA ART...
# 182        261            AUT PESQ/PEDIDO RECONSIDERAÇÃO PROTOCOL
# 183        262        AUT PESQ/PEDIDO RECONSIDERAÇÃO ACEITA PUBIC
# 184        263         AUT PESQ/PEDIDO RECONSIDERAÇÃO NEGADA PUBL
# 185        264                    AUT PESQ/PAGAMENTO TAH EFETUADO
# 186        265       AUT PESQ/PRORROGAÇÃO PRAZO ALVARÁ SOLICITADO
# 187        266         AUT PESQ/OFICIO INTIMA P/ DEFESA CAD/NULID
# 188        267  AUT PESQ/INDEFERIMENTO RENOVAÇÃO ALVARÁ PUBLICADO
# 189        268          AUT PESQ/ALVARÁ DE RETIFICAÇÃO SOLICITADO
# 190        269     AUT PESQ/ALVARA DE RETIFICAÇÃO INDEFERIDO PUBL
# 191        270        AUT PESQ/NÃO CONHECE REQUERIMENTO PUBLICADO
# 192        271           AUT PESQ/ALVARÁ RENOVAÇÃO 1 ANO PUBLICAD
# 193        272           AUT PESQ/ALVARÁ RENOVAÇÃO 2 ANOS PUBLICA
# 194        273           AUT PESQ/TITULO DECLARADO NULO PUBLICADO
# 195        274           AUT PESQ/DESP DECL CAD/S.EF/REV ALV PUBL
# 196        275                AUT PESQ/ALVARÁ RENOVAÇÃO PUBLICADO
# 197        276           AUT PESQ/ALVARÁ DE RETIFICAÇÃO PUBLICADO
# 198        277           AUT PESQ/ALVARÁ RENOVAÇÃO 3 ANOS PUBLICA
# 199        278           AUT PESQ/RENUNCIA AUT PESQ PROTOCOLIZADA
# 200        279           AUT PESQ/ARQUIVAMENTO PROCESSO PUBLICADO
# 201        280                  AUT PESQ/BAIXA TRANSCRIÇÃO ALVARÁ
# 202        281    AUT PESQ/TRANSF DIREITOS -CESSÃO TOTAL APROVADA
# 203        282   AUT PESQ/TRANSF DIREITOS -CESSÃO TOTAL EFETIVADA
# 204        283       AUT PESQ/GUIA UTILIZAÇÃO REQUERIMENTO PROTOC
# 205        284      AUT PESQ/GUIA UTILIZAÇÃO INDEFERIDA PUBLICADA
# 206        285      AUT PESQ/GUIA UTILIZAÇÃO AUTORIZADA PUBLICADA
# 207        286            AUT PESQ/TORNA S/EFEITO BAIXA TRANSCRIC
# 208        287          AUT PESQ/SOLICITA DESCONS RENUNCIA ALVARA
# 209        288                AUT PESQ/INCUR ART 23 CM NESTA DATA
# 210        289     AUT PESQ/INCUR ART 23 CM SAIDA RELAT FORA PRAZ
# 211        290          AUT PESQ/RELATORIO PESQ FINAL APRESENTADO
# 212        291  DIR REQ LAVRA/RELATORIO PESQ APROV C/REDUC ÁRE...
# 213        292           AUT PESQ/INCUR ART 23 CM FINAL PRAZO ALV
# 214        293        AUT PESQ/RELATORIO PESQ PARCIAL APRESENTADO
# 215        294          AUT PESQ/RENÚNCIA AUT PESQ HOMOLOGADA PUB
# 216        295               AUT PESQ/ÁREA INDISPONIVEL PUBLICADO
# 217        296                AUT PESQ/TÍTULO CANCELADO PUBLICADO
# 218        297              AUT PESQ/REL PESQ ARQ ART 30C CM PUBL
# 219        298           AUT PESQ/REL PESQ NÃO APV ART 30B CM PUB
# 220        299            AUT PESQ/REL PESQ APROV ART 30A CM PUBL
# 221        300           AUT PESQ/TORNA S/EFEITO HOMOL RENUNC PUB
# 222        301        DISPONIB/VISTORIA PARA DISPONIBIL REALIZADA
# 223        302         DISPONIB/HABILIT EDITAL DISPONIB ART 26 CM
# 224        303  DISPONIB/CONSID PRIORITARIO-  EDITAL PESQUISA PUB
# 225        304      DISPONIB/EDITAL DISPONIB SEM PRETENDENTE PUBL
# 226        305  DISPONIB/ÁREA DISPONIBILIDADE PARA LAVRA - EDITAL
# 227        306           DISPONIB/EDITAL DISPON LAV S/EFEITO PUBL
# 228        307           DISPONIB/HABILIT EDITAL DISPONIB P/LAVRA
# 229        308      DISPONIB/INDEF HABILIT EDIT DISPONIB LAV PUBL
# 230        309    DISPONIB/CONSID PRIORITARIO-  EDITAL LAVRA PUBL
# 231        310  DISPONIB/ÁREA DISPONIBILIDADE PARA PESQUISA - ...
# 232        311           DISPONIB/EDITAL DISPON PESQ S/EFEITO PUB
# 233        312           DISPONIB/HABILIT EDITAL DISPONIBI P/PESQ
# 234        313     DISPONIB/INDEF HABILIT EDIT DISPONIB PESQ PUBL
# 235        314           DISPONIB/CONSID PRIOR EDIT DISP PESQ PUB
# 236        315           DISPONIB/DOCUMENTO DIVERSO PROTOCOLIZADO
# 237        316                        DISPONIB/DESPACHO PUBLICADO
# 238        317  DIR REQ LAVRA/RELATORIO PESQ APROV ART 30 I CM...
# 239        318   AUT PESQ/RELATORIO PESQ NÃO APV ART 30 II CM PUB
# 240        319     AUT PESQ/RELATORIO PESQ ARQ ART 30 III CM PUBL
# 241        320     AUT PESQ/RELATORIO PESQ SOBR ART 30 IV CM PUBL
# 242        321           AUT PESQ/ALVARÁ DE PESQUISA 01 ANO PUBLI
# 243        322           AUT PESQ/ALVARÁ DE PESQUISA 02 ANOS PUBL
# 244        323           AUT PESQ/ALVARÁ DE PESQUISA 03 ANOS PUBL
# 245        324             AUT PESQ/PRORROGAÇÃO PRAZO 01 ANO PUBL
# 246        325             AUT PESQ/PRORROGAÇÃO PRAZO 02 ANOS PUB
# 247        326             AUT PESQ/PRORROGAÇÃO PRAZO 03 ANOS PUB
# 248        327           AUT PESQ/DESPACHO RETIFICACAO ALVARÁ PUB
# 249        328           DISPONIB/ÁREA DISPONIVEL ART 26 CM PUBLI
# 250        329           DISPONIB/ÁREA DISP LAVRA ART 26 CM PUBLI
# 251        330  REQ LAV/TRANSF DIREITOS -CESSÃO TOTAL DIREITO ...
# 252        331  REQ LAV/TRANSF DIREITOS -CESSÃO TOTAL DIREITO ...
# 253        332  REQ LAV/TRANSF DIREITOS -CESSÃO TOTAL DIREITO ...
# 254        333  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 255        334           REQ PLG/INDEFERIMENTO DE PLANO PUBLICADO
# 256        335                    REQ PLG/INDEFERIMENTO PUBLICADO
# 257        336            REQ LAV/DOCUMENTO DIVERSO PROTOCOLIZADO
# 258        337            REQ PLG/IND ART 1 LEI 6567/78 PUBLICADO
# 259        338  REQ LAV/TRANSF DIREITOS -CESSÃO TOTAL DIREITO ...
# 260        339                  PLG/INCORPORAÇÃO/CESSÃO EFETIVADA
# 261        340                    REQ LAV/INTERDICAO LAVRA ILEGAL
# 262        341           REQ PLG/MEMORIAL DESCRITIVO ÁREA PLG PUB
# 263        342             REQ PLG/CONTESTAÇÃO COOPERATIVA PROTOC
# 264        343                                MANIFESTO DE JAZIDA
# 265        344                        REQ PLG/EXIGÊNCIA PUBLICADA
# 266        345     REQ PLG/PRORROGAÇÃO PRAZO EXIGÊNCIA SOLICITADO
# 267        346      REQ PLG/PRORROGAÇÃO PRAZO EXIGÊNCIA CONCEDIDA
# 268        347         REQ PLG/PRORROGAÇÃO PRAZO EXIGÊNCIA NEGADA
# 269        348            REQ PLG/CUMPRIMENTO  EXIGÊNCIA PROTOCOL
# 270        349   AUT PESQ/PRORROGAÇÃO PRAZO REQ LAVRA- 01 ANO PUB
# 271        350           REQ LAV/REQUERIMENTO LAVRA PROTOCOLIZADO
# 272        351           REQ LAV/DESISTENCIA REQ LAVRA PROTOCOLIZ
# 273        352       REQ LAV/DESISTENCIA REQ LAVRA HOMOLOGADA PUB
# 274        353        REQ PLG/PEDIDO RECONSIDERAÇÃO PROTOCOLIZADO
# 275        354              REQ PLG/PEDIDO RECONSIDERAÇÃO PROVIDO
# 276        355          REQ LAV/INDENIZAÇÃO AO PESQUISADOR NEGADA
# 277        356                         REQ LAV/DESPACHO PUBLICADO
# 278        357         DISPONIB/TORNA S/EFEITO DISPO ART 26 CM PU
# 279        358  DISPONIB/EDITAL DISPONIB ART 26 CM SEM PRETEND...
# 280        359  DISPONIB/INDEF HABILIT EDIT DISPONIB ART 26 CM...
# 281        360                     DISPONIB/RECURSO PROTOCOLIZADO
# 282        361                        REQ LAV/EXIGÊNCIA PUBLICADA
# 283        362     REQ LAV/PRORROGAÇÃO PRAZO EXIGÊNCIA SOLICITADO
# 284        363         REQ LAV/PRORROGAÇÃO PRAZO EXIGÊNCIA NEGADO
# 285        364      REQ LAV/PRORROGAÇÃO PRAZO EXIGÊNCIA CONCEDIDO
# 286        365           REQ LAV/CUMPRIMENTO EXIGÊNCIA PROTOCOLIZ
# 287        366             REQ LAV/EXIGÊNCIA REITERAÇÃO PUBLICADA
# 288        367               REQ PLG/PEDIDO RECONSIDERAÇÃO NEGADO
# 289        368  REQ PLG/TORNA S/EFEITO RECONSIDERAÇÃO INDEFERI...
# 290        369      DISPONIB/RECURSO- SUPERINTENDENTE NEGADO PUBL
# 291        370           REQ LAV/DENUNCIA CONTRA REQ LAVRA PROTOC
# 292        371           REQ LAV/DENUNC CONTRA REQ LAVRA PROCEDEN
# 293        372           REQ LAV/DENUNC CONTRA REQ LAVRA IMPROCED
# 294        373                REQ LAV/ASSENTIMENTO CDN SOLICITADO
# 295        374              REQ LAV/ASSENTIMENTO FUNAI SOLICITADO
# 296        375    REQ LAV/ASSENTIMENTO ORGAOS DIVERSOS SOLICITADO
# 297        376            REQ LAV/ASSENTIMENTO MARINHA SOLICITADO
# 298        377                REQ LAV/ASSENTIMENTO CDN AUTORIZADO
# 299        378              REQ LAV/ASSENTIMENTO FUNAI AUTORIZADO
# 300        379             REQ LAV/ASSENTIMENTO MARINHA AUTORIZAD
# 301        380       REQ LAV/ASSENTIMENTO ORGÃOS DIVERSOS AUTORIZ
# 302        381            REQ LAV/ASSENTIMENTO CDN NÃO AUTORIZADO
# 303        382           REQ LAV/ASSENTIMENTO FUNAI NÃO AUTORIZAD
# 304        383           REQ LAV/ASSENTIMENTO MARINHA NÃO AUTORIZ
# 305        384   REQ LAV/ASSENTIMENTO ORGÃOS DIVERSOS NÃO AUTORIZ
# 306        385            REQ LAV/ÁREA BLOQUEADA ART 42 CM PUBLIC
# 307        386     DISPONIB/RECURSO- SUPERINTENDENTE PROVIDO PUBL
# 308        387               REQ PLG/ANUÊNCIA CESSÃO APROVADA PUB
# 309        388           REQ PLG/INDEF PLANO ART 9° IN 5/2000 PUB
# 310        389    REQ LAV/TORNA S/EFEITO CADUCIDADE DIR REQ LAVRA
# 311        390           REQ LAV/INDEFERIMENTO REQ LAVRA PUBLICAD
# 312        391           REQ LAV/PEDIDO RECONSIDERAÇÃO PROTOCOLIZ
# 313        392           REQ LAV/PEDIDO RECONSIDERAC PROVIDA PUBL
# 314        393           REQ LAV/PEDIDO RECONSIDERAÇÃO NEGADO PUB
# 315        394           REQ LAV/RECURSO AO MINISTRO PROTOCOLIZAD
# 316        395           REQ LAV/RECURSO AO MINISTRO NEGADO PUBLI
# 317        396           REQ LAV/RECURSO AO MINISTRO PROVIDO PUBL
# 318        397           REQ LAV/CONVITE PAG TAXA PORT LAVRA PUBL
# 319        398           REQ LAV/COMPROV PAG TAXA PORT LAVRA PROT
# 320        399           REQ LAV/DECLARA CADUC DIREIT REQ LAV PUB
# 321        400     CONC LAV/PORTARIA CONCESSÃO DE LAVRA PUBLICADA
# 322        401       CONC LAV/PRORROGAÇÃO INICIO LAVRA SOLICITADO
# 323        402       CONC LAV/PRORROGAÇÃO INICIO LAVRA AUTORIZADO
# 324        403                CONC LAV/IMISSÃO DE POSSE REQUERIDA
# 325        404   CONC LAV/PRORROGAÇÃO INICIO LAVRA NAO AUTORIZADO
# 326        405                CONC LAV/INICIO DE LAVRA COMUNICADO
# 327        406            CONC LAV/EDITAL IMISSÃO POSSE PUBLICADA
# 328        407                CONC LAV/IMISSÃO DE POSSE REALIZADA
# 329        408            CONC LAV/IMISSÃO DE POSSE NÃO REALIZADA
# 330        409                  CONC LAV/IMISSÃO DE POSSE ANULADA
# 331        410           CONC LAV/ARQUIVAMENTO PROCESSO PUBLICADO
# 332        411   CONC LAV/SUSPENSAO TRABALHOS LAVRA PROTOCOLIZADO
# 333        412                  CONC LAV/VISTORIA LAVRA IRREGULAR
# 334        413            CONC LAV/VISTORIA LAVRA ÁREA ABANDONADA
# 335        414   CONC LAV/RELATÓRIO PESQ COMPLEMENTAR APRESENTADO
# 336        415            CONC LAV/MODIFICAÇÃO DE PAE APRESENTADO
# 337        416        CONC LAV/MODIFICAÇÃO DE PAE APROV PUBLICADO
# 338        417         CONC LAV/MODIFICAÇÃO DE PAE NÃO APROV PUBL
# 339        418                  CONC LAV/RAL ANO BASE APRESENTADO
# 340        419                  CONC LAV/RAL NÃO ACEITO PUBLICADO
# 341        420           CONC LAV/RAL ANOS ANTERIORES APRESENTADO
# 342        421      CONC LAV/RETIFICAÇÃO ÁREA LAVRA PROTOCOLIZADO
# 343        422      CONC LAV/TRANSF DIREITOS -CESSÃO TOTAL NEGADA
# 344        423             CONC LAV/RETIFICAÇÃO ÁREA LAVRA NEGADO
# 345        424  CONC LAV/RELATÓRIO REAVALIAÇÃO RESERVA APRESEN...
# 346        425    CONC LAV/RELATÓRIO REAVALIAÇÃO RESERVA APROVADO
# 347        426     CONC LAV/ADITAMENTO NOVA SUBSTÂNCIA SOLICITADA
# 348        427      CONC LAV/ADITAMENTO NOVA SUBST AUTORIZADO PUB
# 349        428  CONC LAV/ADITAMENTO NOVA SUBST NÃO AUTORIZADO PUB
# 350        429  CONC LAV/RELATÓRIO REAVALIAÇÃO RESERVA NÃO APR...
# 351        430           CONC LAV/RENÚNCIA CONCESSÃO LAVRA PROTOC
# 352        431           CONC LAV/BAIXA TRANSCRICAO TITL LAV PUBL
# 353        432               CONC LAV/ÁREA DE SERVIDÃO SOLICITADA
# 354        433         CONC LAV/ÁREA PROTEÇÃO DE FONTE SOLICITADA
# 355        434                   CONC LAV/ÁREA DE SERVIDÁO NEGADA
# 356        435           CONC LAV/ÁREA DE SERVIDÃO CONCEDIDA PUBL
# 357        436           CONC LAV/DOCUMENTO DIVERSO PROTOCOLIZADO
# 358        437      CONC LAV/SUSPENSÃO TRABALHOS LAVRA AUTORIZADO
# 359        438         CONC LAV/SUSPENSÃO TRABALHOS  LAVRA NEGADA
# 360        439   CONC LAV/SUSPENSÃO LAVRA AUTORIZADA 6 MESES PUBL
# 361        440          CONC LAV/ROTULO ÁGUA MINERAL APROVADO PUB
# 362        441     CONC LAV/SUSPENSÃO LAVRA AUTORIZADA 1 ANO PUBL
# 363        442             CONC LAV/INTERDIÇÃO DA LAVRA PUBLICADA
# 364        443    CONC LAV/SUSPENSÃO LAVRA AUTORIZADA 2 ANOS PUBL
# 365        444           CONC LAV/DESINTERDIÇÃO LAVRA AUTORIZ PUB
# 366        445    CONC LAV/SUSPENSÃO LAVRA AUTORIZADA 3 ANOS PUBL
# 367        446    CONC LAV/SUSPENSÃO LAVRA AUTORIZADA 4 ANOS PUBL
# 368        447  CONC LAV/SUSPENSÃO LAVRA AUTORIZADA  MAIS 4 AN...
# 369        448         CONC LAV/ROTULO ÁGUA MINERAL PROTOCOLIZADO
# 370        449     CONC LAV/ARRENDAMENTO TOTAL AVERBAÇÃO APROVADA
# 371        450    CONC LAV/ARRENDAMENTO TOTAL AVERBAÇÃO EFETIVADA
# 372        451    CONC LAV/TRANSF DIREITOS -CESSÃO TOTAL APROVADA
# 373        452   CONC LAV/TRANSF DIREITOS -CESSÃO TOTAL EFETIVADA
# 374        453  CONC LAV/TRANSF DIREITOS -CANCELAMENTO SOLICITADO
# 375        454            CONC LAV/PEDIDO AVERBAÇÃO NEGADO PUBLIC
# 376        455          CONC LAV/ONERACAO DIREITOS LAVRA APROVADA
# 377        456          CONC LAV/ONERAÇÃO DIREITOS LAVRA AVERBADA
# 378        457                     CONC LAV/ADVERTENCIA PUBLICADA
# 379        458           CONC LAV/PORTARIA ÁREA PROTEÇÃO PUBLICAD
# 380        459             CONC LAV/AUTO INFRAÇÃO MULTA PUBLICADA
# 381        460                  CONC LAV/MULTA APLICADA PUBLICADA
# 382        461                 CONC LAV/PAGAMENTO  MULTA EFETUADO
# 383        462      CONC LAV/ARQUIVAMENTO AUTO INFRAÇÃO PUBLICADO
# 384        463           CONC LAV/SOLICITA ANULAÇÃO AUTO INFRAÇÃO
# 385        464    CONC LAV/ÁREA PROTEÇÃO DE  FONTE NÃO AUTORIZADA
# 386        465    CONC LAV/TRANSF DIREITOS -CESSÃO TOTAL PROTOCOL
# 387        466             CONC LAV/DENÚNCIA CONTRA TITULAR LAVRA
# 388        467           CONC LAV/DENUN CONTRA TITULAR LAV IMPROC
# 389        468           CONC LAV/DENUN CONTRA TITULAR LAV PROCED
# 390        469    CONC LAV/TRANSF DIREITOS -CESSÃO PARCIAL NEGADA
# 391        470                       CONC LAV/EXIGÊNCIA PUBLICADA
# 392        471     CONC LAV/PRORROGAÇÃO PRAZO EXIGÊNCIA CONCEDIDO
# 393        472    CONC LAV/PRORROGAÇÃO PRAZO EXIGÊNCIA SOLICITADO
# 394        473           CONC LAV/CUMPRIMENTO EXIGÊNCIA PROTOCOLI
# 395        474                      CONC LAV/DEFESA PROTOCOLIZADA
# 396        475                   CONC LAV/DEFESA ACEITA PUBLICADA
# 397        476               CONC LAV/DEFESA NÃO ACEITA PUBLICADA
# 398        477                     CONC LAV/RECURSO PROTOCOLIZADO
# 399        478                 CONC LAV/RECURSO PROVIDO PUBLICADO
# 400        479                  CONC LAV/RECURSO NEGADO PUBLICADO
# 401        480      CONC LAV/ROTULO AGUA MINERAL NÃO APROVADO PUB
# 402        481              CONC LAV/GRUPAMENTO MINEIRO REQUERIDO
# 403        482           CONC LAV/GRUPAMENTO MINEIRO AUTORIZ PUBL
# 404        483     CONC LAV/GRUPAMENTO MINEIRO NÃO AUTORIZAD PUBL
# 405        484      CONC LAV/GRUPAMENTO MINEIRO INCLUSÃO ÁREA REQ
# 406        485     CONC LAV/GRUPAMENTO MINEIRO INCLUSÃO ÁREA PUBL
# 407        486      CONC LAV/GRUPAMENTO MINEIRO EXCLUSÃO ÁREA REQ
# 408        487    CONC LAV/GRUPAMENTO MINEIRO EXCLUSÃO ÁREA PUBLI
# 409        488       CONC LAV/PORTARIA ENGLOBANDO OUTRO TITL PUBL
# 410        489   CONC LAV/PORTARIA ENGLOBADA P/OUTRA PORTARIA PUB
# 411        490     CONC LAV/INSTAURADO PROC ADM CAD/NUL PUBLICADO
# 412        491   CONC LAV/ARQUIVAMENTO PROC ADM CAD/NUL PUBLICADO
# 413        492           CONC LAV/ÁREA NÃO DISPON P/PESQ OU LAVRA
# 414        493           CONC LAV/EDITAL DISPON P/LAVRA PUBLICADO
# 415        494  CONC LAV/ARQUIVAMENTO DO PROCESSO ÁREA LIVRE PUBL
# 416        495           CONC LAV/PORTARIA RETIFIC CONCESSÃO PUBL
# 417        496           CONC LAV/PORTARIA NULIDADE DE CONCE PUBL
# 418        497           CONC LAV/MANIFESTO MINA CANCELADO PUBLIC
# 419        498           CONC LAV/PORTARIA REVOGACÃO LAVRA PUBLIC
# 420        499    CONC LAV/PORTARIA CADUCADA S/EFEITO CONCES PUBL
# 421        500   CONC LAV/GRUPAMENTO MINEIRO INCLUSÃO ÁREA NEGADA
# 422        501        CONC LAV/ARRENDAMENTO RECISÃO PROTOCOLIZADA
# 423        502   CONC LAV/ARRENDAMENTO RECISÃO AVERBAÇÃO APROVADA
# 424        503  CONC LAV/ARRENDAMENTO RECISÃO AVERBAÇÃO EFETIVADA
# 425        504              CONC LAV/ONERAÇÃO DIREITOS -CANCELADO
# 426        505  CONC LAV/ONERAÇÃO DIREITOS -CANCELAMENTO AVERBADO
# 427        506  CONC LAV/PORTARIA DESMEMBRADA EM OUTRAS PUBLICADA
# 428        507   CONC LAV/PORTARIA DESMEMBRADA DE OUTRA PUBLICADA
# 429        508                        CONC LAV/DESPACHO PUBLICADO
# 430        509             CONC LAV/CONSORCIO MINERAÇÃO REQUERIDO
# 431        510           CONC LAV/CONSORCIO MINERACAO INDEFER PUB
# 432        511            CONC LAV/CONSORCIO MINERACAO AUTORIZADO
# 433        512              CONC LAV/CONCESSÃO INTEGRANTE DE G.M.
# 434        513                PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 435        514      CONC LAV/CONSÓRCIO MINERAÇÃO INCLUSÃO ÁREA PU
# 436        515           CONC LAV/TORNA S/EFEITO ART 43 CONST PUB
# 437        516                  CONC LAV/DENÚNCIA INVASÃO DE ÁREA
# 438        517           CONC LAV/RELATORIO ART 43 CONSTITUI PROT
# 439        518         CONC LAV/ÁREA LIVRE 30 DIAS APÓS PUBLICA D
# 440        519  CONC LAV/VISTORIA REALIZADA -REEMBOLSO PROTOCO...
# 441        520         CONC LAV/GRUPAMENTO MINEIRO CANCELADO PUBL
# 442        521                       PLG/RENOVAÇÃO PLG SOLICITADA
# 443        522  PLG/INDEFERIMENTO PRORROGAÇÃO PRAZO PLG PUBLICADO
# 444        523                        PLG/RENOVAÇÃO PLG PUBLICADA
# 445        524          PLG/ADITAMENTO NOVA SUBSTÂNCIA SOLICITADO
# 446        525          PLG/ADITAMENTO NOVA SUBSTÂNCIA AUTORIZADA
# 447        526         PLG/ADITAMENTO NOVA SUBSTÂNCIA NÃO AUT PUB
# 448        527           PLG/TRANSF DIREITOS -CESSÃO TOTAL NEGADA
# 449        528         PLG/TRANSF DIREITOS -CESSÃO PARCIAL NEGADA
# 450        529                          PLG/BAIXA TRANSCRIÇÃO PLG
# 451        530                            PLG/EXIGÊNCIA PUBLICADA
# 452        531            PLG/CUMPRIMENTO EXIGÊNCIA PROTOCOLIZADA
# 453        532                     PLG/CANCELAMENTO PLG PUBLICADO
# 454        533   AUT PESQ/TRANSF DIREITOS -CESSÃO PARCIAL ANULADA
# 455        534  CONC LAV/TORNA S/EFEITO CANCELAMENTO GRUPAM MI...
# 456        535             CONC LAV/TORNA S/EFEITO MULTA APLICADA
# 457        536   CONC LAV/TRANSF DIREITOS -DISTRATO PROTOCOLIZADO
# 458        537  DISPONIB/ANULA DECLARAÇÃO PRIOR EDITAL PESQUIS...
# 459        538  REQ PESQ/INDEFERIMENTO PLANO ART 9 IN 05/2000 PUB
# 460        539          CONC LAV/ARRENDAMENTO AVERBAÇÃO CANCELADA
# 461        540  AUT PESQ/TRANSF DIREITOS -CESSÃO PARCIAL EFETI...
# 462        541                  AUT PESQ/RAL ANO BASE APRESENTADO
# 463        542                       PLG/RAL ANO BASE APRESENTADO
# 464        543  CONC LAV/TORNA S/EFEITO APROVAÇÃO RELATÓRIO RE...
# 465        544  AUT PESQ/TORNA S/EFEITO DESP NEGOU CESSÃO PARC...
# 466        545  AUT PESQ/TRANSF DIREITOS -CESSÃO PARCIAL PROTO...
# 467        546  REQ LAV/TRANSF DIREITOS -CESSÃO PARCIAL REQ LA...
# 468        549            TORNA S/EFEITO NOTIFICAÇÃO CFEM (NFLDP)
# 469        550     CONC LAV/TORNA S/EFEITO APROVAÇÃO NOVO PAE PUB
# 470        551  CONC LAV/TRANSF DIREITOS -CESSÃO DIREITOS CANC...
# 471        552        REQ PLG/CONTESTAÇÃO COOPERATIVA NÃO PROVIDA
# 472        553            REQ PLG/CONTESTAÇÃO COOPERATIVA PROVIDA
# 473        554         CONC LAV/RENÚNCIA CONC LAV HOMOLOGADA PUBL
# 474        555             CONC LAV/ÁREA LIVRE A PARTIR DA PUBLIC
# 475        556       CONC LAV/TORNA S/EFEITO NOTIFICAÇÃO CFEM PUB
# 476        557  CONC LAV/TRANSF DIREITOS -CESSÃO PARCIAL APROVADA
# 477        558   CONC LAV/ARRENDAMENTO PARCIAL AVERBAÇÃO APROVADA
# 478        559  CONC LAV/ARRENDAMENTO PARCIAL AVERBAÇÃO EFETIVADA
# 479        560         REQ LAV/TORNA S/EFEITO EXIGÊNCIA PUBLICADA
# 480        561        AUT PESQ/PRORROGAÇÃO PRAZO REQ LAVRA NEGADO
# 481        562     DISPONIB/RENÚNCIA HABILITAÇÃO DISP ART 26 PROT
# 482        563        DISPONIB/HOMOLOGA RENÚNCIA HABILIT ART26 PU
# 483        564  REQ LAV/TRANSF DIREITOS -CESSÃO DE DIREITOS AN...
# 484        565           REQ PLG/ARQUIVAMENTO DEFINITIVO PROCESSO
# 485        566  REQ LAV/TRANSF DIREITOS -CESSÃO PARCIAL REQ LA...
# 486        567                 REQ PLG/INDEFERIMENTO DE PLANO PUB
# 487        568                    REQ PLG/IND ART 4 PORT 284/2000
# 488        569         REQ PLG/TORNA S/EFEITO EXIGÊNCIA PUBLICADA
# 489        570            REQ PLG/CONTESTAÇÃO COOP NÃO PROVIDA PU
# 490        571         PLG/TRANSF DIREITOS -CESSÃO TOTAL APROVADA
# 491        572        PLG/TRANSF DIREITOS -CESSÃO TOTAL EFETIVADA
# 492        573  REQ PLG/OPÇÃO REGIME AUTORIZAÇÃO PESQ PROTOCOL...
# 493        574   REQ PLG/OPÇÃO REGIME AUTORIZAÇÃO PESQ INDEFERIDO
# 494        575      REQ PLG/TORNA S/EFEITO DESPACHO INDEFERIMENTO
# 495        576                  PLG/AUTO INFRAÇÃO MULTA PUBLICADO
# 496        577                       PLG/MULTA APLICADA PUBLICADA
# 497        578                      PLG/PAGAMENTO  MULTA EFETUADO
# 498        579                PLG/SOLICITA ANULAÇÃO AUTO INFRAÇÃO
# 499        580                    PLG/AUTO INFRAÇÃO ARQUIVADO PUB
# 500        581             PLG/TORNA S/EFEITO A PERM LAVRA GARIMP
# 501        582          CONC LAV/ARRENDAMENTO TOTAL PROTOCOLIZADO
# 502        583  REQ LAV/TRANSF DIREITOS -CESSÃO PARCIAL REQ LA...
# 503        584    PLG/TRANSF DIREITOS -CESSÃO TOTAL PROTOCOLIZADA
# 504        585                  AUT PESQ/SOLICITA PARC DÉBITO TAH
# 505        586   AUT PESQ/INDEFERIMENTO PLANO PEDIDO PARC DÉB TAH
# 506        587          AUT PESQ/PARCELAMENTO DÉBITO TAH DEFERIDO
# 507        588        AUT PESQ/PAGAMENTO PARCELA DÉB TAH EFETUADO
# 508        589           REQ PLG/SOLICITA ANU PRÉVIA CESSÃO TOTAL
# 509        590           REQ PLG/AVERBAÇÃO CESSÃO TOTAL EFETIVADA
# 510        591           REQ PLG/SOLICITA DISTRATO CESSÃO TOT REQ
# 511        592         PLG/PRORROGAÇÃO PRAZO EXIGÊNCIA SOLICITADO
# 512        593         REQ LICEN/SOLICITA ANU PRÉVIA CESSÃO TOTAL
# 513        594         REQ LICEN/AVERBAÇÃO CESSÃO TOTAL EFETIVADA
# 514        595      LICEN/TRANSF DIREITOS -CESSÃO TOTAL EFETIVADA
# 515        596     CONC LAV/ONERAÇÃO DIREITOS -PENHORA AUTORIZADO
# 516        597       CONC LAV/ONERAÇÃO DIREITOS -PENHORA AVERBADO
# 517        598     AUT PESQ/ONERAÇÃO DIREITOS -PENHORA AUTORIZADO
# 518        599       AUT PESQ/ONERAÇÃO DIREITOS -PENHORA AVERBADO
# 519        600  PLG/TRANSF DIREITOS -CESSÃO PARCIAL PROTOCOLIZADA
# 520        601       PLG/TRANSF DIREITOS -CESSÃO PARCIAL APROVADA
# 521        602      PLG/TRANSF DIREITOS -CESSÃO PARCIAL EFETIVADA
# 522        603  REQ LAV/TRANSF DIREITOS -CESSÃO PARCIAL REQ LA...
# 523        604        CONC LAV/ARRENDAMENTO PARCIAL PROTOCOLIZADO
# 524        605     CONC LAV/ARRENDAMENTO PARCIAL AVERBAÇÃO NEGADA
# 525        606             REQ PLG/IND ART.6°  PORT 284/2000  PUB
# 526        607  DISPONIB/HOMOLOGA DESISTENCIA  HABILIT  EDITAL...
# 527        608    CONC LAV/TORNA S/EFEITO AUTO INFRAÇÃO PUBLICADO
# 528        609      REQ LAV/ONERAÇÃO DIREITOS LAVRA PROTOCOLIZADA
# 529        610           REQ LAV/ONERAÇÃO DIREITOS LAVRA APROVADA
# 530        611           REQ LAV/ONERAÇÃO DIREITOS LAVRA AVERBADA
# 531        612          REQ PLG/DESISTENCIA REQ PLG PROTOCOLIZADA
# 532        613   REQ PLG/DESISTÊNCIA REQ PLG HOMOLOGADA PUBLICADA
# 533        614          AUT PESQ/TAXA  ANUAL HECTARE PAGA A MENOR
# 534        615  REQ LAV/LIBERAÇÃO ONERAÇÃO DIREITOS LAVRA PUBL...
# 535        616  REQ LAV/LIBERAÇÃO ONERAÇÃO DIREITOS LAVRA AVER...
# 536        617                REQ PESQ/INDEFERE OPÇÃO REQ LICENÇA
# 537        618        REQ PESQ/PROCESSO SITUADO EM ÁREA BLOQUEADA
# 538        619         REQ PESQ/PROCESSO SITUADO EM ÁREA INDÍGENA
# 539        620         AUT PESQ/ÁREA PROTEÇÃO DE FONTE SOLICITADA
# 540        621    AUT PESQ/LICENÇA AMBIENTAL OPERAÇÃO APRESENTADA
# 541        622  AUT PESQ/LICENÇA AMBIENTAL INSTALAÇÃO APRESENTADA
# 542        623      AUT PESQ/GUIA UTILIZAÇÃO RENOVAÇÃO SOLICITADA
# 543        624        REQ LAV/GUIA UTILIZAÇÃO REQUERIMENTO PROTOC
# 544        625       REQ LAV/GUIA UTILIZAÇÃO AUTORIZADA PUBLICADA
# 545        626       REQ LAV/GUIA UTILIZAÇÃO INDEFERIDA PUBLICADA
# 546        627  CONC LAV/TRANSF DIREITOS -CESSÃO PARCIAL PROTOCOL
# 547        628  CONC LAV/TRANSF DIREITOS -CESSÃO PARCIAL EFETI...
# 548        629           REQ PESQ/ASSENT. CDN/CESSÃO DIREITOS AUT
# 549        630      AUT PESQ/ASSENTIMENTO CDN/CESSÃO DIREITOS AUT
# 550        631  REQ LAV/ASSENTIMENTO CDN/CESSÃO DIREITOS  AUTO...
# 551        632  CONC LAV/ASSENTIMENTO CDN/CESSÃO DIREITOS AUTO...
# 552        633  CONC LAV/TORNA S/EFEITO INSTAURAÇÃO PROC ADM C...
# 553        634          AUT PESQ/COMPLEMENTAÇÃO PGTO TAH EFETUADO
# 554        635                   AUT PESQ/AUTO INFRAÇÃO MULTA-TAH
# 555        636                   TORNA S/EFEITO AUTO INFRAÇÃO-TAH
# 556        637                     ARQUIVAMENTO AUTO INFRAÇÃO-TAH
# 557        638        AUT PESQ/AUTO INFRAÇÃO MULTA-RELATÓRIO PESQ
# 558        639     AUT PESQ/TORNA S/EFEITO AUTO INFRAÇÃO-REL PESQ
# 559        640       AUT PESQ/ARQUIVAMENTO AUTO INFRAÇÃO-REL PESQ
# 560        641                       AUT PESQ/MULTA  APLICADA-TAH
# 561        642              AUT PESQ/PAGAMENTO MULTA EFETUADO-TAH
# 562        643                 TORNA S/EFEITO MULTA  APLICADA-TAH
# 563        644        AUT PESQ/MULTA  APLICADA-RELATÓRIO PESQUISA
# 564        645         AUT PESQ/PAGAMENTO MULTA EFETUADO-REL PESQ
# 565        646    AUT PESQ/TORNA S/EFEITO MULTA APLICADA-REL PESQ
# 566        647         AUT PESQ/INSTAURA PROC ADM CADU ALVARÁ-TAH
# 567        648       AUT PESQ/TORNA S/EFEITO PROC ADM CAD ALV-TAH
# 568        649       AUT PESQ/ARQUIVAMENTO PROC  ADM CADU ALV-TAH
# 569        650          AUT PESQ/ALVARÁ DE PESQUISA CADUCADO -TAH
# 570        651         AUT PESQ/TORNA S/EFEITO CADUCIDADE ALV-TAH
# 571        652          AUT PESQ/SOLICITA DEVOLUÇÃO PAGAMENTO TAH
# 572        653          AUT PESQ/DEVOLUÇÃO PAGAMENTO TAH EFETUADA
# 573        654                  AUT PESQ/PARCELAMENTO TAH QUITADO
# 574        655       AUT PESQ/NOTIFICAÇÃO ADM I I PGTO DÉBITO TAH
# 575        656  AUT PESQ/TORNA S/EFEITO NOTIF ADM II PGTO DÉB TAH
# 576        657         CONC LAV/TORNA S/EFEITO DESPACHO PUBLICADO
# 577        658  LICEN/INSTAURA PROC ADM CANCELAMENTO REGISTRO ...
# 578        659        CONC LAV/TORNA S/EFEITO EXIGÊNCIA PUBLICADA
# 579        660    AUT PESQ/PRORROGAÇÃO PRAZO REQ LAVRA SOLICITADO
# 580        661         CONC LAV/COMPROVA PAGTO EMOL IMISSÃO POSSE
# 581        662                  NOTIFICAÇÃO ADM PGTO DÉBITO MULTA
# 582        663                 SOLICITA PARCELAMENTO DÉBITO MULTA
# 583        664             INDEFERE REQ PARCELAMENTO DÉBITO MULTA
# 584        665                        PARCELAMENTO MULTA DEFERIDO
# 585        666                 PGTO PARCELA DÉBITO MULTA EFETUADA
# 586        667                         PARCELAMENTO MULTA QUITADO
# 587        668                 SOLICITA DEVOLUÇÃO PAGAMENTO MULTA
# 588        669                 DEVOLUÇÃO PAGAMENTO MULTA EFETUADO
# 589        670                   DEVOLUÇÃO PAGAMENTO MULTA NEGADO
# 590        671                   PLG/DESPACHO RETIFICAÇÃO PLG PUB
# 591        672                 SOLICITA  PARCELAMENTO DÉBITO CFEM
# 592        673                     INDEF PARCELAMENTO DÉBITO CFEM
# 593        674                         PARCELAMENTO CFEM DEFERIDO
# 594        675                          PARCELAMENTO CFEM QUITADO
# 595        676                    LICENÇA AMBIENTAL PROTOCOLIZADA
# 596        677    DISPONIB/ÁREA DISPONIBILIDADE PARA PLG - EDITAL
# 597        678           CASSAÇÃO ANUENCIA PRÉVIA CESSÃO DIREITOS
# 598        679                 MANF/REGISTRO MANIFESTO SOLICITADO
# 599        680                  MANF/MANIFESTO DE MINA REGISTRADO
# 600        681                  AUT PESQ/RELATÓRIO PESQ ANALISADO
# 601        682                              REQ LAV/PAE ANALISADO
# 602        683      AUT PESQ/ONERAÇÃO DIREITOS -PENHORA CANCELADA
# 603        684  AUT PESQ/ONERAÇÃO DIREITOS -PENHORA CANCELAMEN...
# 604        685      CONC LAV/ONERAÇÃO DIREITOS -PENHORA CANCELADA
# 605        686  CONC LAV/ONERAÇÃO DIREITOS -PENHORA CANCELAMEN...
# 606        687              NOTIFICAÇÃO ADM PAGTO DÉBITO VISTORIA
# 607        688      AUT PESQ/OPÇÃO REGIME PERM. LAVRA GARIMP PROT
# 608        689         REQ LAV/NOTIFICAÇÃO RECOLHIMENTO CFEM PUBL
# 609        690        PAGAMENTO EMOLUMENTOS CESSÃO TOTAL DIREITOS
# 610        691      PAGAMENTO EMOLUMENTOS CESSÃO PARCIAL DIREITOS
# 611        692  PAGAMENTO EMOLUMENTOS INCORP. FUSÃO CISÃO EMPRESA
# 612        693        PAGAMENTO EMOLUMENTOS DEMAIS ATOS AVERBAÇÃO
# 613        694           PAGAMENTO VISTORIA FISCALIZAÇÃO EFETUADO
# 614        695   REQ LAV/TORNA S/EFEITO DESPACHO INDEF. REQ LAVRA
# 615        696      CONC LAV/TORNA S/EFEITO CADUCIDADE LAVRA PUBL
# 616        698             MANF/NULIDADE MANIFESTO DE MINA PUBLIC
# 617        699           MANF/DECLAR CADU/S.EFEIT MANIFESTO PUBLI
# 618        700       REQ LICEN/REQUERIMENTO LICENCIAMENTO PROTOCO
# 619        701                     LICEN/IND ART 7 IN 01/2001 PUB
# 620        702                    LICEN/IND ART 22 IN 01/2001 PUB
# 621        703                     LICEN/IND ART 6 IN 01/2001 PUB
# 622        704               LICEN/CANCELAMENTO LICENCIAMENTO PUB
# 623        705           LICEN/BAIXA LICENCIAMENTO ESGOTADO PRAZO
# 624        706             LICEN/PLANO APROVEITAMENTO ECON  APRES
# 625        707             LICEN/PLANO APROVEITAMENTO ECON  APROV
# 626        708                     PLG/RENÚNCIA PLG PROTOCOLIZADA
# 627        709              PLG/RENÚNCIA PLG HOMOLOGADA PUBLICADA
# 628        710           LICEN/CONSULTA ORGAOS DIVERS ENCAMINHADA
# 629        711              LICEN/ASSENT ORGAOS DIVERS AUTORIZADO
# 630        712           LICEN/ASSENT ORGAOS DIVERS NAO AUTORIZAD
# 631        713                           PLG/DECLARA NULIDADE PLG
# 632        714                         PLG/DECLARA CADUCIDADE PLG
# 633        715            PLG/INSTAURA PROCESSO DE CADUCIDADE PLG
# 634        718                          LICEN/EXIGÊNCIA PUBLICADA
# 635        719       LICEN/PRORROGAÇÃO PRAZO EXIGÊNCIA SOLICITADO
# 636        720           LICEN/CUMPRIMENTO EXIGÊNCIA PROTOCOLIZAD
# 637        721           LICEN/INDEF NÃO CUMPRIMENTO EXIGENC PUBL
# 638        722        LICEN/PRORROGAÇÃO PRAZO EXIGÊNCIA CONCEDIDO
# 639        723           LICEN/PRORROGAÇÃO PRAZO EXIGÊNCIA NEGADA
# 640        730           LICEN/LICENCIAMENTO AUTORIZADO PUBLICADO
# 641        736              LICEN/DOCUMENTO DIVERSO PROTOCOLIZADO
# 642        737                LICEN/ARREND DIR LICENCIAMENTO PROT
# 643        738            LICEN/INDEFERIMENTO ART 18 CM PUBLICADO
# 644        739         LICEN/IND LIMINAR ART 1 LEI 6567/78 PUBLIC
# 645        740                      LICEN/INDEFERIMENTO PUBLICADO
# 646        741    LICEN/RETIFICAÇÃO REGISTRO DE LICENÇA PUBLICADA
# 647        742      LICEN/PRORROGAÇÃO REGISTRO LICENÇA AUTORIZADA
# 648        743          LICEN/REEMBOLSO VISTORIA REALIZADA PROTOC
# 649        744   LICEN/INDEFERIMENTO PRORROGAÇÃO REGISTRO LICENÇA
# 650        745           LICEN/PEDIDO RECONSIDERAÇÃO PROVIDA PUBL
# 651        746          LICEN/PEDIDO RECONSIDERAÇÃO PROTOCOLIZADO
# 652        747       LICEN/PEDIDO RECONSIDERAÇÃO NEGADO PUBLICADO
# 653        748       LICEN/TRANSF DIREITOS -CESSÃO TOTAL PROTOCOL
# 654        749       LICEN/TRANSF DIREITOS -CESSÃO TOTAL APROVADA
# 655        750         LICEN/TRANSF DIREITOS -CESSÃO TOTAL NEGADA
# 656        751                 LICEN/BAIXA LICENÇA ESGOTADO PRAZO
# 657        752          LICEN/ARREND DEREIT LICENC APROVADO PUBLD
# 658        753            LICEN/RECURSO AO MINISTRO PROTOCOLIZADO
# 659        754                    LICEN/RECURSO PROVIDO PUBLICADO
# 660        755   LICEN/PRORROGAÇÃO REGISTRO LICENÇA PROTOCOLIZADA
# 661        756                   LICEN/DESPACHO DIVERSO PUBLICADO
# 662        757                     LICEN/RECURSO NEGADO PUBLICADO
# 663        758          LICEN/TORNA S/EFEITO NOTIFICAÇÃO CFEM PUB
# 664        759              LICEN/RAL ANOS ANTERIORES APRESENTADO
# 665        760                     LICEN/RAL ANO BASE APRESENTADO
# 666        761                      LICEN/AUTO INFRACAO PUBLICADO
# 667        762            LICEN/AUTO INFRAÇÃO ARQUIVADO PUBLICADO
# 668        763           LICEN/RELATORIO ART 43 CONSTITUICAO PROT
# 669        764               LICEN/NEGA ANUÊNCIA CESSÃO TOTAL PUB
# 670        765       LICEN/TRANSF DIREITOS -CESSÃO PARCIAL NEGADA
# 671        766                     LICEN/TORNA S/EFEITO EXIGÊNCIA
# 672        767  LICEN/TORNA S/EFEITO BAIXA REGISTRO DE LICENÇA...
# 673        768  LICEN/TORNA S/EFEITO PRORROGAÇÃO REGISTRO LICENÇA
# 674        769    LICEN/TORNA S/EFEITO DESPACHO INDEFERIMENTO PUB
# 675        770         LICEN/ADITAMENTO NOVA SUBST AUTORIZADO PUB
# 676        771             LICEN/TORNA S/EFEITO LICENCIAMENTO PUB
# 677        772           LICEN/NOTIFICAÇÃO RECOLHIMENTO CFEM PUBL
# 678        773                     LICEN/MULTA APLICADA PUBLICADA
# 679        774               LICEN/ADVERTENCIA APLICADA PUBLICADA
# 680        775                     LICEN/DENÚNCIA INVASÃO DA ÁREA
# 681        776     LICEN/TRANSF DIREITOS -CESSÃO PARCIAL APROVADA
# 682        777  LICEN/TORNA S/EFEITO DESPACHO NEGA RECONSIDERAÇÃO
# 683        778         LICEN/INDEF PLANO ART. 9 IN 05/2000 PUBLIC
# 684        779          LICEN/DENÚNCIA C/TIT REG LIC IMPROCEDENTE
# 685        780      REQ LICEN/DESISTENCIA REQ LICEN PROTOCOLIZADA
# 686        781     LICEN/ARQUIVAMENTO PROCESSO LICENCIAMENTO PUBL
# 687        782                 LICEN/ÁREA BLOQUEADA ART 42 CM PUB
# 688        783    REQ LICEN/DESISTÊNCIA REQ LICEN HOMOLOGADA PUBL
# 689        784  LICEN/RENÚNCIA LICENCIAMENTO HOMOLOGADA PUBLICADA
# 690        785           LICEN/TORNO S/EFEI HOMOL DES REQ REG LIC
# 691        786           LICEN/ONERAÇÃO DIREITOS -PENHOR AVERBADO
# 692        787                LICEN/ENGLOBAMENTO ÁREAS SOLICITADO
# 693        788                 LICEN/ENGLOBAMENTO ÁREAS PUBLICADO
# 694        789    REQ LICEN/CESSÃO TOTAL REQ. REGISTRO LICEN. PUB
# 695        790        LICEN/OPÇÃO REGIME AUTORIZAÇÃO  PESQ PROTOC
# 696        791     LICEN/OPÇÃO REGIME AUTORIZAÇÃO PESQ INDEFERIDA
# 697        793            REQ PLG/DOCUMENTO DIVERSO PROTOCOLIZADO
# 698        794       AUT PESQ/RELATORIO PESQ POSITIVO APRESENTADO
# 699        795       AUT PESQ/RELATORIO PESQ NEGATIVO APRESENTADO
# 700        796    LICEN/TORNA S/EFEITO CANCELAMENTO DO TITULO PUB
# 701        797    LICEN/TORNA S/EFEITO LICENCIAMENTO ART 43 CONST
# 702        798              LICEN/ÁREA LIVRE 30 DIAS APOS PUBLICA
# 703        799            LICEN/CANCELAMENTO LICENCIAMENTO PUBLIC
# 704        800             ART 43 CONSTIT RELACINADO P/ DISTRITOS
# 705        801              DISP 43 ADCT/ÁREA LIVRE DATA DA PUBLI
# 706        802  REQ LAV/TRANSF DIREITOS -CESSÃO PARCIAL DIREIT...
# 707        803                        AUTO DE PARALISAÇÃO LAVRADO
# 708        805           PLG/OPÇÃO REGIME AUTORIZAÇÃO PESQ PROTOC
# 709        806                    REQ LAV/AUTO INFRAÇÃO PUBLICADO
# 710        807       REQ LAV/ARQUIVAMENTO AUTO INFRAÇÂO PUBLICADO
# 711        808                       REQ LAV/DEFESA PROTOCOLIZADA
# 712        809                    REQ LAV/DEFESA ACEITA PUBLICADA
# 713        810                REQ LAV/DEFESA NÃO ACEITA PUBLICADA
# 714        811                   REQ LAV/MULTA APLICADA PUBLICADA
# 715        812                  REQ LAV/PAGAMENTO  MULTA EFETUADO
# 716        813              REQ LAV/TORNA S/EFEITO MULTA APLICADA
# 717        820                 REQ EXT/REQUERIMENTO PROTOCOLIZADO
# 718        821           REQ EXT/INDEFERIMENTO DE PLANO PUBLICADO
# 719        822          REQ EXT/INDEFERIMENTO INTERFERENCIA TOTAL
# 720        823  REQ EXT/INDEFERIMENTO ÁREA EM PARQUE NAC EST O...
# 721        824    REQ EXT/INDEFERIMENTO ÁREA EM RESERVA BIOLÓGICA
# 722        825   REQ EXT/EXIGÊNCIA COM PRAZO DE 30 DIAS PUBLICADA
# 723        826  REQ EXT/PRORROGAÇÃO PRAZO EXIGÊNCIA PROTOCOLIZADO
# 724        827         REQ EXT/PRORROGAÇÃO PRAZO EXIGÊNCIA NEGADO
# 725        828         REQ EXT/TORNA S/EFEITO EXIGÊNCIA PUBLICADA
# ...
# 2237      2450     LICEN/SIGILO INFORMAÇÃO MINERÁRIA - INDEFERIDO
# 2238      2451       LICEN/SIGILO INFORMAÇÃO MINERÁRIA - DEFERIDO
# 2239      2452       PLG/SIGILO INFORMAÇÃO MINERÁRIA - INDEFERIDO
# 2240      2453         PLG/SIGILO INFORMAÇÃO MINERÁRIA - DEFERIDO
# 2241      2454   REG EXT/SIGILO INFORMAÇÃO MINERÁRIA - INDEFERIDO
# 2242      2455     REG EXT/SIGILO INFORMAÇÃO MINERÁRIA - DEFERIDO
# 2243      2456   REQ EXT/SIGILO INFORMAÇÃO MINERÁRIA - INDEFERIDO
# 2244      2457     REQ EXT/SIGILO INFORMAÇÃO MINERÁRIA - DEFERIDO
# 2245      2458   REQ LAV/SIGILO INFORMAÇÃO MINERÁRIA - INDEFERIDO
# 2246      2459     REQ LAV/SIGILO INFORMAÇÃO MINERÁRIA - DEFERIDO
# 2247      2460  REQ LICEN/SIGILO INFORMAÇÃO MINERÁRIA - INDEFE...
# 2248      2461   REQ LICEN/SIGILO INFORMAÇÃO MINERÁRIA - DEFERIDO
# 2249      2462  AUT PESQ/ASSENTIMENTO CDN CASSADO/CESSÃO DIREITOS
# 2250      2463  DISPONIB/LEILÃO ELET/PROPOSTA PAGA SEM REQ/RET...
# 2251      2464  DISPONIB/LEILÃO ELET/PROPOSTA NÃO PAGA/RETORNO...
# 2252      2465                        DISPONIB/MANIFESTAÇÃO UNICA
# 2253      2466  DISPONIB/MANIFESTAÇÃO UNICA/SEM PROTOC REQ/ARE...
# 2254      2467         DISPONIB/LEILÃO ELETRONICO AREA PARA LAVRA
# 2255      2468      DISPONIB/LEILÃO ELETRONICO AREA PARA PESQUISA
# 2256      2469           DISPONIB/LEILÃO ELETRONICO AREA PARA PLG
# 2257      2470  DISPONIB/LEILÃO ELET/SEM REGISTRO PROPOSTA/ARE...
# 2258      2471  DISPONIB/LEILÃO ELET/PROPOSTA PAGA/SEM PROTOC ...
# 2259      2472  DISPONIB/LEILÃO ELET/PROP UNICAFINANC NÃO PAGA...
# 2260      2473  DISPONIB/LEILÃO ELET/PROPOSTAS FINAN NÃO PAGAS...
# 2261      2474             AUT PESQ/FISCALIZAÇÃO REMOTA CONCLUIDA
# 2262      2475        DIR REQ LAVRA/FISCALIZAÇÃO REMOTA CONCLUIDA
# 2263      2476              REQ LAV/FISCALIZAÇÃO REMOTA CONCLUIDA
# 2264      2477             CONC LAV/FISCALIZAÇÃO REMOTA CONCLUIDA
# 2265      2478                LICEN/FISCALIZAÇÃO REMOTA CONCLUIDA
# 2266      2479                  PLG/FISCALIZAÇÃO REMOTA CONCLUIDA
# 2267      2480              REG EXT/FISCALIZAÇÃO REMOTA CONCLUIDA
# 2268      2481  AUT PESQ/VENCIMENTO ALVARÁ ALTERADO RESOLUÇÃO ...
# 2269      2482             DIR REQ LAVRA/ASSENTIMENTO CDN CASSADO
# 2270      2483  DIR REQ LAVRA/ASSENTIMENTO CDN CASSADO/CESSÃO ...
# 2271      2484                   REQ LAV/ASSENTIMENTO CDN CASSADO
# 2272      2485   REQ LAV/ASSENTIMENTO CDN CASSADO/CESSÃO DIREITOS
# 2273      2486  CONC LAV/ASSENTIMENTO CDN CASSADO/CESSÃO DIREITOS
# 2274      2487     CONC LAV/ASSENTIMENTO CDN CASSADO/ARRENDAMENTO
# 2275      2488              REQ LAV/DECLARAÇÃO DE APTIDÃO EMITIDA
# 2276      2489    AUT PESQ/DECLARAÇÃO DE RESULTADOS DE EXPLORAÇÃO
# 2277      2490           AUT PESQ/DECLARAÇÃO DE RECURSOS MINERAIS
# 2278      2491           AUT PESQ/DECLARAÇÃO DE RESERVAS MINERAIS
# 2279      2492  DIR REQ LAVRA/DECLARAÇÃO DE RESULTADOS DE EXPL...
# 2280      2493      DIR REQ LAVRA/DECLARAÇÃO DE RECURSOS MINERAIS
# 2281      2494      DIR REQ LAVRA/DECLARAÇÃO DE RESERVAS MINERAIS
# 2282      2495     REQ LAV/DECLARAÇÃO DE RESULTADOS DE EXPLORAÇÃO
# 2283      2496            REQ LAV/DECLARAÇÃO DE RECURSOS MINERAIS
# 2284      2497            REQ LAV/DECLARAÇÃO DE RESERVAS MINERAIS
# 2285      2498  CONC LAV/BARRAGENS NÃO CONHECE REQUERIMENTO PU...
# 2286      2499              REQ EXT/DECLARAÇÃO DE APTIDÃO EMITIDA
# 2287      2500    CONC LAV/DECLARAÇÃO DE RESULTADOS DE EXPLORAÇÃO
# 2288      2501           CONC LAV/DECLARAÇÃO DE RECURSOS MINERAIS
# 2289      2502           CONC LAV/DECLARAÇÃO DE RESERVAS MINERAIS
# 2290      2503     CONC LAV/PLANO DE FECHAMENTO DE MINA ANALISADO
# 2291      2504      CONC LAV/PLANO DE FECHAMENTO DE MINA APROVADO
# 2292      2505    LICEN/PLANO DE FECHAMENTO DE MINA PROTOCOLIZADO
# 2293      2506        LICEN/PLANO DE FECHAMENTO DE MINA ANALISADO
# 2294      2507         LICEN/PLANO DE FECHAMENTO DE MINA APROVADO
# 2295      2508      PLG/PLANO DE FECHAMENTO DE MINA PROTOCOLIZADO
# 2296      2509          PLG/PLANO DE FECHAMENTO DE MINA ANALISADO
# 2297      2510           PLG/PLANO DE FECHAMENTO DE MINA APROVADO
# 2298      2511  REG EXT/PLANO DE FECHAMENTO DE MINA PROTOCOLIZADO
# 2299      2512      REG EXT/PLANO DE FECHAMENTO DE MINA ANALISADO
# 2300      2513       REG EXT/PLANO DE FECHAMENTO DE MINA APROVADO
# 2301      2514               AUT PESQ/BARRAGENS EMBARGO PUBLICADO
# 2302      2515               CONC LAV/BARRAGENS EMBARGO PUBLICADO
# 2303      2516                  LICEN/BARRAGENS EMBARGO PUBLICADO
# 2304      2517                    PLG/BARRAGENS EMBARGO PUBLICADO
# 2305      2518                REQ LAV/BARRAGENS EMBARGO PUBLICADO
# 2306      2519      AUT PESQ/BARRAGENS DESEMBARGO SOLICITADO PROT
# 2307      2520      CONC LAV/BARRAGENS DESEMBARGO SOLICITADO PROT
# 2308      2521         LICEN/BARRAGENS DESEMBARGO SOLICITADO PROT
# 2309      2522           PLG/BARRAGENS DESEMBARGO SOLICITADO PROT
# 2310      2523       REQ LAV/BARRAGENS DESEMBARGO SOLICITADO PROT
# 2311      2524     AUT PESQ/BARRAGENS DESEMBARGO NEGADO PUBLICADO
# 2312      2525     CONC LAV/BARRAGENS DESEMBARGO NEGADO PUBLICADO
# 2313      2526        LICEN/BARRAGENS DESEMBARGO NEGADO PUBLICADO
# 2314      2527          PLG/BARRAGENS DESEMBARGO NEGADO PUBLICADO
# 2315      2528      REQ LAV/BARRAGENS DESEMBARGO NEGADO PUBLICADO
# 2316      2529            AUT PESQ/BARRAGENS DESEMBARGO PUBLICADO
# 2317      2530            CONC LAV/BARRAGENS DESEMBARGO PUBLICADO
# 2318      2531               LICEN/BARRAGENS DESEMBARGO PUBLICADO
# 2319      2532                 PLG/BARRAGENS DESEMBARGO PUBLICADO
# 2320      2533             REQ LAV/BARRAGENS DESEMBARGO PUBLICADO
# 2321      2534    AUT PESQ/BARRAGENS ANÁLISE PROCESSUAL CONCLUÍDA
# 2322      2535    CONC LAV/BARRAGENS ANÁLISE PROCESSUAL CONCLUÍDA
# 2323      2536       LICEN/BARRAGENS ANÁLISE PROCESSUAL CONCLUÍDA
# 2324      2537         PLG/BARRAGENS ANÁLISE PROCESSUAL CONCLUÍDA
# 2325      2538     REQ LAV/BARRAGENS ANÁLISE PROCESSUAL CONCLUÍDA
# 2326      2539            AUT PESQ/BARRAGENS AUTO DE INFRAÇÃO PUB
# 2327      2540  AUT PESQ/BARRAGENS DECLAR CONDIÇÃO ESTABILIDAD...
# 2328      2541  AUT PESQ/BARRAGENS DECLAR CONDIÇÃOESTABILIDADE...
# 2329      2542               AUT PESQ/BARRAGENS DEFESA ACEITA PUB
# 2330      2543          AUT PESQ/BARRAGENS DEFESA  NÃO ACEITA PUB
# 2331      2544    AUT PESQ/BARRAGENS EXIGENCIA PRAZO ESPECIAL PUB
# 2332      2545          AUT PESQ/BARRAGENS EXIGENCIA PRAZO OFICIO
# 2333      2546             AUT PESQ/BARRAGENS EXIGENCIA PUBLICADA
# 2334      2547              AUT PESQ/BARRAGENS MULTA APLICADA PUB
# 2335      2548  AUT PESQ/BARRAGENS PRORROG EXIGÊNCIA PRAZO OFICIO
# 2336      2549  AUT PESQ/BARRAGENS PRORROG PRAZO EXIGÊNCIA CON...
# 2337      2550              AUT PESQ/BARRAGENS RECURSO NEGADO PUB
# 2338      2551             AUT PESQ/BARRAGENS RECURSO PROVIDO PUB
# 2339      2552           AUT PESQ/BARRAGENS REITERA EXIGENCIA PUB
# 2340      2553  AUT PESQ/BARRAGENS TORNA S/ EFEITO AUTO DE INF...
# 2341      2554       AUT PESQ/BARRAGENS TORNA S/ EFEITO MULTA PUB
# 2342      2555  AUT PESQ/BARRAGENS NÃO CONHECE REQUERIMENTO PU...
# 2343      2556  DIR REQ LAVRA/BARRAGENS DECLAR CONDIÇÃO ESTABI...
# 2344      2557             DIR REQ LAVRA/BARRAGENS DCE NÃO ACEITO
# 2345      2558        DIR REQ LAVRA/BARRAGENS EXIGENCIA PUBLICADA
# 2346      2559  DIR REQ LAVRA/BARRAGENS PRORROG PRAZO EXIGENCI...
# 2347      2560  DIR REQ LAVRA/BARRAGENS EXIGENCIA PRAZO ESPECI...
# 2348      2561     DIR REQ LAVRA/BARRAGENS EXIGENCIA PRAZO OFICIO
# 2349      2562       DIR REQ LAVRA/BARRAGENS DESINTERDIÇÃO NEGADA
# 2350      2563          DIR REQ LAVRA/BARRAGENS DESINTERDIÇÃO PUB
# 2351      2564      DIR REQ LAVRA/BARRAGENS REITERA EXIGENCIA PUB
# 2352      2565  DIR REQ LAVRA/BARRAGENS PRORROG PRAZO EXIGENCI...
# 2353      2566  DIR REQ LAVRA/BARRAGENS PRORROG EXIGENCIA PRAZ...
# 2354      2567       DIR REQ LAVRA/BARRAGENS AUTO DE INFRAÇÃO PUB
# 2355      2568  DIR REQ LAVRA/BARRAGENS TORNA S/ EFEITO AUTO D...
# 2356      2569          DIR REQ LAVRA/BARRAGENS DEFESA ACEITA PUB
# 2357      2570      DIR REQ LAVRA/BARRAGENS DEFESA NÃO ACEITA PUB
# 2358      2571         DIR REQ LAVRA/BARRAGENS MULTA APLICADA PUB
# 2359      2572   DIR REQ LAVRA/BARRAGENS TORNA S/EFEITO MULTA PUB
# 2360      2573         DIR REQ LAVRA/BARRAGENS RECURSO NEGADO PUB
# 2361      2574        DIR REQ LAVRA/BARRAGENS RECURSO PROVIDO PUB
# 2362      2575          DIR REQ LAVRA/BARRAGENS EMBARGO PUBLICADO
# 2363      2576       DIR REQ LAVRA/BARRAGENS DESEMBARGO PUBLICADO
# 2364      2577          DIR REQ LAVRA/BARRAGENS DESEMBARGO NEGADO
# 2365      2578  DIR REQ LAVRA/BARRAGENS NÃO CONHECE REQUERIMEN...
# 2366      2579  LICEN/BARRAGENS NAO CONHECE REQUERIMENTO PUBLI...
# 2367      2580   PLG/BARRAGENS NAO CONHECE REQUERIMENTO PUBLICADO
# 2368      2581  REQ LAV/BARRAGENS NAO CONHECE REQUERIMENTO PUB...
# 2369      2582  DIR REQ LAVRA/BARRAGENS ANALISE PROCESSUAL CON...
# 2370      2583  AUT PESQ/BARRAGENS PRORROG PRAZO EXIGENCIA NEGADO
# 2371      2584  AUT PESQ/BARRAGENS CUMPRIMENTO DE EXIGENCIA PR...
# 2372      2585  AUT PESQ/BARRAGENS DEFESA AUTO INFRAÇÃO PROTOC...
# 2373      2586  AUT PESQ/BARRAGENS PRORROG PRAZO EXIGÊNCIA SOL...
# 2374      2587  AUT PESQ/BARRAGENS PROTOC ENTREGA PAEBM À DEFE...
# 2375      2588  AUT PESQ/BARRAGENS PROTOC ENTREGA PAEBM À PREF...
# 2376      2589     AUT PESQ/BARRAGENS RECURSO MULTA PROTOCOLIZADO
# 2377      2590  DIR REQ LAVRA/BARRAGENS CUMPRIMENTO DE EXIGENC...
# 2378      2591  DIR REQ LAVRA/BARRAGENS PRORROG PRAZO EXIGÊNCI...
# 2379      2592  DIR REQ LAVRA/BARRAGENS PROTOC ENTREGA PAEBM À...
# 2380      2593  DIR REQ LAVRA/BARRAGENS PROTOC ENTREGA PAEBM À...
# 2381      2594  DIR REQ LAVRA/BARRAGENS SOLICITA DESINTERDIÇÃO...
# 2382      2595  DIR REQ LAVRA/BARRAGENS DESEMBARGO SOLICITADO ...
# 2383      2596  DIR REQ LAVRA/BARRAGENS DEFESA AUTO INFRAÇÃO P...
# 2384      2597  DIR REQ LAVRA/BARRAGENS RECURSO MULTA PROTOCOL...
# 2385      2598  AUT PESQ/BARRAGENS TORNA SEM EFEITO DESPACHO P...
# 2386      2599  CONC LAV/BARRAGENS TORNA SEM EFEITO DESPACHO P...
# 2387      2600                  REQ PESQ/ANULA PUBLICAÇÃO - REPEM
# 2388      2601  DIR REQ LAVRA/BARRAGENS TORNA SEM EFEITO DESPA...
# 2389      2602  LICEN/BARRAGENS TORNA SEM EFEITO DESPACHO PUBL...
# 2390      2603  PLG/BARRAGENS TORNA SEM EFEITO DESPACHO PUBLICADO
# 2391      2604  REQ LAV/BARRAGENS TORNA SEM EFEITO DESPACHO PU...
# 2392      2605  AUT PESQ/BARRAGENS RETIFICAÇÃO DE  DESPACHO PU...
# 2393      2606  CONC LAV/BARRAGENS RETIFICAÇÃO DE  DESPACHO PU...
# 2394      2607  DIR REQ LAVRA/BARRAGENS RETIFICAÇÃO DE  DESPAC...
# 2395      2608  LICEN/BARRAGENS RETIFICAÇÃO DE  DESPACHO PUBLI...
# 2396      2609   PLG/BARRAGENS RETIFICAÇÃO DE  DESPACHO PUBLICADO
# 2397      2610  REQ LAV/BARRAGENS RETIFICAÇÃO DE  DESPACHO PUB...
# 2398      2611       CONC LAV/PORTARIA CONCESSÃO DE LAVRA GER/ANM
# 2399      2612  REQ PESQ/PEDIDO RECONSIDERAÇÃO PROVIDA - SUPER...
# 2400      2613  REQ PESQ/PEDIDO RECONSIDERAÇÃO NEGADA - SUPERI...
# 2401      2614     REQ LAV/RECURSO 2ª INSTÂNCIA PROVIDO PUBLICADO
# 2402      2615   REQ LICEN/RECURSO 2ª INSTÂNCIA PROVIDO PUBLICADO
# 2403      2616     REQ PLG/RECURSO 2ª INSTÂNCIA PROVIDO PUBLICADO
# 2404      2617     REQ EXT/RECURSO 2ª INSTÂNCIA PROVIDO PUBLICADO
# 2405      2618  CONC LAV/PORTARIA ENGLOBANDO ÁREAS PESQUISADAS...
# 2406      2619      AUT PESQ/GUIA DE UTILIZAÇÃO PFM PROTOCOLIZADO
# 2407      2620           AUT PESQ/GUIA DE UTILIZAÇÃO PFM APROVADO
# 2408      2621  DIR REQ LAVRA/GUIA DE UTILIZAÇÃO PFM PROTOCOLI...
# 2409      2622      DIR REQ LAVRA/GUIA DE UTILIZAÇÃO PFM APROVADO
# 2410      2623       REQ LAV/GUIA DE UTILIZAÇÃO PFM PROTOCOLIZADO
# 2411      2624          REQ LAV/GUIA DE UTILIZAÇÃO PFM AUTORIZADO
# 2412      2625  REQ LAV/PLANO DE FECHAMENTO DE MINA PROTOCOLIZADO
# 2413      2626  REQ LICEN/PLANO DE FECHAMENTO DE MINA PROTOCOL...
# 2414      2627  REQ PLG/PLANO DE FECHAMENTO DE MINA PROTOCOLIZADO
# 2415      2628  REQ EXT/PLANO DE FECHAMENTO DE MINA PROTOCOLIZADO
# 2416      2629  AUT PESQ/GUIA DE UTILIZAÇÃO RELAT EXEC PFM PRO...
# 2417      2630  AUT PESQ/GUIA DE UTILIZAÇÃO RELAT EXEC PFM APR...
# 2418      2631  DIR REQ LAVRA/GUIA DE UTILIZAÇÃO RELAT EXEC PF...
# 2419      2632  DIR REQ LAVRA/GUIA DE UTILIZAÇÃO RELAT EXEC PF...
# 2420      2633  REQ LAV/GUIA DE UTILIZAÇÃO RELAT EXEC PFM PROT...
# 2421      2634  REQ LAV/GUIA DE UTILIZAÇÃO RELAT EXEC PFM APRO...
# 2422      2635              CONC LAV/RELAT EXEC PFM PROTOCOLIZADO
# 2423      2636                   CONC LAV/RELAT EXEC PFM APROVADO
# 2424      2637                 LICEN/RELAT EXEC PFM PROTOCOLIZADO
# 2425      2638                      LICEN/RELAT EXEC PFM APROVADO
# 2426      2639                   PLG/RELAT EXEC PFM PROTOCOLIZADO
# 2427      2640                        PLG/RELAT EXEC PFM APROVADO
# 2428      2641               REG EXT/RELAT EXEC PFM PROTOCOLIZADO
# 2429      2642                    REG EXT/RELAT EXEC PFM APROVADO
# 2430      2643    AUT PESQ/RECURSO 2ª INSTANCIA PROVIDO PUBLICADO
# 2431      2644  DIR REQ LAVRA/RECURSO 2ª INSTÂNCIA PROVIDO PUB...
# 2432      2645    CONC LAV/RECURSO 2ª INSTÂNCIA PROVIDO PUBLICADO
# 2433      2646       LICEN/RECURSO 2ª INSTÂNCIA PROVIDO PUBLICADO
# 2434      2647         PLG/RECURSO 2ª INSTÂNCIA PROVIDO PUBLICADO
# 2435      2648     REG EXT/RECURSO 2ª INSTÂNCIA PROVIDO PUBLICADO
# 2436      2649  DISPONIB/ÁREA CONQUISTADA - AVALIAÇÃO SOCIAL -...
# 2437      2650                             DISPONIB/ÁREA SUSPENSA
# 2438      2663  CONC LAV/ÁREA DISPONIBILIDADE PARA PESQUISA - ...
# 2439      2664   REQ LAV/ÁREA DISPONIBILIDADE PARA LAVRA - EDITAL
# 2440      2665  CONC LAV/ÁREA DISPONIBILIDADE PARA LAVRA - EDITAL
# 2441      2677    DISPONIB/ÁREA DISPONIBILIDADE PARA PLG - EDITAL
# 2442      2802  DISPONIB/ÁREA DESCARTADA DISPONIB P/ PESQUISA ...
# 2443      2836  DISPONIB/ÁREA DESCARTADA DISPONIB PARA PLG - E...
# 2444      2866    REQ PESQ/ÁREA DISPONIBILIDADE PARA PLG - EDITAL
# 2445      2867     REQ PLG/ÁREA DISPONIBILIDADE PARA PLG - EDITAL
# 2446      2868         PLG/ÁREA DISPONIBILIDADE PARA PLG - EDITAL
# 2447      2869    AUT PESQ/ÁREA DISPONIBILIDADE PARA PLG - EDITAL
# 2448      2870                 CONC LAV/TORNA SEM EFEITO PORTARIA
# 2449      2883  DISPONIB/ÁREA DESBLOQUEADA DISPONIB PARA PLG -...
# 2450      2890      CONC LAV/BARRAGENS EXIGÊNCIA PRAZO OFICIO PUB
# 2451      2891  CONC LAV/EXIGÊNCIA BARRAGEM - PORT MME 21/2019...
# 2452      2892  CONC LAV/EXIGÊNCIA BARRAGEM - CONS MINIST - RE...
# 2453      2893  CONC LAV/CUMPRIMENTO DE EXIGÊNCIA BARRAGEM - A...
# 2454      2894  CONC LAV/CUMP EXIGÊNCIA BARRAGEM-PORT MME 21/2...
# 2455      2895  CONC LAV/CUMP EXIGÊNCIA BARRAGEM CONS MINST-RE...
# 2456      2896           PLG/BARRAGENS EXIGÊNCIA PRAZO OFICIO PUB
# 2457      2897  CONC LAV/EXIG BARRAGEM-PORT MME 21/19 CONS MIN...
# 2458      2898  CONC LAV/CUMP EXIG BARRAGEM-PORT MME 21/19 CON...
# 2459      2899    PLG/CUMPRIMENTO EXIGÊNCIA BARRAGEM - ANM PROTOC
# 2460      2900         LICEN/BARRAGENS EXIGÊNCIA PRAZO OFICIO PUB
# 2461      2901  LICEN/CUMPRIMENTO EXIGÊNCIA BARRAGEM - ANM PROTOC
# 2462      2902       REQ LAV/BARRAGENS EXIGÊNCIA PRAZO OFICIO PUB
# 2463      2903          REQ LAV/EXIGÊNCIA BARRAGEM - ANM - PROTOC
# 2464      2904             SIGILO INFORMAÇÃO MINERARIA- REQUERIDA
# 2465      2905              SIGILO INFORMAÇÃO MINERÁRIA- DEFERIDA
# 2466      2906           SIGILO INFORMAÇÃO MINERÁRIA - INDEFERIDA
# 2467      2907              REG EXT/AUTO INFRAÇÃO MULTA PUBLICADA
# 2468      2908                   REG EXT/MULTA APLICADA PUBLICADA
# 2469      2909  CONC LAV/PRORROGAÇÃO DE EXIGÊNCIA BARRAGEM - O...
# 2470      2910  REQ LAV/PRORROGAÇÃO DE EXIGÊNCIA BARRAGEM - OF...
# 2471      2911  PLG/PRORROGAÇÃO DE EXIGÊNCIA BARRAGEM - OF CIR...
# 2472      2912  LICEN/PRORROGAÇÃO DE EXIGÊNCIA BARRAGEM - OF C...
# 2473      2913  CONC LAV/PORTARIA CADUCADA CONCESSÃO DE LAVRA ...
# 2474      2914  CONC LAV/ADITAMENTO NOVA SUBST AUTORIZADO PUB ANM
# 2475      2915  CONC LAV/ADITAMENTO NOVA SUBST NÃO AUTORIZADO ...
# 2476      2916          ART. 57 AUT PESQ/RECURSO NEGADO PUBLICADO
# 2477      2917          ART. 59 AUT PESQ/RECURSO NEGADO PUBLICADO
# 2478      2918          Art. 60 AUT PESQ/RECURSO NEGADO PUBLICADO

# %%
#Linkando Evento:
dicEvento={}
for i in range(len(Evento)):
    dicEvento[i]={Evento['IDEvento'][i]:Evento['DSEvento'][i]}

for i in dicEvento:
   
    dicEvento[0].update(dicEvento[i])
dicEvento=dicEvento[0]

ProcessoEvento['Evento_']=ProcessoEvento['IDEvento'].map(dicEvento)

# %%
ProcessoEvento.to_csv('ProcessoEvento.csv')

# %% [markdown]
# ### Para ProcessoMunicipio

# %%
ProcessoMunicipio=pd.read_csv('E:\\Mineracao\\ProcessoMunicipio.txt', sep=';', encoding='latin1')
Municipio = pd.read_csv('E:\\Mineracao\\Municipio.txt', sep=';', encoding='latin1')

# %%
ProcessoMunicipio
# Out:
#            DSProcesso  IDMunicipio            Municipios  UF
# 0        884.018/2015      1400027               AMAJARI  RR
# 1        884.018/2016      1400209             CARACARAÍ  RR
# 2        884.018/2017      1400100             BOA VISTA  RR
# 3        884.018/2018      1400282               IRACEMA  RR
# 4        884.018/2019      1400407             NORMANDIA  RR
# ...               ...          ...                   ...  ..
# 1072083  826.032/1999      4101804             ARAUCÁRIA  PR
# 1072084  826.032/2000      4125506  SÃO JOSÉ DOS PINHAIS  PR
# 1072085  826.032/2001      4101804             ARAUCÁRIA  PR
# 1072086  826.032/2001      4106209              CONTENDA  PR
# 1072087  826.032/2002      4122305             RIO NEGRO  PR
#
# [1072088 rows x 4 columns]

# %%
#Linkando Municipio:
dicMunicipio={}
for i in range(len(Municipio)):
    dicMunicipio[i]={Municipio['IDMunicipio'][i]:Municipio['NMMunicipio'][i]}

for i in dicMunicipio:
   
    dicMunicipio[0].update(dicMunicipio[i])
dicMunicipio=dicMunicipio[0]

ProcessoMunicipio['Municipios']=ProcessoMunicipio['IDMunicipio'].map(dicMunicipio)

# %%
#Linkando para UF
uf={}
for i in range(len(Municipio)):
    uf[i]={Municipio['IDMunicipio'][i]:Municipio['SGUF'][i]}
    
for i in uf:   
    uf[0].update(uf[i])

uf=uf[0]
uf
ProcessoMunicipio['UF']=ProcessoMunicipio['IDMunicipio'].map(uf)

# %%
ProcessoMunicipio.to_csv('ProcessoMunicipio.csv')

# %% [markdown]
# ### Para Processo com as bases individuais

# %%
Processo=pd.read_csv('E:\\Mineracao\\Processo.txt', sep=';', encoding='latin1')
TipoRequerimento = pd.read_csv('E:\\Mineracao\\TipoRequerimento.txt', sep=';', encoding='latin1')
FaseProcesso = pd.read_csv('E:\\Mineracao\\FaseProcesso.txt', sep=';', encoding='latin1')
UnidadeAdministrativaRegional = pd.read_csv('E:\\Mineracao\\UnidadeAdministrativaRegional.txt', sep=';', encoding='latin1')
UnidadeProtocolizadora = pd.read_csv('E:\\Mineracao\\UnidadeProtocolizadora.txt', sep=';', encoding='latin1')

# %%
Processo
# Out:
#           DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 0       300.263/2020      300263           2020       S  48069.300263/2020-18
# 1       300.263/2021      300263           2021       S  48403.300263/2021-42
# 2       300.263/2022      300263           2022       S  48402.300263/2022-33
# 3       300.264/2009      300264           2009       S  27211.300264/2009-88
# 4       300.264/2010      300264           2010       N  27206.300264/2010-91
# ...              ...         ...            ...     ...                   ...
# 914772  826.028/2023      826028           2023       S  48069.826028/2023-14
# 914773  826.029/1988      826029           1988       N  27213.826029/1988-36
# 914774  826.029/1989      826029           1989       N  27213.826029/1989-17
# 914775  826.029/1990      826029           1990       N  27213.826029/1990-51
# 914776  826.029/1991      826029           1991       N  27213.826029/1991-31
#
#         IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 0                      0.0              15                               13
# 1                      0.0               8                                3
# 2                      0.0              15                                2
# 3                      0.0               8                               11
# 4                      0.0               8                                6
# ...                    ...             ...                              ...
# 914772                 5.0              13                               13
# 914773                 5.0               7                               13
# 914774                 1.0               1                               13
# 914775                 5.0               7                               13
# 914776                 1.0               2                               13
#
#         IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 0                        48069.0                  NaN  2011-08-23 17:09:10
# 1                        48403.0                  NaN  2006-03-21 00:00:00
# 2                        48402.0                  NaN  2015-12-08 08:24:36
# 3                        27211.0                  NaN  2004-04-13 00:00:00
# 4                        27206.0                  NaN  2003-09-22 00:00:00
# ...                          ...                  ...                  ...
# 914772                   48069.0  2023-02-09 16:33:00  2023-02-09 16:32:41
# 914773                   27213.0  1988-05-26 00:00:00  1988-05-26 00:00:00
# 914774                   27213.0  1989-02-27 00:00:00  1989-02-27 00:00:00
# 914775                   27213.0  1990-02-23 00:00:00  1990-02-23 00:00:00
# 914776                   27213.0  1991-02-05 00:00:00  1991-02-05 00:00:00
#
#        QTAreaHA                        Tipo_Requerimento  \
# 0         25,76                                      NaN
# 1        103,11                                      NaN
# 2         93,36                                      NaN
# 3        748,16                                      NaN
# 4          0,00                                      NaN
# ...         ...                                      ...
# 914772     2,97      Requerimento de Registro de Licença
# 914773     5,71      Requerimento de Registro de Licença
# 914774  1000,00  Requerimento de Autorização de Pesquisa
# 914775    13,72      Requerimento de Registro de Licença
# 914776   224,89  Requerimento de Autorização de Pesquisa
#
#                         Fase_Processo             Unidade_ADM  \
# 0           Apto para Disponibilidade  Gerência Regional / PR
# 1                     Disponibilidade  Gerência Regional / MG
# 2           Apto para Disponibilidade  Gerência Regional / SP
# 3                     Disponibilidade  Gerência Regional / SC
# 4                     Disponibilidade  Gerência Regional / GO
# ...                               ...                     ...
# 914772  Requerimento de Licenciamento  Gerência Regional / PR
# 914773                  Licenciamento  Gerência Regional / PR
# 914774       Requerimento de Pesquisa  Gerência Regional / PR
# 914775                  Licenciamento  Gerência Regional / PR
# 914776        Autorização de Pesquisa  Gerência Regional / PR
#
#          Unidade_Protocolizadora
# 0                         PARANÁ
# 1                   MINAS GERAIS
# 2                      SÃO PAULO
# 3       Unid. Protocolizadora 11
# 4        Unid. Protocolizadora 6
# ...                          ...
# 914772                    PARANÁ
# 914773  Unid. Protocolizadora 13
# 914774  Unid. Protocolizadora 13
# 914775  Unid. Protocolizadora 13
# 914776  Unid. Protocolizadora 13
#
# [914777 rows x 16 columns]

# %%
#Linkando TipoRequerimento
dicTipoRequerimento={}
for i in range(len(TipoRequerimento)):
    dicTipoRequerimento[i]={TipoRequerimento['IDTipoRequerimento'][i]:TipoRequerimento['DSTipoRequerimento'][i]}

for i in dicTipoRequerimento:
   
    dicTipoRequerimento[0].update(dicTipoRequerimento[i])
dicTipoRequerimento=dicTipoRequerimento[0]

Processo['Tipo_Requerimento']=Processo['IDTipoRequerimento'].map(dicTipoRequerimento)

# %%
# Linkando FaseProcesso

dicFaseProcesso={}
for i in range(len(FaseProcesso)):
    dicFaseProcesso[i]={FaseProcesso['IDFaseProcesso'][i]:FaseProcesso['DSFaseProcesso'][i]}

for i in dicFaseProcesso:
   
    dicFaseProcesso[0].update(dicFaseProcesso[i])
dicFaseProcesso=dicFaseProcesso[0]

Processo['Fase_Processo']=Processo['IDFaseProcesso'].map(dicFaseProcesso)

# %%
# Linkando UnidadeAdministrativaRegional

dicUnidadeAdministrativaRegional={}
for i in range(len(UnidadeAdministrativaRegional)):
    dicUnidadeAdministrativaRegional[i]={UnidadeAdministrativaRegional['IDUnidadeAdministrativaRegional'][i]:UnidadeAdministrativaRegional['DSUnidadeAdministrativaRegional'][i]}

for i in dicUnidadeAdministrativaRegional:
   
    dicUnidadeAdministrativaRegional[0].update(dicUnidadeAdministrativaRegional[i])
dicUnidadeAdministrativaRegional=dicUnidadeAdministrativaRegional[0]

Processo['Unidade_ADM']=Processo['IDUnidadeAdministrativaRegional'].map(dicUnidadeAdministrativaRegional)

# %%
# Linkando UnidadeProtocolizadora

dicUnidadeProtocolizadora={}
for i in range(len(UnidadeProtocolizadora)):
    dicUnidadeProtocolizadora[i]={UnidadeProtocolizadora['IDUnidadeProtocolizadora'][i]:UnidadeProtocolizadora['DSUnidadeProtocolizadora'][i]}

for i in dicUnidadeProtocolizadora:
   
    dicUnidadeProtocolizadora[0].update(dicUnidadeProtocolizadora[i])
dicUnidadeProtocolizadora=dicUnidadeProtocolizadora[0]

Processo['Unidade_Protocolizadora']=Processo['IDUnidadeProtocolizadora'].map(dicUnidadeProtocolizadora)

# %%
Processo.to_csv('Processo.csv')

# %% [markdown]
# # Escopo da análise de dados
#
# ##### Filtrar para os anos de 2019 até 2021, para substância ouros e afins, no estado do Pará
# ##### Filtrar pelo evento: 333>1402>513
# ##### Filtrar pelo evento 333>1402>1403>513
# ##### Filtrar pelo evento 333>1403>513
# ##### Reter apenas processos com maior área

# %% [markdown]
# ##### Nosso primeiro passo será filtrar para o Pará e ano 19 ate 22

# %%
#Lendo as planilhas:
processo_sub = pd.read_table('C:/Users/napcc/Dropbox (CPI)/EduardoMinsky/Scripts/ProcessoSubstancia.xls', sep=',')
processo = pd.read_table('C:/Users/napcc/Dropbox (CPI)/EduardoMinsky/Scripts/Processo.xls', sep=',', encoding='latin1')
evento = pd.read_table('C:/Users/napcc/Dropbox (CPI)/EduardoMinsky/Scripts/ProcessoEvento.xls', sep=',', encoding='latin1')
mun = pd.read_table('C:/Users/napcc/Dropbox (CPI)/EduardoMinsky/Scripts/ProcessoMunicipio.xls', sep=',', encoding='latin1')
pessoa = pd.read_table('C:/Users/napcc/Dropbox (CPI)/EduardoMinsky/Scripts/ProcessoPessoa.xls', sep=',', encoding='latin1')
# Out:
# C:\Users\napcc\AppData\Local\Temp\ipykernel_15216\1345815607.py:6: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   pessoa = pd.read_table('C:/Users/napcc/Dropbox (CPI)/EduardoMinsky/Scripts/ProcessoPessoa.xls', sep=',', encoding='latin1')

# %%
#Quantos dados temos para o brasil?
f'A nossa base possui {processo.drop_duplicates(subset="DSProcesso").shape[0]} processos únicos para o Brasil'
# Out:
# 'A nossa base possui 915381 processos únicos para o Brasil'

# %%
# Filtrando na base de municipios os dados do Para
para = mun.query('UF == "PA"')
del para['Unnamed: 0']
para
# Out:
#            DSProcesso  IDMunicipio    Municipios  UF
# 383      811.363/1973      1503606      ITAITUBA  PA
# 1111     004.140/1957      1502202      CAPANEMA  PA
# 1112     004.141/1957      1502202      CAPANEMA  PA
# 1323     004.512/1955      1504802  MONTE ALEGRE  PA
# 1380     004.610/1964      1503903        JURUTI  PA
# ...               ...          ...           ...  ..
# 1072532  800.178/1990      1508308         VISEU  PA
# 1072574  800.179/1973      1500404      ALENQUER  PA
# 1072575  800.179/1973      1504802  MONTE ALEGRE  PA
# 1072631  800.180/1973      1500404      ALENQUER  PA
# 1072632  800.180/1973      1504802  MONTE ALEGRE  PA
#
# [120111 rows x 4 columns]

# %%
#Limpando um pouco a base principal de processos:
del processo['Unnamed: 0']
processo
# Out:
#           DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 0       300.263/2020      300263           2020       S  48069.300263/2020-18
# 1       300.263/2021      300263           2021       S  48403.300263/2021-42
# 2       300.263/2022      300263           2022       S  48402.300263/2022-33
# 3       300.264/2009      300264           2009       S  27211.300264/2009-88
# 4       300.264/2010      300264           2010       N  27206.300264/2010-91
# ...              ...         ...            ...     ...                   ...
# 915376  810.096/2019      810096           2019       S  48401.810096/2019-49
# 915377  810.096/2020      810096           2020       S  48052.810096/2020-90
# 915378  810.096/2022      810096           2022       S  48052.810096/2022-51
# 915379  810.096/2023      810096           2023       S  48052.810096/2023-32
# 915380  810.097/1973      810097           1973       N  27206.810097/1973-96
#
#         IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 0                      0.0              15                               13
# 1                      0.0               8                                3
# 2                      0.0              15                                2
# 3                      0.0               8                               11
# 4                      0.0               8                                6
# ...                    ...             ...                              ...
# 915376                 7.0              11                                1
# 915377                23.0               7                                1
# 915378                 1.0               2                                1
# 915379                 1.0               1                                1
# 915380                 1.0               1                                6
#
#         IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 0                        48069.0                  NaN  2011-08-23 17:09:10
# 1                        48403.0                  NaN  2006-03-21 00:00:00
# 2                        48402.0                  NaN  2015-12-08 08:24:36
# 3                        27211.0                  NaN  2004-04-13 00:00:00
# 4                        27206.0                  NaN  2003-09-22 00:00:00
# ...                          ...                  ...                  ...
# 915376                   48401.0  2019-03-19 11:00:00  2019-03-19 11:00:25
# 915377                   48052.0  2020-03-03 21:12:00  2018-10-29 14:34:36
# 915378                   48052.0  2022-02-18 10:05:00  2022-02-18 10:04:55
# 915379                   48052.0  2023-02-15 14:32:00  2023-02-15 14:31:42
# 915380                   27206.0  1973-07-24 00:00:00  1973-07-24 00:00:00
#
#        QTAreaHA                                  Tipo_Requerimento  \
# 0         25,76                                                NaN
# 1        103,11                                                NaN
# 2         93,36                                                NaN
# 3        748,16                                                NaN
# 4          0,00                                                NaN
# ...         ...                                                ...
# 915376     2,35             Requerimento de Registro de ExtraÃ§Ã£o
# 915377    16,35  Requerimento de MudanÃ§a de Regime para Licenc...
# 915378    47,83          Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 915379    40,65          Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 915380   615,00          Requerimento de AutorizaÃ§Ã£o de Pesquisa
#
#                                  Fase_Processo              Unidade_ADM  \
# 0                    Apto para Disponibilidade  GerÃªncia Regional / PR
# 1                              Disponibilidade  GerÃªncia Regional / MG
# 2                    Apto para Disponibilidade  GerÃªncia Regional / SP
# 3                              Disponibilidade  GerÃªncia Regional / SC
# 4                              Disponibilidade  GerÃªncia Regional / GO
# ...                                        ...                      ...
# 915376  Requerimento de Registro de ExtraÃ§Ã£o  GerÃªncia Regional / RS
# 915377                           Licenciamento  GerÃªncia Regional / RS
# 915378               AutorizaÃ§Ã£o de Pesquisa  GerÃªncia Regional / RS
# 915379                Requerimento de Pesquisa  GerÃªncia Regional / RS
# 915380                Requerimento de Pesquisa  GerÃªncia Regional / GO
#
#          Unidade_Protocolizadora
# 0                        PARANÃ
# 1                   MINAS GERAIS
# 2                     SÃO PAULO
# 3       Unid. Protocolizadora 11
# 4        Unid. Protocolizadora 6
# ...                          ...
# 915376         RIO GRANDE DO SUL
# 915377         RIO GRANDE DO SUL
# 915378         RIO GRANDE DO SUL
# 915379         RIO GRANDE DO SUL
# 915380   Unid. Protocolizadora 6
#
# [915381 rows x 16 columns]

# %%
#Inner join entre a base principal de processos e municipios do Para para termos apenas processo nessa região:
processo_para = processo.merge(para,on='DSProcesso',how='inner')
processo_para
# Out:
#           DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 0       800.513/1975      800513           1975       N  27205.800513/1975-10
# 1       850.308/1985      850308           1985       N  27205.850308/1985-77
# 2       850.308/1986      850308           1986       N  27205.850308/1986-58
# 3       850.308/1987      850308           1987       N  27205.850308/1987-39
# 4       850.308/1988      850308           1988       N  27205.850308/1988-10
# ...              ...         ...            ...     ...                   ...
# 120105  864.026/2008      864026           2008       N  48417.864026/2008-89
# 120106  864.026/2008      864026           2008       N  48417.864026/2008-89
# 120107  803.024/1975      803024           1975       N  27205.803024/1975-10
# 120108  806.026/1975      806026           1975       N  27205.806026/1975-61
# 120109  858.017/1990      858017           1990       S  27205.858017/1990-94
#
#         IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 0                      1.0               2                                5
# 1                      1.0               1                                5
# 2                      1.0               2                                5
# 3                      1.0               1                                5
# 4                      1.0               1                                5
# ...                    ...             ...                              ...
# 120105                 1.0               8                               17
# 120106                 1.0               8                               17
# 120107                 1.0               1                                5
# 120108                 1.0               2                                5
# 120109                 1.0               1                                5
#
#         IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 0                        27205.0  1975-01-14 00:00:00  1975-01-14 00:00:00
# 1                        27205.0  1985-04-01 00:00:00  1985-04-01 00:00:00
# 2                        27205.0  1986-04-15 00:00:00  1986-04-15 00:00:00
# 3                        27205.0  1987-04-27 00:00:00  1987-04-27 00:00:00
# 4                        27205.0  1988-03-24 00:00:00  1988-03-24 00:00:00
# ...                          ...                  ...                  ...
# 120105                   48417.0  2008-01-25 16:22:00  2008-01-25 16:22:00
# 120106                   48417.0  2008-01-25 16:22:00  2008-01-25 16:22:00
# 120107                   27205.0  1975-04-09 00:00:00  1975-04-09 00:00:00
# 120108                   27205.0  1975-07-08 00:00:00  1975-07-08 00:00:00
# 120109                   27205.0  1990-01-12 00:00:00  1990-01-12 00:00:00
#
#         QTAreaHA                          Tipo_Requerimento  \
# 0       10000,00  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 1        1000,00  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 2        6861,69  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 3        1000,00  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 4        2000,00  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# ...          ...                                        ...
# 120105   9864,30  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 120106   9864,30  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 120107  10000,00  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 120108   1000,00  Requerimento de AutorizaÃ§Ã£o de Pesquisa
# 120109      0,00  Requerimento de AutorizaÃ§Ã£o de Pesquisa
#
#                     Fase_Processo              Unidade_ADM  \
# 0       AutorizaÃ§Ã£o de Pesquisa  GerÃªncia Regional / PA
# 1        Requerimento de Pesquisa  GerÃªncia Regional / PA
# 2       AutorizaÃ§Ã£o de Pesquisa  GerÃªncia Regional / PA
# 3        Requerimento de Pesquisa  GerÃªncia Regional / PA
# 4        Requerimento de Pesquisa  GerÃªncia Regional / PA
# ...                           ...                      ...
# 120105            Disponibilidade  GerÃªncia Regional / TO
# 120106            Disponibilidade  GerÃªncia Regional / TO
# 120107   Requerimento de Pesquisa  GerÃªncia Regional / PA
# 120108  AutorizaÃ§Ã£o de Pesquisa  GerÃªncia Regional / PA
# 120109   Requerimento de Pesquisa  GerÃªncia Regional / PA
#
#         Unidade_Protocolizadora  IDMunicipio                Municipios  UF
# 0       Unid. Protocolizadora 5      1504208                   MARABÃ  PA
# 1       Unid. Protocolizadora 5      1500602                  ALTAMIRA  PA
# 2       Unid. Protocolizadora 5      1504208                   MARABÃ  PA
# 3       Unid. Protocolizadora 5      1503606                  ITAITUBA  PA
# 4       Unid. Protocolizadora 5      1506005                   PRAINHA  PA
# ...                         ...          ...                       ...  ..
# 120105                TOCANTINS      1501758  BREJO GRANDE DO ARAGUAIA  PA
# 120106                TOCANTINS      1505494        PALESTINA DO PARÃ  PA
# 120107  Unid. Protocolizadora 5      1505304                ORIXIMINÃ  PA
# 120108  Unid. Protocolizadora 5      1504802              MONTE ALEGRE  PA
# 120109  Unid. Protocolizadora 5      1503606                  ITAITUBA  PA
#
# [120110 rows x 19 columns]

# %%
#Vamos agora excluir processos antigos e também processos não ativos:
a = processo_para.query('BTAtivo =="S"')
processo_para_ativos = a.query('NRAnoProcesso >=2019 and NRAnoProcesso <2023') 
processo_para_ativos
f'A nossa base de dados para o Para  possui processo para os anos de {processo_para_ativos["NRAnoProcesso"].unique()} e apenas processos que são classificados como {processo_para_ativos["BTAtivo"].unique()}'
# Out:
# "A nossa base de dados para o Para  possui processo para os anos de [2020 2021 2019 2022] e apenas processos que são classificados como ['S']"

# %%
#Agora, vamos pegar o dado que contem o LINK entre o numero do processo e a substancia alvo de mineração:
#Limpando ela um cadin
del processo_sub['Unnamed: 0']
processo_sub
# Out:
#            DSProcesso  IDSubstancia  IDTipoUsoSubstancia  \
# 0        811.050/2009        500102                   18
# 1        811.050/2010        701902                    9
# 2        811.050/2011        701902                   14
# 3        811.050/2012        701204                    1
# 4        811.050/2012        701400                    1
# ...               ...           ...                  ...
# 1078712  830.477/2005        200200                    1
# 1078713  830.477/2005        200600                    1
# 1078714  830.477/2005        200603                    1
# 1078715  830.477/2006        100100                   21
# 1078716  830.477/2007        706100                    7
#
#          IDMotivoEncerramentoSubstancia DTInicioVigencia DTFimVigencia  \
# 0                                   NaN       2009-11-18           NaN
# 1                                   NaN       2010-10-20           NaN
# 2                                   NaN       2011-09-06           NaN
# 3                                   NaN       2012-07-04           NaN
# 4                                   NaN       2012-07-04           NaN
# ...                                 ...              ...           ...
# 1078712                             NaN       2005-03-10           NaN
# 1078713                             NaN       2005-03-10           NaN
# 1078714                             NaN       2005-03-10           NaN
# 1078715                             NaN       2006-03-14           NaN
# 1078716                             NaN       2007-02-12           NaN
#
#                   Substancia Tipo_Uso_Substancia Motivo_Encerramento
# 0           ROCHA BETUMINOSA          Energético                 NaN
# 1                    BASALTO               Brita                 NaN
# 2                    BASALTO      Pedra de talhe                 NaN
# 3                    ARENITO    Construção civil                 NaN
# 4                     ARGILA    Construção civil                 NaN
# ...                      ...                 ...                 ...
# 1078712                AREIA    Construção civil                 NaN
# 1078713             CASCALHO    Construção civil                 NaN
# 1078714       SEIXOS ROLADOS    Construção civil                 NaN
# 1078715  MINÉRIO DE ALUMÍNIO          Industrial                 NaN
# 1078716              GRANITO        Revestimento                 NaN
#
# [1078717 rows x 9 columns]

# %%
#Apenas processos que contenham substancia OURO
ouro = processo_sub.query('Substancia.str.contains("OURO")',engine='python')
ouro
# Out:
#            DSProcesso  IDSubstancia  IDTipoUsoSubstancia  \
# 35       811.052/1973        104901                   99
# 61       811.053/1973        104901                   99
# 87       811.054/1973        104901                   99
# 112      811.055/1973        104901                   99
# 135      811.056/1973        104901                   99
# ...               ...           ...                  ...
# 1078642  830.476/1991        104901                   99
# 1078654  830.476/2002        104900                    3
# 1078681  830.476/2022        104900                   21
# 1078683  830.477/1979        104901                   99
# 1078697  830.477/1991        104901                   99
#
#          IDMotivoEncerramentoSubstancia DTInicioVigencia DTFimVigencia  \
# 35                                  NaN       1973-08-21           NaN
# 61                                  NaN       1973-08-21           NaN
# 87                                  NaN       1973-08-21           NaN
# 112                                 NaN       1973-08-21           NaN
# 135                                 NaN       1973-08-21           NaN
# ...                                 ...              ...           ...
# 1078642                             NaN       1991-04-12           NaN
# 1078654                            99.0       2002-03-19    2011-02-10
# 1078681                             0.0       2022-04-01           NaN
# 1078683                             NaN       1979-05-30           NaN
# 1078697                             NaN       1991-04-12           NaN
#
#               Substancia Tipo_Uso_Substancia  Motivo_Encerramento
# 35                  OURO       Não informado                  NaN
# 61                  OURO       Não informado                  NaN
# 87                  OURO       Não informado                  NaN
# 112                 OURO       Não informado                  NaN
# 135                 OURO       Não informado                  NaN
# ...                  ...                 ...                  ...
# 1078642             OURO       Não informado                  NaN
# 1078654  MINÉRIO DE OURO         Ourivesaria  Motivo desconhecido
# 1078681  MINÉRIO DE OURO          Industrial                  NaN
# 1078683             OURO       Não informado                  NaN
# 1078697             OURO       Não informado                  NaN
#
# [189995 rows x 9 columns]

# %%
#Vamos agora filtrar no dataframe dos processos ativos (2019 até 2022) para o Para quais deles sao para ouro, utilizando esse dataframe de ouro criado:
pd.set_option('display.max_columns', None)
para_ouro = processo_para_ativos.merge(ouro,on='DSProcesso',how='inner')
para_ouro
f'A base de processos para substâncias, após filtrarmos para ouro, nós temos como substâncias: {para_ouro["Substancia"].unique()}'
# Out:
# "A base de processos para substâncias, após filtrarmos para ouro, nós temos como substâncias: ['MINÉRIO DE OURO' 'OURO']"

# %%
#As substâncias de ouro são:'OURO' 'MINÉRIO DE OURO' 'OURO NATIVO' 'OURO PIGMENTO'. Por que que temos só MINÉRIO DE OURO E OURO quando fazemos esse filtro?

#Vamos entao, a titulo de exemplo, filtrar apenas processos que tem ouro pigmento:
exemplo = ouro.query('Substancia=="OURO PIGMENTO"')
#Agora, vamos filtrar esse processo de ouro pigmento NA BASE TODA, para ver qual regiao do brazil são esses processos:
a = processo.merge(mun,on='DSProcesso',how='inner')
b = a.merge(exemplo,on='DSProcesso',how='inner')
b = b[b['UF']=='PA']
#EXemplo para OURO NATIVO:
exemplo2 = ouro.query('Substancia=="OURO NATIVO"')
c = processo.merge(mun,on='DSProcesso',how='inner')
d = c.merge(exemplo2,on='DSProcesso',how='inner')
d=d[d['UF']=='PA']
f'Os processos no Para, que usam substancias Ouro Nativo são para o Ano {b["NRAnoProcesso"].unique()}e para Ouro Pigment são para o ano {d["NRAnoProcesso"].unique()}'
# Out:
# 'Os processos no Para, que usam substancias Ouro Nativo são para o Ano [2003 2005]e para Ouro Pigment são para o ano [2000 2003 2005 1996]'

# %%
#Agora nós sabemos porque só utilizam aquelas duas substancias. Elas são de processos que estão no nosso recorte temporal

# %%
#Vamos agora agrupar pelos diferentes Eventos:
evento
del evento['Unnamed: 0']

# %%
#Criando os filtros de evento
evento_333 = evento.query('IDEvento ==333')
evento_1402 =  evento.query('IDEvento ==1402')
evento_1403 = evento.query('IDEvento ==1403')
evento_513 = evento.query('IDEvento ==513')

# %%
#Vamos agora fazer evento 333 com 1402 e 513
#Primeiro: evento 333
para_ouro_333=para_ouro.merge(evento_333,on='DSProcesso',how='inner')
#Agora evento 333 com 1402
para_ouro_333_1402 = para_ouro_333.merge(evento_1402,on='DSProcesso',how='inner')
# Agora evento 333 com 1402 e 513
para_ouro_333_1402_513 = para_ouro_333_1402.merge(evento_513,on='DSProcesso',how='inner')
#Fazendo pequenas melhorias para a leitura das colunas serem mais faceis:
dicionario={
    'IDEvento_x':'IDEvento333',
    'DTEvento_x':'DataEvento333',
    'Evento__x':'Evento333',
    'IDEvento_y':'IDEvento1402',
    'DTEvento_y':'DataEvento1402',
    'Evento__y':'Evento1402',
    'IDEvento':'IDEvento513',
    'DTEvento':'DataEvento513',
    'Evento_':'Evento513'
    
}
para_ouro_333_1402_513.rename(columns=dicionario,
          inplace=True)
para_ouro_333_1402_513
# Out:
#        DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 0    850.002/2020      850002           2020       S  48059.850002/2020-55
# 1    850.004/2020      850004           2020       S  48059.850004/2020-44
# 2    850.015/2021      850015           2021       S  48059.850015/2021-13
# 3    850.019/2020      850019           2020       S  48059.850019/2020-11
# 4    850.022/2020      850022           2020       S  48059.850022/2020-26
# ..            ...         ...            ...     ...                   ...
# 286  851.591/2021      851591           2021       S  48059.851591/2021-70
# 287  851.646/2020      851646           2020       S  48059.851646/2020-61
# 288  851.646/2020      851646           2020       S  48059.851646/2020-61
# 289  850.992/2019      850992           2019       S  48059.850992/2019-98
# 290  850.992/2019      850992           2019       S  48059.850992/2019-98
#
#      IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 0                  24.0               6                                5
# 1                   2.0               6                                5
# 2                   2.0               6                                5
# 3                  24.0               6                                5
# 4                  24.0               6                                5
# ..                  ...             ...                              ...
# 286                 2.0               6                                5
# 287                24.0               6                                5
# 288                24.0               6                                5
# 289                 2.0               6                                5
# 290                 2.0               6                                5
#
#      IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 0                     48059.0  2020-01-02 16:27:00  2016-10-11 09:12:46
# 1                     48059.0  2020-01-03 10:30:00  2020-01-03 10:30:09
# 2                     48059.0  2021-01-07 08:31:00  2021-01-07 08:31:13
# 3                     48059.0  2020-01-15 12:32:00  2009-07-23 10:55:17
# 4                     48059.0  2020-01-15 16:02:00  2011-08-08 14:45:39
# ..                        ...                  ...                  ...
# 286                   48059.0  2021-11-08 08:43:00  2021-11-08 08:42:51
# 287                   48059.0  2020-12-31 11:02:00  2018-01-18 10:25:13
# 288                   48059.0  2020-12-31 11:02:00  2018-01-18 10:25:13
# 289                   48059.0  2019-12-17 09:09:00  2019-12-17 09:09:10
# 290                   48059.0  2019-12-17 09:09:00  2019-12-17 09:09:10
#
#     QTAreaHA                            Tipo_Requerimento     Fase_Processo  \
# 0      15,82  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 1      49,62             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2      32,01             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 3      50,00  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 4      70,74  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# ..       ...                                          ...               ...
# 286    50,00             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 287    46,07  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 288    46,07  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 289  3135,01             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 290  3135,01             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                  Unidade_ADM Unidade_Protocolizadora  IDMunicipio Municipios  \
# 0    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 1    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 2    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 3    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 4    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# ..                       ...                     ...          ...        ...
# 286  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 287  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 288  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 289  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 290  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
#
#      UF  IDSubstancia  IDTipoUsoSubstancia  IDMotivoEncerramentoSubstancia  \
# 0    PA        104900                   21                             0.0
# 1    PA        104900                   21                             0.0
# 2    PA        104900                   21                             0.0
# 3    PA        104900                   21                             0.0
# 4    PA        104900                   21                             0.0
# ..   ..           ...                  ...                             ...
# 286  PA        104900                   21                             0.0
# 287  PA        104900                   21                             0.0
# 288  PA        104900                   21                             0.0
# 289  PA        104900                   21                             0.0
# 290  PA        104900                   21                             0.0
#
#     DTInicioVigencia DTFimVigencia       Substancia Tipo_Uso_Substancia  \
# 0         2020-01-02           NaN  MINÉRIO DE OURO          Industrial
# 1         2020-01-03           NaN  MINÉRIO DE OURO          Industrial
# 2         2021-01-07           NaN  MINÉRIO DE OURO          Industrial
# 3         2020-01-15           NaN  MINÉRIO DE OURO          Industrial
# 4         2020-01-15           NaN  MINÉRIO DE OURO          Industrial
# ..               ...           ...              ...                 ...
# 286       2021-11-08           NaN  MINÉRIO DE OURO          Industrial
# 287       2020-12-31           NaN  MINÉRIO DE OURO          Industrial
# 288       2020-12-31           NaN  MINÉRIO DE OURO          Industrial
# 289       2019-12-17           NaN  MINÉRIO DE OURO          Industrial
# 290       2019-12-17           NaN  MINÉRIO DE OURO          Industrial
#
#     Motivo_Encerramento  IDEvento333 DataEvento333  \
# 0                   NaN          333    2020-01-02
# 1                   NaN          333    2020-01-03
# 2                   NaN          333    2021-01-07
# 3                   NaN          333    2020-01-15
# 4                   NaN          333    2020-01-15
# ..                  ...          ...           ...
# 286                 NaN          333    2021-11-08
# 287                 NaN          333    2020-12-31
# 288                 NaN          333    2020-12-31
# 289                 NaN          333    2019-12-17
# 290                 NaN          333    2019-12-17
#
#                                              Evento333  IDEvento1402  \
# 0    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 1    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 2    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 3    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 4    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# ..                                                 ...           ...
# 286  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 287  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 288  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 289  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 290  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
#
#     DataEvento1402                                Evento1402  IDEvento513  \
# 0       2020-03-27  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 1       2020-04-22  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 2       2021-01-21  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 3       2020-08-07  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 4       2020-02-18  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# ..             ...                                       ...          ...
# 286     2022-10-28  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 287     2021-06-24  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 288     2022-07-04  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 289     2020-04-27  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 290     2021-09-02  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
#
#     DataEvento513                             Evento513
# 0      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2      2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 3      2020-09-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 4      2020-08-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# ..            ...                                   ...
# 286    2022-11-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 287    2022-10-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 288    2022-10-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 289    2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 290    2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
#
# [291 rows x 36 columns]

# %%
#Vamos reter apenas os processos únicos. Nos já averiguamos em conversas passadas que um mesmo processo pode estar na mão de diferentes pessoas pois esses processos podem ser vendidos etc
para_ouro_333_1402_513.drop_duplicates(subset='DSProcesso',inplace=True)
para_ouro_333_1402_513
# Out:
#        DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 0    850.002/2020      850002           2020       S  48059.850002/2020-55
# 1    850.004/2020      850004           2020       S  48059.850004/2020-44
# 2    850.015/2021      850015           2021       S  48059.850015/2021-13
# 3    850.019/2020      850019           2020       S  48059.850019/2020-11
# 4    850.022/2020      850022           2020       S  48059.850022/2020-26
# ..            ...         ...            ...     ...                   ...
# 284  851.573/2020      851573           2020       S  48059.851573/2020-15
# 285  851.591/2020      851591           2020       S  48059.851591/2020-99
# 286  851.591/2021      851591           2021       S  48059.851591/2021-70
# 287  851.646/2020      851646           2020       S  48059.851646/2020-61
# 289  850.992/2019      850992           2019       S  48059.850992/2019-98
#
#      IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 0                  24.0               6                                5
# 1                   2.0               6                                5
# 2                   2.0               6                                5
# 3                  24.0               6                                5
# 4                  24.0               6                                5
# ..                  ...             ...                              ...
# 284                 2.0               6                                5
# 285                 2.0               6                                5
# 286                 2.0               6                                5
# 287                24.0               6                                5
# 289                 2.0               6                                5
#
#      IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 0                     48059.0  2020-01-02 16:27:00  2016-10-11 09:12:46
# 1                     48059.0  2020-01-03 10:30:00  2020-01-03 10:30:09
# 2                     48059.0  2021-01-07 08:31:00  2021-01-07 08:31:13
# 3                     48059.0  2020-01-15 12:32:00  2009-07-23 10:55:17
# 4                     48059.0  2020-01-15 16:02:00  2011-08-08 14:45:39
# ..                        ...                  ...                  ...
# 284                   48059.0  2020-12-10 16:25:00  2020-12-10 16:24:32
# 285                   48059.0  2020-12-17 10:37:00  2020-12-17 10:36:52
# 286                   48059.0  2021-11-08 08:43:00  2021-11-08 08:42:51
# 287                   48059.0  2020-12-31 11:02:00  2018-01-18 10:25:13
# 289                   48059.0  2019-12-17 09:09:00  2019-12-17 09:09:10
#
#     QTAreaHA                            Tipo_Requerimento     Fase_Processo  \
# 0      15,82  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 1      49,62             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2      32,01             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 3      50,00  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 4      70,74  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# ..       ...                                          ...               ...
# 284    49,89             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 285    49,81             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 286    50,00             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 287    46,07  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 289  3135,01             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                  Unidade_ADM Unidade_Protocolizadora  IDMunicipio Municipios  \
# 0    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 1    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 2    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 3    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 4    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# ..                       ...                     ...          ...        ...
# 284  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 285  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 286  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 287  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 289  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
#
#      UF  IDSubstancia  IDTipoUsoSubstancia  IDMotivoEncerramentoSubstancia  \
# 0    PA        104900                   21                             0.0
# 1    PA        104900                   21                             0.0
# 2    PA        104900                   21                             0.0
# 3    PA        104900                   21                             0.0
# 4    PA        104900                   21                             0.0
# ..   ..           ...                  ...                             ...
# 284  PA        104900                   21                             0.0
# 285  PA        104900                   21                             0.0
# 286  PA        104900                   21                             0.0
# 287  PA        104900                   21                             0.0
# 289  PA        104900                   21                             0.0
#
#     DTInicioVigencia DTFimVigencia       Substancia Tipo_Uso_Substancia  \
# 0         2020-01-02           NaN  MINÉRIO DE OURO          Industrial
# 1         2020-01-03           NaN  MINÉRIO DE OURO          Industrial
# 2         2021-01-07           NaN  MINÉRIO DE OURO          Industrial
# 3         2020-01-15           NaN  MINÉRIO DE OURO          Industrial
# 4         2020-01-15           NaN  MINÉRIO DE OURO          Industrial
# ..               ...           ...              ...                 ...
# 284       2020-12-10           NaN  MINÉRIO DE OURO          Industrial
# 285       2020-12-17           NaN  MINÉRIO DE OURO          Industrial
# 286       2021-11-08           NaN  MINÉRIO DE OURO          Industrial
# 287       2020-12-31           NaN  MINÉRIO DE OURO          Industrial
# 289       2019-12-17           NaN  MINÉRIO DE OURO          Industrial
#
#     Motivo_Encerramento  IDEvento333 DataEvento333  \
# 0                   NaN          333    2020-01-02
# 1                   NaN          333    2020-01-03
# 2                   NaN          333    2021-01-07
# 3                   NaN          333    2020-01-15
# 4                   NaN          333    2020-01-15
# ..                  ...          ...           ...
# 284                 NaN          333    2020-12-10
# 285                 NaN          333    2020-12-17
# 286                 NaN          333    2021-11-08
# 287                 NaN          333    2020-12-31
# 289                 NaN          333    2019-12-17
#
#                                              Evento333  IDEvento1402  \
# 0    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 1    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 2    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 3    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 4    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# ..                                                 ...           ...
# 284  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 285  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 286  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 287  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 289  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
#
#     DataEvento1402                                Evento1402  IDEvento513  \
# 0       2020-03-27  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 1       2020-04-22  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 2       2021-01-21  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 3       2020-08-07  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 4       2020-02-18  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# ..             ...                                       ...          ...
# 284     2022-07-13  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 285     2021-01-21  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 286     2022-10-28  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 287     2021-06-24  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 289     2020-04-27  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
#
#     DataEvento513                             Evento513
# 0      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2      2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 3      2020-09-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 4      2020-08-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# ..            ...                                   ...
# 284    2022-11-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 285    2021-03-05  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 286    2022-11-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 287    2022-10-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 289    2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
#
# [231 rows x 36 columns]

# %%
#Agora vamos fazer evento 333 com 1403 e 513
#Nós ja temos o dado de processos do para com substancia ouro e evento 333 : para_ouro_333
#Agora evento 333 com evento_1403
para_ouro_333_1403= para_ouro_333.merge(evento_1403,on='DSProcesso',how='inner')
#Agora evento 333 e 1403 com 513
para_ouro_333_1403_513 = para_ouro_333_1403.merge(evento_513,on='DSProcesso',how='inner')
para_ouro_333_1403_513

#Fazendo pequenas melhorias para a leitura das colunas serem mais faceis:
dicionario={
    'IDEvento_x':'IDEvento333',
    'DTEvento_x':'DataEvento333',
    'Evento__x':'Evento333',
    'IDEvento_y':'IDEvento1403',
    'DTEvento_y':'DataEvento1403',
    'Evento__y':'Evento1403',
    'IDEvento':'IDEvento513',
    'DTEvento':'DataEvento513',
    'Evento_':'Evento513'
    
}
para_ouro_333_1403_513.rename(columns=dicionario,
          inplace=True)
para_ouro_333_1403_513
# Out:
#        DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 0    850.002/2020      850002           2020       S  48059.850002/2020-55
# 1    850.002/2020      850002           2020       S  48059.850002/2020-55
# 2    850.002/2020      850002           2020       S  48059.850002/2020-55
# 3    850.004/2020      850004           2020       S  48059.850004/2020-44
# 4    850.019/2020      850019           2020       S  48059.850019/2020-11
# ..            ...         ...            ...     ...                   ...
# 96   851.038/2021      851038           2021       S  48059.851038/2021-37
# 97   851.044/2020      851044           2020       S  48059.851044/2020-11
# 98   851.045/2021      851045           2021       S  48059.851045/2021-39
# 99   851.332/2020      851332           2020       S  48059.851332/2020-68
# 100  851.332/2020      851332           2020       S  48059.851332/2020-68
#
#      IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 0                  24.0               6                                5
# 1                  24.0               6                                5
# 2                  24.0               6                                5
# 3                   2.0               6                                5
# 4                  24.0               6                                5
# ..                  ...             ...                              ...
# 96                  2.0               6                                5
# 97                  2.0               6                                5
# 98                  2.0               6                                5
# 99                  2.0               6                                5
# 100                 2.0               6                                5
#
#      IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 0                     48059.0  2020-01-02 16:27:00  2016-10-11 09:12:46
# 1                     48059.0  2020-01-02 16:27:00  2016-10-11 09:12:46
# 2                     48059.0  2020-01-02 16:27:00  2016-10-11 09:12:46
# 3                     48059.0  2020-01-03 10:30:00  2020-01-03 10:30:09
# 4                     48059.0  2020-01-15 12:32:00  2009-07-23 10:55:17
# ..                        ...                  ...                  ...
# 96                    48059.0  2021-06-21 11:24:00  2021-06-21 11:24:01
# 97                    48059.0  2020-08-26 09:48:00  2020-08-26 09:47:37
# 98                    48059.0  2021-06-22 11:03:00  2021-06-22 11:03:01
# 99                    48059.0  2020-10-23 16:50:00  2020-10-23 16:50:24
# 100                   48059.0  2020-10-23 16:50:00  2020-10-23 16:50:24
#
#     QTAreaHA                            Tipo_Requerimento     Fase_Processo  \
# 0      15,82  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 1      15,82  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 2      15,82  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 3      49,62             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 4      50,00  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# ..       ...                                          ...               ...
# 96     49,23             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 97      1,83             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 98     48,74             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 99     47,34             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 100    47,34             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                  Unidade_ADM Unidade_Protocolizadora  IDMunicipio Municipios  \
# 0    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 1    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 2    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 3    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 4    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# ..                       ...                     ...          ...        ...
# 96   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 97   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 98   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 99   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 100  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
#
#      UF  IDSubstancia  IDTipoUsoSubstancia  IDMotivoEncerramentoSubstancia  \
# 0    PA        104900                   21                             0.0
# 1    PA        104900                   21                             0.0
# 2    PA        104900                   21                             0.0
# 3    PA        104900                   21                             0.0
# 4    PA        104900                   21                             0.0
# ..   ..           ...                  ...                             ...
# 96   PA        104900                   21                             0.0
# 97   PA        104900                   21                             0.0
# 98   PA        104900                   21                             0.0
# 99   PA        104900                   21                             0.0
# 100  PA        104900                   21                             0.0
#
#     DTInicioVigencia DTFimVigencia       Substancia Tipo_Uso_Substancia  \
# 0         2020-01-02           NaN  MINÉRIO DE OURO          Industrial
# 1         2020-01-02           NaN  MINÉRIO DE OURO          Industrial
# 2         2020-01-02           NaN  MINÉRIO DE OURO          Industrial
# 3         2020-01-03           NaN  MINÉRIO DE OURO          Industrial
# 4         2020-01-15           NaN  MINÉRIO DE OURO          Industrial
# ..               ...           ...              ...                 ...
# 96        2021-06-21           NaN  MINÉRIO DE OURO          Industrial
# 97        2020-08-26           NaN  MINÉRIO DE OURO          Industrial
# 98        2021-06-22           NaN  MINÉRIO DE OURO          Industrial
# 99        2020-10-23           NaN  MINÉRIO DE OURO          Industrial
# 100       2020-10-23           NaN  MINÉRIO DE OURO          Industrial
#
#     Motivo_Encerramento  IDEvento333 DataEvento333  \
# 0                   NaN          333    2020-01-02
# 1                   NaN          333    2020-01-02
# 2                   NaN          333    2020-01-02
# 3                   NaN          333    2020-01-03
# 4                   NaN          333    2020-01-15
# ..                  ...          ...           ...
# 96                  NaN          333    2021-06-21
# 97                  NaN          333    2020-08-26
# 98                  NaN          333    2021-06-22
# 99                  NaN          333    2020-10-23
# 100                 NaN          333    2020-10-23
#
#                                              Evento333  IDEvento1403  \
# 0    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 1    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 2    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 3    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 4    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# ..                                                 ...           ...
# 96   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 97   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 98   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 99   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 100  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
#
#     DataEvento1403                            Evento1403  IDEvento513  \
# 0       2021-03-18  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 1       2022-01-31  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 2       2023-02-17  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 3       2021-04-22  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 4       2021-10-04  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# ..             ...                                   ...          ...
# 96      2023-02-16  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 97      2022-10-28  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 98      2023-02-16  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 99      2022-01-31  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 100     2022-03-29  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
#
#     DataEvento513                             Evento513
# 0      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 3      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 4      2020-09-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# ..            ...                                   ...
# 96     2022-02-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 97     2022-02-15  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 98     2022-02-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 99     2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 100    2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
#
# [101 rows x 36 columns]

# %%
#Vamos reter apenas os processos únicos. Nos já averiguamos em conversas passadas que um mesmo processo pode estar na mão de diferentes pessoas pois esses processos podem ser vendidos etc
para_ouro_333_1403_513.drop_duplicates(subset='DSProcesso',inplace=True)
para_ouro_333_1403_513
# Out:
#       DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 0   850.002/2020      850002           2020       S  48059.850002/2020-55
# 3   850.004/2020      850004           2020       S  48059.850004/2020-44
# 4   850.019/2020      850019           2020       S  48059.850019/2020-11
# 6   850.022/2020      850022           2020       S  48059.850022/2020-26
# 7   850.032/2020      850032           2020       S  48059.850032/2020-61
# ..           ...         ...            ...     ...                   ...
# 95  851.034/2020      851034           2020       S  48059.851034/2020-78
# 96  851.038/2021      851038           2021       S  48059.851038/2021-37
# 97  851.044/2020      851044           2020       S  48059.851044/2020-11
# 98  851.045/2021      851045           2021       S  48059.851045/2021-39
# 99  851.332/2020      851332           2020       S  48059.851332/2020-68
#
#     IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 0                 24.0               6                                5
# 3                  2.0               6                                5
# 4                 24.0               6                                5
# 6                 24.0               6                                5
# 7                  2.0               6                                5
# ..                 ...             ...                              ...
# 95                 2.0               6                                5
# 96                 2.0               6                                5
# 97                 2.0               6                                5
# 98                 2.0               6                                5
# 99                 2.0               6                                5
#
#     IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 0                    48059.0  2020-01-02 16:27:00  2016-10-11 09:12:46
# 3                    48059.0  2020-01-03 10:30:00  2020-01-03 10:30:09
# 4                    48059.0  2020-01-15 12:32:00  2009-07-23 10:55:17
# 6                    48059.0  2020-01-15 16:02:00  2011-08-08 14:45:39
# 7                    48059.0  2020-01-17 19:11:00  2020-01-17 19:11:11
# ..                       ...                  ...                  ...
# 95                   48059.0  2020-08-21 11:11:00  2020-08-21 11:11:12
# 96                   48059.0  2021-06-21 11:24:00  2021-06-21 11:24:01
# 97                   48059.0  2020-08-26 09:48:00  2020-08-26 09:47:37
# 98                   48059.0  2021-06-22 11:03:00  2021-06-22 11:03:01
# 99                   48059.0  2020-10-23 16:50:00  2020-10-23 16:50:24
#
#    QTAreaHA                            Tipo_Requerimento     Fase_Processo  \
# 0     15,82  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 3     49,62             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 4     50,00  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 6     70,74  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 7      1,35             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# ..      ...                                          ...               ...
# 95    50,00             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 96    49,23             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 97     1,83             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 98    48,74             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 99    47,34             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                 Unidade_ADM Unidade_Protocolizadora  IDMunicipio Municipios  \
# 0   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 3   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 4   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 6   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 7   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# ..                      ...                     ...          ...        ...
# 95  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 96  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 97  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 98  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 99  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
#
#     UF  IDSubstancia  IDTipoUsoSubstancia  IDMotivoEncerramentoSubstancia  \
# 0   PA        104900                   21                             0.0
# 3   PA        104900                   21                             0.0
# 4   PA        104900                   21                             0.0
# 6   PA        104900                   21                             0.0
# 7   PA        104900                   21                             0.0
# ..  ..           ...                  ...                             ...
# 95  PA        104900                   21                             0.0
# 96  PA        104900                   21                             0.0
# 97  PA        104900                   21                             0.0
# 98  PA        104900                   21                             0.0
# 99  PA        104900                   21                             0.0
#
#    DTInicioVigencia DTFimVigencia       Substancia Tipo_Uso_Substancia  \
# 0        2020-01-02           NaN  MINÉRIO DE OURO          Industrial
# 3        2020-01-03           NaN  MINÉRIO DE OURO          Industrial
# 4        2020-01-15           NaN  MINÉRIO DE OURO          Industrial
# 6        2020-01-15           NaN  MINÉRIO DE OURO          Industrial
# 7        2020-01-17           NaN  MINÉRIO DE OURO          Industrial
# ..              ...           ...              ...                 ...
# 95       2020-08-21           NaN  MINÉRIO DE OURO          Industrial
# 96       2021-06-21           NaN  MINÉRIO DE OURO          Industrial
# 97       2020-08-26           NaN  MINÉRIO DE OURO          Industrial
# 98       2021-06-22           NaN  MINÉRIO DE OURO          Industrial
# 99       2020-10-23           NaN  MINÉRIO DE OURO          Industrial
#
#    Motivo_Encerramento  IDEvento333 DataEvento333  \
# 0                  NaN          333    2020-01-02
# 3                  NaN          333    2020-01-03
# 4                  NaN          333    2020-01-15
# 6                  NaN          333    2020-01-15
# 7                  NaN          333    2020-01-17
# ..                 ...          ...           ...
# 95                 NaN          333    2020-08-21
# 96                 NaN          333    2021-06-21
# 97                 NaN          333    2020-08-26
# 98                 NaN          333    2021-06-22
# 99                 NaN          333    2020-10-23
#
#                                             Evento333  IDEvento1403  \
# 0   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 3   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 4   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 6   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 7   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# ..                                                ...           ...
# 95  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 96  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 97  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 98  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 99  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
#
#    DataEvento1403                            Evento1403  IDEvento513  \
# 0      2021-03-18  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 3      2021-04-22  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 4      2021-10-04  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 6      2021-04-19  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 7      2021-06-14  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# ..            ...                                   ...          ...
# 95     2022-10-28  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 96     2023-02-16  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 97     2022-10-28  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 98     2023-02-16  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 99     2022-01-31  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
#
#    DataEvento513                             Evento513
# 0     2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 3     2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 4     2020-09-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 6     2020-08-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 7     2020-06-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# ..           ...                                   ...
# 95    2021-06-30  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 96    2022-02-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 97    2022-02-15  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 98    2022-02-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 99    2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
#
# [83 rows x 36 columns]

# %% [markdown]
# #### No total, nos temos 231 processo na configuração: 333 > 1402>513 e 83 na configuração: 333>1403>513.
# ##### Vamos, agora, fazer um merge na nossa base de dados!!
# #### Com o inner join entre as bases que CONTEM OS PROCESSOS 333>1402 >513 com OS PROCESSOS 333>1403>513, nós vamos saber quais os processos são comuns em ambas as fases (1402 e 1403)
# # ![Alt text](https://tse1.mm.bing.net/th?id=OIP.O0rd3dTFoqDjpHLaEPuqDwHaEK&pid=Api&P=0 "a title")

# %%
para_ouro_1402_AND_1403 = para_ouro_333_1402_513.merge(para_ouro_333_1403_513,on='DSProcesso',how='inner')
#Eu vou criar agora uma coluna nova nesse dataframe que vai me indicar a combinação desse processo: No caso todos os valores para essas linhas serão 1402_1403 pois é a combinação dos eventos
para_ouro_1402_AND_1403['Combinação_Evento']='1402_1403'
para_ouro_1402_AND_1403
# Out:
#       DSProcesso  NRProcesso_x  NRAnoProcesso_x BTAtivo_x  \
# 0   850.002/2020        850002             2020         S
# 1   850.004/2020        850004             2020         S
# 2   850.019/2020        850019             2020         S
# 3   850.022/2020        850022             2020         S
# 4   850.032/2020        850032             2020         S
# ..           ...           ...              ...       ...
# 78  851.034/2020        851034             2020         S
# 79  851.038/2021        851038             2021         S
# 80  851.044/2020        851044             2020         S
# 81  851.045/2021        851045             2021         S
# 82  851.332/2020        851332             2020         S
#
#                  NRNUP_x  IDTipoRequerimento_x  IDFaseProcesso_x  \
# 0   48059.850002/2020-55                  24.0                 6
# 1   48059.850004/2020-44                   2.0                 6
# 2   48059.850019/2020-11                  24.0                 6
# 3   48059.850022/2020-26                  24.0                 6
# 4   48059.850032/2020-61                   2.0                 6
# ..                   ...                   ...               ...
# 78  48059.851034/2020-78                   2.0                 6
# 79  48059.851038/2021-37                   2.0                 6
# 80  48059.851044/2020-11                   2.0                 6
# 81  48059.851045/2021-39                   2.0                 6
# 82  48059.851332/2020-68                   2.0                 6
#
#     IDUnidadeAdministrativaRegional_x  IDUnidadeProtocolizadora_x  \
# 0                                   5                     48059.0
# 1                                   5                     48059.0
# 2                                   5                     48059.0
# 3                                   5                     48059.0
# 4                                   5                     48059.0
# ..                                ...                         ...
# 78                                  5                     48059.0
# 79                                  5                     48059.0
# 80                                  5                     48059.0
# 81                                  5                     48059.0
# 82                                  5                     48059.0
#
#           DTProtocolo_x       DTPrioridade_x QTAreaHA_x  \
# 0   2020-01-02 16:27:00  2016-10-11 09:12:46      15,82
# 1   2020-01-03 10:30:00  2020-01-03 10:30:09      49,62
# 2   2020-01-15 12:32:00  2009-07-23 10:55:17      50,00
# 3   2020-01-15 16:02:00  2011-08-08 14:45:39      70,74
# 4   2020-01-17 19:11:00  2020-01-17 19:11:11       1,35
# ..                  ...                  ...        ...
# 78  2020-08-21 11:11:00  2020-08-21 11:11:12      50,00
# 79  2021-06-21 11:24:00  2021-06-21 11:24:01      49,23
# 80  2020-08-26 09:48:00  2020-08-26 09:47:37       1,83
# 81  2021-06-22 11:03:00  2021-06-22 11:03:01      48,74
# 82  2020-10-23 16:50:00  2020-10-23 16:50:24      47,34
#
#                             Tipo_Requerimento_x   Fase_Processo_x  \
# 0   Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 1              Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2   Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 3   Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 4              Requerimento de Lavra Garimpeira  Lavra Garimpeira
# ..                                          ...               ...
# 78             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 79             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 80             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 81             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 82             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#               Unidade_ADM_x Unidade_Protocolizadora_x  IDMunicipio_x  \
# 0   GerÃªncia Regional / PA                     PARÃ        1503606
# 1   GerÃªncia Regional / PA                     PARÃ        1503606
# 2   GerÃªncia Regional / PA                     PARÃ        1503606
# 3   GerÃªncia Regional / PA                     PARÃ        1503606
# 4   GerÃªncia Regional / PA                     PARÃ        1503606
# ..                      ...                       ...            ...
# 78  GerÃªncia Regional / PA                     PARÃ        1503606
# 79  GerÃªncia Regional / PA                     PARÃ        1503606
# 80  GerÃªncia Regional / PA                     PARÃ        1503606
# 81  GerÃªncia Regional / PA                     PARÃ        1503606
# 82  GerÃªncia Regional / PA                     PARÃ        1503606
#
#    Municipios_x UF_x  IDSubstancia_x  IDTipoUsoSubstancia_x  \
# 0      ITAITUBA   PA          104900                     21
# 1      ITAITUBA   PA          104900                     21
# 2      ITAITUBA   PA          104900                     21
# 3      ITAITUBA   PA          104900                     21
# 4      ITAITUBA   PA          104900                     21
# ..          ...  ...             ...                    ...
# 78     ITAITUBA   PA          104900                     21
# 79     ITAITUBA   PA          104900                     21
# 80     ITAITUBA   PA          104900                     21
# 81     ITAITUBA   PA          104900                     21
# 82     ITAITUBA   PA          104900                     21
#
#     IDMotivoEncerramentoSubstancia_x DTInicioVigencia_x DTFimVigencia_x  \
# 0                                0.0         2020-01-02             NaN
# 1                                0.0         2020-01-03             NaN
# 2                                0.0         2020-01-15             NaN
# 3                                0.0         2020-01-15             NaN
# 4                                0.0         2020-01-17             NaN
# ..                               ...                ...             ...
# 78                               0.0         2020-08-21             NaN
# 79                               0.0         2021-06-21             NaN
# 80                               0.0         2020-08-26             NaN
# 81                               0.0         2021-06-22             NaN
# 82                               0.0         2020-10-23             NaN
#
#        Substancia_x Tipo_Uso_Substancia_x Motivo_Encerramento_x  \
# 0   MINÉRIO DE OURO            Industrial                   NaN
# 1   MINÉRIO DE OURO            Industrial                   NaN
# 2   MINÉRIO DE OURO            Industrial                   NaN
# 3   MINÉRIO DE OURO            Industrial                   NaN
# 4   MINÉRIO DE OURO            Industrial                   NaN
# ..              ...                   ...                   ...
# 78  MINÉRIO DE OURO            Industrial                   NaN
# 79  MINÉRIO DE OURO            Industrial                   NaN
# 80  MINÉRIO DE OURO            Industrial                   NaN
# 81  MINÉRIO DE OURO            Industrial                   NaN
# 82  MINÉRIO DE OURO            Industrial                   NaN
#
#     IDEvento333_x DataEvento333_x  \
# 0             333      2020-01-02
# 1             333      2020-01-03
# 2             333      2020-01-15
# 3             333      2020-01-15
# 4             333      2020-01-17
# ..            ...             ...
# 78            333      2020-08-21
# 79            333      2021-06-21
# 80            333      2020-08-26
# 81            333      2021-06-22
# 82            333      2020-10-23
#
#                                           Evento333_x  IDEvento1402  \
# 0   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 1   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 2   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 3   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 4   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# ..                                                ...           ...
# 78  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 79  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 80  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 81  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 82  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
#
#    DataEvento1402                                Evento1402  IDEvento513_x  \
# 0      2020-03-27  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 1      2020-04-22  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 2      2020-08-07  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 3      2020-02-18  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 4      2020-06-15  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# ..            ...                                       ...            ...
# 78     2021-06-14  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 79     2021-07-15  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 80     2021-04-19  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 81     2021-07-15  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 82     2021-01-15  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
#
#    DataEvento513_x                           Evento513_x  NRProcesso_y  \
# 0       2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        850002
# 1       2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        850004
# 2       2020-09-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        850019
# 3       2020-08-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        850022
# 4       2020-06-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        850032
# ..             ...                                   ...           ...
# 78      2021-06-30  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        851034
# 79      2022-02-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        851038
# 80      2022-02-15  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        851044
# 81      2022-02-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        851045
# 82      2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL        851332
#
#     NRAnoProcesso_y BTAtivo_y               NRNUP_y  IDTipoRequerimento_y  \
# 0              2020         S  48059.850002/2020-55                  24.0
# 1              2020         S  48059.850004/2020-44                   2.0
# 2              2020         S  48059.850019/2020-11                  24.0
# 3              2020         S  48059.850022/2020-26                  24.0
# 4              2020         S  48059.850032/2020-61                   2.0
# ..              ...       ...                   ...                   ...
# 78             2020         S  48059.851034/2020-78                   2.0
# 79             2021         S  48059.851038/2021-37                   2.0
# 80             2020         S  48059.851044/2020-11                   2.0
# 81             2021         S  48059.851045/2021-39                   2.0
# 82             2020         S  48059.851332/2020-68                   2.0
#
#     IDFaseProcesso_y  IDUnidadeAdministrativaRegional_y  \
# 0                  6                                  5
# 1                  6                                  5
# 2                  6                                  5
# 3                  6                                  5
# 4                  6                                  5
# ..               ...                                ...
# 78                 6                                  5
# 79                 6                                  5
# 80                 6                                  5
# 81                 6                                  5
# 82                 6                                  5
#
#     IDUnidadeProtocolizadora_y        DTProtocolo_y       DTPrioridade_y  \
# 0                      48059.0  2020-01-02 16:27:00  2016-10-11 09:12:46
# 1                      48059.0  2020-01-03 10:30:00  2020-01-03 10:30:09
# 2                      48059.0  2020-01-15 12:32:00  2009-07-23 10:55:17
# 3                      48059.0  2020-01-15 16:02:00  2011-08-08 14:45:39
# 4                      48059.0  2020-01-17 19:11:00  2020-01-17 19:11:11
# ..                         ...                  ...                  ...
# 78                     48059.0  2020-08-21 11:11:00  2020-08-21 11:11:12
# 79                     48059.0  2021-06-21 11:24:00  2021-06-21 11:24:01
# 80                     48059.0  2020-08-26 09:48:00  2020-08-26 09:47:37
# 81                     48059.0  2021-06-22 11:03:00  2021-06-22 11:03:01
# 82                     48059.0  2020-10-23 16:50:00  2020-10-23 16:50:24
#
#    QTAreaHA_y                          Tipo_Requerimento_y   Fase_Processo_y  \
# 0       15,82  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 1       49,62             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2       50,00  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 3       70,74  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 4        1,35             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# ..        ...                                          ...               ...
# 78      50,00             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 79      49,23             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 80       1,83             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 81      48,74             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 82      47,34             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#               Unidade_ADM_y Unidade_Protocolizadora_y  IDMunicipio_y  \
# 0   GerÃªncia Regional / PA                     PARÃ        1503606
# 1   GerÃªncia Regional / PA                     PARÃ        1503606
# 2   GerÃªncia Regional / PA                     PARÃ        1503606
# 3   GerÃªncia Regional / PA                     PARÃ        1503606
# 4   GerÃªncia Regional / PA                     PARÃ        1503606
# ..                      ...                       ...            ...
# 78  GerÃªncia Regional / PA                     PARÃ        1503606
# 79  GerÃªncia Regional / PA                     PARÃ        1503606
# 80  GerÃªncia Regional / PA                     PARÃ        1503606
# 81  GerÃªncia Regional / PA                     PARÃ        1503606
# 82  GerÃªncia Regional / PA                     PARÃ        1503606
#
#    Municipios_y UF_y  IDSubstancia_y  IDTipoUsoSubstancia_y  \
# 0      ITAITUBA   PA          104900                     21
# 1      ITAITUBA   PA          104900                     21
# 2      ITAITUBA   PA          104900                     21
# 3      ITAITUBA   PA          104900                     21
# 4      ITAITUBA   PA          104900                     21
# ..          ...  ...             ...                    ...
# 78     ITAITUBA   PA          104900                     21
# 79     ITAITUBA   PA          104900                     21
# 80     ITAITUBA   PA          104900                     21
# 81     ITAITUBA   PA          104900                     21
# 82     ITAITUBA   PA          104900                     21
#
#     IDMotivoEncerramentoSubstancia_y DTInicioVigencia_y DTFimVigencia_y  \
# 0                                0.0         2020-01-02             NaN
# 1                                0.0         2020-01-03             NaN
# 2                                0.0         2020-01-15             NaN
# 3                                0.0         2020-01-15             NaN
# 4                                0.0         2020-01-17             NaN
# ..                               ...                ...             ...
# 78                               0.0         2020-08-21             NaN
# 79                               0.0         2021-06-21             NaN
# 80                               0.0         2020-08-26             NaN
# 81                               0.0         2021-06-22             NaN
# 82                               0.0         2020-10-23             NaN
#
#        Substancia_y Tipo_Uso_Substancia_y Motivo_Encerramento_y  \
# 0   MINÉRIO DE OURO            Industrial                   NaN
# 1   MINÉRIO DE OURO            Industrial                   NaN
# 2   MINÉRIO DE OURO            Industrial                   NaN
# 3   MINÉRIO DE OURO            Industrial                   NaN
# 4   MINÉRIO DE OURO            Industrial                   NaN
# ..              ...                   ...                   ...
# 78  MINÉRIO DE OURO            Industrial                   NaN
# 79  MINÉRIO DE OURO            Industrial                   NaN
# 80  MINÉRIO DE OURO            Industrial                   NaN
# 81  MINÉRIO DE OURO            Industrial                   NaN
# 82  MINÉRIO DE OURO            Industrial                   NaN
#
#     IDEvento333_y DataEvento333_y  \
# 0             333      2020-01-02
# 1             333      2020-01-03
# 2             333      2020-01-15
# 3             333      2020-01-15
# 4             333      2020-01-17
# ..            ...             ...
# 78            333      2020-08-21
# 79            333      2021-06-21
# 80            333      2020-08-26
# 81            333      2021-06-22
# 82            333      2020-10-23
#
#                                           Evento333_y  IDEvento1403  \
# 0   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 1   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 2   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 3   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 4   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# ..                                                ...           ...
# 78  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 79  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 80  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 81  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
# 82  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1403
#
#    DataEvento1403                            Evento1403  IDEvento513_y  \
# 0      2021-03-18  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 1      2021-04-22  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 2      2021-10-04  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 3      2021-04-19  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 4      2021-06-14  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# ..            ...                                   ...            ...
# 78     2022-10-28  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 79     2023-02-16  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 80     2022-10-28  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 81     2023-02-16  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
# 82     2022-01-31  PLG/LICENÃA AMBIENTAL PROTOCOLIZADA            513
#
#    DataEvento513_y                           Evento513_y Combinação_Evento
# 0       2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# 1       2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# 2       2020-09-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# 3       2020-08-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# 4       2020-06-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# ..             ...                                   ...               ...
# 78      2021-06-30  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# 79      2022-02-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# 80      2022-02-15  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# 81      2022-02-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
# 82      2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL         1402_1403
#
# [83 rows x 72 columns]

# %%
#Agora eu vou fazer o seguinte:
#Sabendo quais são os processos que temos EM COMUM com os dois eventos (1402 e 1403), vou criar um novo dataframe para os processos que são apenas 1402. Ou seja, foram de 333 para 1402 direto para 513.
#Sem passar pelo 1403 (obvio que ele poderia ter passado por outros eventos de processo. Obvio tbm que não existe uma ordem (não necessáriamente 0 evento 1402 vem antes do 1403) mas necessariamente,
#Nessa operação nós vamos reter apenas os processos que não tem relação com os processos que tem 1403 como evento
para_1402_Only = para_ouro_333_1402_513[~para_ouro_333_1402_513['DSProcesso'].isin(para_ouro_1402_AND_1403['DSProcesso'])]
para_1402_Only
#Checando duplicidade:
para_1402_Only[para_1402_Only['DSProcesso'].duplicated()] # Zero registros encontrados!!

#OK! Agora vamos criar a mesma coluna de combinação de eventos mas dessa vez tera so o valor 1402
para_1402_Only['Combinação_Evento']='1402'
para_1402_Only
# Out:
# C:\Users\napcc\AppData\Local\Temp\ipykernel_15216\2901799345.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   para_1402_Only['Combinação_Evento']='1402'
#        DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 2    850.015/2021      850015           2021       S  48059.850015/2021-13
# 5    850.023/2019      850023           2019       S  48405.850023/2019-50
# 9    850.041/2021      850041           2021       S  48059.850041/2021-33
# 10   850.041/2022      850041           2022       S  48059.850041/2022-14
# 11   850.044/2021      850044           2021       S  48059.850044/2021-77
# ..            ...         ...            ...     ...                   ...
# 284  851.573/2020      851573           2020       S  48059.851573/2020-15
# 285  851.591/2020      851591           2020       S  48059.851591/2020-99
# 286  851.591/2021      851591           2021       S  48059.851591/2021-70
# 287  851.646/2020      851646           2020       S  48059.851646/2020-61
# 289  850.992/2019      850992           2019       S  48059.850992/2019-98
#
#      IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 2                   2.0               6                                5
# 5                   2.0               6                                5
# 9                  24.0               6                                5
# 10                  2.0               6                                5
# 11                 24.0               6                                5
# ..                  ...             ...                              ...
# 284                 2.0               6                                5
# 285                 2.0               6                                5
# 286                 2.0               6                                5
# 287                24.0               6                                5
# 289                 2.0               6                                5
#
#      IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 2                     48059.0  2021-01-07 08:31:00  2021-01-07 08:31:13
# 5                     48405.0  2019-01-09 17:58:00  2019-01-09 17:57:33
# 9                     48059.0  2021-01-16 16:17:00  2019-01-28 16:46:41
# 10                    48059.0  2022-01-14 10:09:00  2022-01-14 10:08:43
# 11                    48059.0  2021-01-18 17:26:00  2019-01-28 16:46:41
# ..                        ...                  ...                  ...
# 284                   48059.0  2020-12-10 16:25:00  2020-12-10 16:24:32
# 285                   48059.0  2020-12-17 10:37:00  2020-12-17 10:36:52
# 286                   48059.0  2021-11-08 08:43:00  2021-11-08 08:42:51
# 287                   48059.0  2020-12-31 11:02:00  2018-01-18 10:25:13
# 289                   48059.0  2019-12-17 09:09:00  2019-12-17 09:09:10
#
#     QTAreaHA                            Tipo_Requerimento     Fase_Processo  \
# 2      32,01             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 5      48,80             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 9     339,22  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 10    499,99             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 11    327,11  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# ..       ...                                          ...               ...
# 284    49,89             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 285    49,81             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 286    50,00             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 287    46,07  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 289  3135,01             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                  Unidade_ADM Unidade_Protocolizadora  IDMunicipio Municipios  \
# 2    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 5    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 9    GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 10   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 11   GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# ..                       ...                     ...          ...        ...
# 284  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 285  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 286  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 287  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
# 289  GerÃªncia Regional / PA                   PARÃ      1503606   ITAITUBA
#
#      UF  IDSubstancia  IDTipoUsoSubstancia  IDMotivoEncerramentoSubstancia  \
# 2    PA        104900                   21                             0.0
# 5    PA        104900                   21                             NaN
# 9    PA        104900                   21                             0.0
# 10   PA        104900                   21                             0.0
# 11   PA        104900                   21                             0.0
# ..   ..           ...                  ...                             ...
# 284  PA        104900                   21                             0.0
# 285  PA        104900                   21                             0.0
# 286  PA        104900                   21                             0.0
# 287  PA        104900                   21                             0.0
# 289  PA        104900                   21                             0.0
#
#     DTInicioVigencia DTFimVigencia       Substancia Tipo_Uso_Substancia  \
# 2         2021-01-07           NaN  MINÉRIO DE OURO          Industrial
# 5         2019-01-09           NaN  MINÉRIO DE OURO          Industrial
# 9         2021-01-16           NaN  MINÉRIO DE OURO          Industrial
# 10        2022-01-14           NaN  MINÉRIO DE OURO          Industrial
# 11        2021-01-18           NaN  MINÉRIO DE OURO          Industrial
# ..               ...           ...              ...                 ...
# 284       2020-12-10           NaN  MINÉRIO DE OURO          Industrial
# 285       2020-12-17           NaN  MINÉRIO DE OURO          Industrial
# 286       2021-11-08           NaN  MINÉRIO DE OURO          Industrial
# 287       2020-12-31           NaN  MINÉRIO DE OURO          Industrial
# 289       2019-12-17           NaN  MINÉRIO DE OURO          Industrial
#
#     Motivo_Encerramento  IDEvento333 DataEvento333  \
# 2                   NaN          333    2021-01-07
# 5                   NaN          333    2019-01-09
# 9                   NaN          333    2021-01-16
# 10                  NaN          333    2022-01-14
# 11                  NaN          333    2021-01-18
# ..                  ...          ...           ...
# 284                 NaN          333    2020-12-10
# 285                 NaN          333    2020-12-17
# 286                 NaN          333    2021-11-08
# 287                 NaN          333    2020-12-31
# 289                 NaN          333    2019-12-17
#
#                                              Evento333  IDEvento1402  \
# 2    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 5    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 9    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 10   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 11   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# ..                                                 ...           ...
# 284  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 285  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 286  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 287  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
# 289  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...          1402
#
#     DataEvento1402                                Evento1402  IDEvento513  \
# 2       2021-01-21  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 5       2020-07-30  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 9       2022-03-31  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 10      2022-11-18  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 11      2022-03-31  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# ..             ...                                       ...          ...
# 284     2022-07-13  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 285     2021-01-21  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 286     2022-10-28  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 287     2021-06-24  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
# 289     2020-04-27  REQ PLG/LICENÃA AMBIENTAL PROTOCOLIZADA          513
#
#     DataEvento513                             Evento513 Combinação_Evento
# 2      2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# 5      2021-02-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# 9      2022-05-11  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# 10     2023-02-13  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# 11     2022-05-11  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# ..            ...                                   ...               ...
# 284    2022-11-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# 285    2021-03-05  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# 286    2022-11-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# 287    2022-10-07  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
# 289    2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL              1402
#
# [148 rows x 37 columns]

# %%
#Agora eu vou fazer o seguinte:
#Sabendo quais são os processos que temos EM COMUM com os dois eventos (1402 e 1403), vou criar um novo dataframe para os processos que são apenas 1403. Ou seja, foram de 333 para 1403 direto para 513.
#Sem passar pelo 1402 (obvio que ele poderia ter passado por outros eventos de processo. Obvio tbm que não existe uma ordem (não necessáriamente 0 evento 1402 vem antes do 1403) mas necessariamente,
#Nessa operação nós vamos reter apenas os processos que não tem relação com os processos que tem 1402 como evento
para_1403_Only = para_ouro_333_1403_513[~para_ouro_333_1403_513['DSProcesso'].isin(para_ouro_1402_AND_1403['DSProcesso'])]
para_1403_Only
#Checando duplicidade:
para_1403_Only[para_1403_Only['DSProcesso'].duplicated()] # Zero registros encontrados!!

#OK! Agora vamos criar a mesma coluna de combinação de eventos mas dessa vez tera so o valor 1402
para_1403_Only['Combinação_Evento']='1403'
para_1403_Only
# Out:
# Empty DataFrame
# Columns: [DSProcesso, NRProcesso, NRAnoProcesso, BTAtivo, NRNUP, IDTipoRequerimento, IDFaseProcesso, IDUnidadeAdministrativaRegional, IDUnidadeProtocolizadora, DTProtocolo, DTPrioridade, QTAreaHA, Tipo_Requerimento, Fase_Processo, Unidade_ADM, Unidade_Protocolizadora, IDMunicipio, Municipios, UF, IDSubstancia, IDTipoUsoSubstancia, IDMotivoEncerramentoSubstancia, DTInicioVigencia, DTFimVigencia, Substancia, Tipo_Uso_Substancia, Motivo_Encerramento, IDEvento333, DataEvento333, Evento333, IDEvento1403, DataEvento1403, Evento1403, IDEvento513, DataEvento513, Evento513, Combinação_Evento]
# Index: []

# %% [markdown]
# ##### Não há nenhum processo que foi de 333 para 1403 para 513. Todos ou foram de 333 1402 para 513 ou 333 1402 1403 para 513
#
# ##### Agora vamos unir esses dois dataframes:
# ##### A uniao vai ser um pouco complicada. Primeiro temos que reter apenas colunas relevantes para os dois dados. Como vai ser por concatenação, todos os dataframes precisam ter o mesmo numero de colunas
# ##### E com o mesmo nome

# %%
#Limpando colunas para o 1402 AND 1403
para_ouro_1402_AND_1403.columns
columns_keep_1402_AND_1403 = ['DSProcesso','NRAnoProcesso_x','QTAreaHA_x','Tipo_Requerimento_x','Fase_Processo_x','Municipios_x','Substancia_x','DataEvento333_x','DataEvento1402','DataEvento513_x',
                              'DataEvento1403','Combinação_Evento']
para_ouro_1402_AND_1403_clean = para_ouro_1402_AND_1403[columns_keep_1402_AND_1403]
para_ouro_1402_AND_1403_clean
# Out:
#       DSProcesso  NRAnoProcesso_x QTAreaHA_x  \
# 0   850.002/2020             2020      15,82
# 1   850.004/2020             2020      49,62
# 2   850.019/2020             2020      50,00
# 3   850.022/2020             2020      70,74
# 4   850.032/2020             2020       1,35
# ..           ...              ...        ...
# 78  851.034/2020             2020      50,00
# 79  851.038/2021             2021      49,23
# 80  851.044/2020             2020       1,83
# 81  851.045/2021             2021      48,74
# 82  851.332/2020             2020      47,34
#
#                             Tipo_Requerimento_x   Fase_Processo_x  \
# 0   Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 1              Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2   Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 3   Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 4              Requerimento de Lavra Garimpeira  Lavra Garimpeira
# ..                                          ...               ...
# 78             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 79             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 80             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 81             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 82             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#    Municipios_x     Substancia_x DataEvento333_x DataEvento1402  \
# 0      ITAITUBA  MINÉRIO DE OURO      2020-01-02     2020-03-27
# 1      ITAITUBA  MINÉRIO DE OURO      2020-01-03     2020-04-22
# 2      ITAITUBA  MINÉRIO DE OURO      2020-01-15     2020-08-07
# 3      ITAITUBA  MINÉRIO DE OURO      2020-01-15     2020-02-18
# 4      ITAITUBA  MINÉRIO DE OURO      2020-01-17     2020-06-15
# ..          ...              ...             ...            ...
# 78     ITAITUBA  MINÉRIO DE OURO      2020-08-21     2021-06-14
# 79     ITAITUBA  MINÉRIO DE OURO      2021-06-21     2021-07-15
# 80     ITAITUBA  MINÉRIO DE OURO      2020-08-26     2021-04-19
# 81     ITAITUBA  MINÉRIO DE OURO      2021-06-22     2021-07-15
# 82     ITAITUBA  MINÉRIO DE OURO      2020-10-23     2021-01-15
#
#    DataEvento513_x DataEvento1403 Combinação_Evento
# 0       2020-05-29     2021-03-18         1402_1403
# 1       2020-05-29     2021-04-22         1402_1403
# 2       2020-09-03     2021-10-04         1402_1403
# 3       2020-08-07     2021-04-19         1402_1403
# 4       2020-06-26     2021-06-14         1402_1403
# ..             ...            ...               ...
# 78      2021-06-30     2022-10-28         1402_1403
# 79      2022-02-03     2023-02-16         1402_1403
# 80      2022-02-15     2022-10-28         1402_1403
# 81      2022-02-03     2023-02-16         1402_1403
# 82      2021-02-26     2022-01-31         1402_1403
#
# [83 rows x 12 columns]

# %%
#Limpando colunas para o 1402 ONLY
columns_keep_1402=['DSProcesso','NRAnoProcesso','QTAreaHA','Tipo_Requerimento','Fase_Processo','Municipios','Substancia','DataEvento333','DataEvento1402','DataEvento513','Combinação_Evento']
para_1402_Only_clean=para_1402_Only[columns_keep_1402]
para_1402_Only_clean
# Out:
#        DSProcesso  NRAnoProcesso QTAreaHA  \
# 2    850.015/2021           2021    32,01
# 5    850.023/2019           2019    48,80
# 9    850.041/2021           2021   339,22
# 10   850.041/2022           2022   499,99
# 11   850.044/2021           2021   327,11
# ..            ...            ...      ...
# 284  851.573/2020           2020    49,89
# 285  851.591/2020           2020    49,81
# 286  851.591/2021           2021    50,00
# 287  851.646/2020           2020    46,07
# 289  850.992/2019           2019  3135,01
#
#                                Tipo_Requerimento     Fase_Processo Municipios  \
# 2               Requerimento de Lavra Garimpeira  Lavra Garimpeira   ITAITUBA
# 5               Requerimento de Lavra Garimpeira  Lavra Garimpeira   ITAITUBA
# 9    Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira   ITAITUBA
# 10              Requerimento de Lavra Garimpeira  Lavra Garimpeira   ITAITUBA
# 11   Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira   ITAITUBA
# ..                                           ...               ...        ...
# 284             Requerimento de Lavra Garimpeira  Lavra Garimpeira   ITAITUBA
# 285             Requerimento de Lavra Garimpeira  Lavra Garimpeira   ITAITUBA
# 286             Requerimento de Lavra Garimpeira  Lavra Garimpeira   ITAITUBA
# 287  Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira   ITAITUBA
# 289             Requerimento de Lavra Garimpeira  Lavra Garimpeira   ITAITUBA
#
#           Substancia DataEvento333 DataEvento1402 DataEvento513  \
# 2    MINÉRIO DE OURO    2021-01-07     2021-01-21    2021-02-26
# 5    MINÉRIO DE OURO    2019-01-09     2020-07-30    2021-02-26
# 9    MINÉRIO DE OURO    2021-01-16     2022-03-31    2022-05-11
# 10   MINÉRIO DE OURO    2022-01-14     2022-11-18    2023-02-13
# 11   MINÉRIO DE OURO    2021-01-18     2022-03-31    2022-05-11
# ..               ...           ...            ...           ...
# 284  MINÉRIO DE OURO    2020-12-10     2022-07-13    2022-11-25
# 285  MINÉRIO DE OURO    2020-12-17     2021-01-21    2021-03-05
# 286  MINÉRIO DE OURO    2021-11-08     2022-10-28    2022-11-25
# 287  MINÉRIO DE OURO    2020-12-31     2021-06-24    2022-10-07
# 289  MINÉRIO DE OURO    2019-12-17     2020-04-27    2021-11-29
#
#     Combinação_Evento
# 2                1402
# 5                1402
# 9                1402
# 10               1402
# 11               1402
# ..                ...
# 284              1402
# 285              1402
# 286              1402
# 287              1402
# 289              1402
#
# [148 rows x 11 columns]

# %%
#podemos perceber que os nomes das colunas não sao iguais. Vamos Alterar isso!
#Alem disso, pro dataframe para_1402_Only_clean vamos criar uma coluna chamada DataEvento1403 e alimentar ela com as palavras NÃO APLICAVEL. A coluna DataEvento1403 com valor NÃO APLICÁVEL é justamente
# a informação que diz que aquele processo não passou pelo evento 1403
para_1402_Only_clean['DataEvento1403']='NÃO APLICAVEL'
dict_rename={'NRAnoProcesso_x':'NRAnoProcesso','QTAreaHA_x':'QTAreaHA','Tipo_Requerimento_x':'Tipo_Requerimento','Fase_Processo_x':'Fase_Processo','Municipios_x':'Municipios',
             'Substancia_x':'Substancia','DataEvento333_x':'DataEvento333','DataEvento513_x':'DataEvento513'}
para_ouro_1402_AND_1403_clean.rename(columns = dict_rename, inplace = True)
# Out:
# C:\Users\napcc\AppData\Local\Temp\ipykernel_15216\924869605.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   para_1402_Only_clean['DataEvento1403']='NÃO APLICAVEL'
# C:\Users\napcc\AppData\Local\Temp\ipykernel_15216\924869605.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   para_ouro_1402_AND_1403_clean.rename(columns = dict_rename, inplace = True)

# %%
#Beleza, agora vamos fazer a uniao!
c = pd.concat([para_1402_Only_clean, para_ouro_1402_AND_1403_clean])
#Checando para processos repetidos, just in case!
c[c['DSProcesso'].duplicated()]
#Zero processos
# Out:
# Empty DataFrame
# Columns: [DSProcesso, NRAnoProcesso, QTAreaHA, Tipo_Requerimento, Fase_Processo, Municipios, Substancia, DataEvento333, DataEvento1402, DataEvento513, Combinação_Evento, DataEvento1403]
# Index: []

# %%
#Antes de analisar a distribuição dos valores de área, vamos unir com o tipo de pessoa!
#queremos pessoa fisica e juridica!
processos_link_pessoas = c.merge(pessoa,on='DSProcesso',how='inner')
#Como mais de uma pessoa / empresa tem o mesmo nmro de processo, eu vou primeiro separar os processos de pessoa fisica de pj
pj = processos_link_pessoas.query('Pessoa=="J"')
pj
pf = processos_link_pessoas.query('Pessoa=="F"')
pj
# Out:
#        DSProcesso  NRAnoProcesso QTAreaHA  \
# 8    850.041/2021           2021   339,22
# 9    850.041/2021           2021   339,22
# 11   850.041/2022           2022   499,99
# 12   850.041/2022           2022   499,99
# 14   850.044/2021           2021   327,11
# ..            ...            ...      ...
# 701  850.790/2019           2019    48,54
# 703  850.790/2019           2019    48,54
# 719  851.027/2020           2020    24,73
# 728  851.044/2020           2020     1,83
# 736  851.332/2020           2020    47,34
#
#                                Tipo_Requerimento     Fase_Processo  \
# 8    Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 9    Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# 11              Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 12              Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 14   Requerimento de MudanÃ§a de Regime para PLG  Lavra Garimpeira
# ..                                           ...               ...
# 701             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 703             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 719             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 728             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 736             Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                Municipios       Substancia DataEvento333 DataEvento1402  \
# 8                ITAITUBA  MINÉRIO DE OURO    2021-01-16     2022-03-31
# 9                ITAITUBA  MINÉRIO DE OURO    2021-01-16     2022-03-31
# 11               ITAITUBA  MINÉRIO DE OURO    2022-01-14     2022-11-18
# 12               ITAITUBA  MINÉRIO DE OURO    2022-01-14     2022-11-18
# 14               ITAITUBA  MINÉRIO DE OURO    2021-01-18     2022-03-31
# ..                    ...              ...           ...            ...
# 701  SÃO FÃLIX DO XINGU  MINÉRIO DE OURO    2019-10-22     2019-12-06
# 703  SÃO FÃLIX DO XINGU  MINÉRIO DE OURO    2019-10-22     2019-12-06
# 719              ITAITUBA  MINÉRIO DE OURO    2020-08-20     2021-04-19
# 728              ITAITUBA  MINÉRIO DE OURO    2020-08-26     2021-04-19
# 736              ITAITUBA  MINÉRIO DE OURO    2020-10-23     2021-01-15
#
#     DataEvento513 Combinação_Evento DataEvento1403  Unnamed: 0  IDPessoa  \
# 8      2022-05-11              1402  NÃO APLICAVEL     1066441   9000840
# 9      2022-05-11              1402  NÃO APLICAVEL     1066442   9000840
# 11     2023-02-13              1402  NÃO APLICAVEL     1066444   9024526
# 12     2023-02-13              1402  NÃO APLICAVEL     1066445   9024526
# 14     2022-05-11              1402  NÃO APLICAVEL     1066770   9000840
# ..            ...               ...            ...         ...       ...
# 701    2020-02-07         1402_1403     2020-12-21     1142450   9041138
# 703    2020-02-07         1402_1403     2020-12-21     2152642   9023779
# 719    2022-02-15         1402_1403     2022-10-28     1159423   8966974
# 728    2022-02-15         1402_1403     2022-10-28     1160495   8966974
# 736    2021-02-26         1402_1403     2022-01-31     1174963   9032753
#
#      IDTipoRelacao  IDTipoResponsabilidadeTecnica  IDTipoRepresentacaoLegal  \
# 8                1                            0.0                       NaN
# 9                4                            0.0                       NaN
# 11               1                            0.0                       NaN
# 12               4                            0.0                       NaN
# 14               1                            0.0                       NaN
# ..             ...                            ...                       ...
# 701              1                            NaN                       NaN
# 703              1                            NaN                       NaN
# 719              1                            0.0                       NaN
# 728              1                            0.0                       NaN
# 736              1                            NaN                       NaN
#
#     DTPrazoArrendamento DTInicioVigencia DTFimVigencia Pessoa  \
# 8                   NaN       2021-01-16           NaN      J
# 9                   NaN       2021-01-16           NaN      J
# 11                  NaN       2022-01-14           NaN      J
# 12                  NaN       2022-01-14           NaN      J
# 14                  NaN       2021-01-18           NaN      J
# ..                  ...              ...           ...    ...
# 701                 NaN       2022-11-23           NaN      J
# 703                 NaN       2020-10-06    2022-11-22      J
# 719                 NaN       2020-08-20           NaN      J
# 728                 NaN       2020-08-26           NaN      J
# 736                 NaN       2022-05-04           NaN      J
#
#                                            Pessoa_NOME          TipoRelacao  \
# 8    COOPERATIVA DE EXTRACAO MINERAL DE NOSSA SENHO...   Titular\Requerente
# 9    COOPERATIVA DE EXTRACAO MINERAL DE NOSSA SENHO...  Representante Legal
# 11    OURO NORTE COOPERATIVA DO GARIMPEIRO LEGAL - CGL   Titular\Requerente
# 12    OURO NORTE COOPERATIVA DO GARIMPEIRO LEGAL - CGL  Representante Legal
# 14   COOPERATIVA DE EXTRACAO MINERAL DE NOSSA SENHO...   Titular\Requerente
# ..                                                 ...                  ...
# 701      WESLEI DE SOUSA GONCALVES SCORPION MINERADORA   Titular\Requerente
# 703  COOPERATIVA DE GARIMPEIROS E MINERADORES SUSTENTA   Titular\Requerente
# 719  COOPERATIVA MISTA DE DESENVOLVIMENTO DO CREPUR...   Titular\Requerente
# 728  COOPERATIVA MISTA DE DESENVOLVIMENTO DO CREPUR...   Titular\Requerente
# 736  COOPERATIVA DOS GARIMPEIROS DO SUDOESTE DO PAR...   Titular\Requerente
#
#     Responsa_tecnica Representacao_Legal
# 8                NaN                 NaN
# 9                NaN                 NaN
# 11               NaN                 NaN
# 12               NaN                 NaN
# 14               NaN                 NaN
# ..               ...                 ...
# 701              NaN                 NaN
# 703              NaN                 NaN
# 719              NaN                 NaN
# 728              NaN                 NaN
# 736              NaN                 NaN
#
# [114 rows x 25 columns]

# %%
#Agora eu vou reter apenas processos únicos das duas bases e por fim uni-las novamente:
#624 processos para pf
#114 processos para pj
pj.drop_duplicates(subset="DSProcesso",inplace=True)
pf.drop_duplicates(subset="DSProcesso",inplace=True)
# Out:
# C:\Users\napcc\AppData\Local\Temp\ipykernel_15216\4065285415.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pj.drop_duplicates(subset="DSProcesso",inplace=True)
# C:\Users\napcc\AppData\Local\Temp\ipykernel_15216\4065285415.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf.drop_duplicates(subset="DSProcesso",inplace=True)

# %%
df = pd.concat([pj, pf])

# %% [markdown]
# ### Iniciando processo de retenção de processos por área

# %%
import seaborn as sns

# %%
df['QTAreaHA']=df['QTAreaHA'].str.replace(',', '.').astype(float) # PAssando os dados de área para numero em vez de string(letras)

# %%
#Vamos achar a mediana da área, min e max e média:
df['QTAreaHA'].median()#Mediana de 49.87
df['QTAreaHA'].min()#1.35
df['QTAreaHA'].max()#10000.0
df['QTAreaHA'].mean()#508.3446325878591
# Out:
# 508.3446325878591

# %%
#Vamos achar q1 q3 e q95 e q90 e q80
df['QTAreaHA'].quantile([0.25,0.75,0.95,0.90,0.80])
#q1 = 46.090
#q3 = 171.110
#q95 = 2144.788
#q90 =  557.978
#q80 = 330.860
# Out:
# 0.25      46.090
# 0.75     171.110
# 0.95    2144.788
# 0.90     557.978
# 0.80     330.860
# Name: QTAreaHA, dtype: float64

# %%
#Quanto de soma de área nos temos para os processos que são os 10%
proc_10 = df.query('QTAreaHA>557.978')['QTAreaHA'].drop_duplicates().sort_values(ascending=False).sum()
#Quanto de soma de área nos temos para os processos que são os 90%
proc_90 = df.query('QTAreaHA<=557.978')['QTAreaHA'].drop_duplicates().sort_values(ascending=False).sum()
f'A  área somada dos 10 dos maiores processos são {proc_10} e a dos 90 restantes são {proc_90}'
# Out:
# 'A  área somada dos 10 dos maiores processos são 65007.55 e a dos 90 restantes são 15382.26'

# %%
sns.kdeplot(data=df, x='QTAreaHA', cut=0, bw_adjust=3)#Plotzinho sobre a distruição dos dados de área
# Out:
# <AxesSubplot:xlabel='QTAreaHA', ylabel='Density'>

# %% [markdown]
# ### Como acordado na reunião de 28/02/2023, vou produzir dados para q80 (ou seja, os top 20%)

# %%
df.query('QTAreaHA>330.860').drop_duplicates('QTAreaHA').to_excel('Processos_garimpo_filtrados_VERSAO2.xlsx')

# %% [markdown]
# ### Criando uma planilha de acompanhamento / pesquisa

# %%
df_consulta = df[['DSProcesso','Pessoa','Pessoa_NOME','TipoRelacao']]
df_consulta.to_excel('Colsulta.xlsx')

# %% [markdown]
# ## Baseado na conversa de 02/03/2023, o escopo da análise mudou um pouco:
# * Utilizar base de dados incluindo os processos referentes ao período expandido;
# * Levantar os processos de PLG para os Estados que englobam a Amazônia Legal: Acre, Pará, Amazonas, Roraima, Rondônia, Amapá, Mato Grosso, Tocantins e Maranhão (siglas para busca:RR, AM, AP, PA, MA, TO, MT, RO, AC).
# * Primeiro momento: buscar todos os processos de PLG que incluam a publicação de PLG para os estados listados (ou seja, que supostamente autoriza publicamente a Lavra Garimpeira). Os marcadores de busca de eventos devem ser o 333 e o 513.
# * Segundo momento: buscar, para todos os estados listados, os processos de PLG que incluam a publicação de PLG e que constem apresentação de Licença Ambiental no sistema. Os marcadores de busca de eventos devem ser o 333, o 1402 e o 513.
# * Terceiro momento: comparar os números que retornam dessas buscas para verificar se há a publicação de PLGs em processos em que não foram apresentadas as licenças.
# * Ranquear os processos para cada estado de acordo com a área, para verificar quais padrões de distribuição de processos/área ocorrem na região como um todo e nos estados individualmente.
# * Ranquear por área para ver se há concentração geográfica das maiores áreas e se há destaque para algum estado.
# * Após determinação de quartis para análise, se forem observados padrões semelhantes, podemos verificar se o sigilo se repete também para outros estados.
# * Verificação do padrão de distribuição dos processos com maiores áreas em relação às cooperativas, comparando o ranqueamento com os múltiplos pedidos realizados pelos mesmos grupos.
# * Verificação do aumento/diminuição de pedidos ao longo do período por estado e para toda a região (linhas do tempo da quantidade dos processos).
# * Verificação do tempo (talvez olhar a média) de tramitação entre pedido e publicação para os processos (eventos 333 e 513).
# * Verificação do tempo de tramitação entre o pedido e a apresentação de licença (eventos 333 e 1402).
# * Verificação do tempo de tramitação entre a apresentação de licença e a publicação da PLG (eventos 1402 e 513).

# %%
#Importando Pacotes
import pandas as pd
import numpy as np
from collections import ChainMap
pd.set_option('display.max_columns', None)

# %%
#Lendo as planilhas:
processo_sub = pd.read_csv('ProcessoSubstancia.csv', sep=',')
processo = pd.read_csv('Processo.csv', sep=',')
evento = pd.read_csv('ProcessoEvento.csv', sep=',')
mun = pd.read_csv('ProcessoMunicipio.csv', sep=',')
pessoa = pd.read_csv('ProcessoPessoa.csv', sep=',')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4196\3613505092.py:6: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   pessoa = pd.read_csv('ProcessoPessoa.csv', sep=',')

# %% [markdown]
# ### Vamos iniciar a análise filtrando os processos que estão nos estados da amaz. legal. Para isso, vamos usar a base de municípios!

# %%
del mun['Unnamed: 0']
amaz_lgl = mun.query('UF=="AC" | UF=="AM" | UF=="RR" | UF=="RO" | UF=="MT" | UF=="PA" | UF=="AP" | UF=="MA" | UF=="TO"')
f'O Estados que compõem essa base amaz_lgl são:{amaz_lgl.UF.unique()}'
# Out:
# "O Estados que compõem essa base amaz_lgl são:['RR' 'MT' 'PA' 'RO' 'AM' 'AP' 'MA' 'TO' 'AC']"

# %%
amaz_lgl.head(5)#Vendo as 5 primeiras linhas
# Out:
#      DSProcesso  IDMunicipio         Municipios  UF
# 0  884.029/2020      1400175              CANTÁ  RR
# 1  884.029/2021      1400159             BONFIM  RR
# 2  884.029/2022      1400027            AMAJARI  RR
# 3  884.030/1996      1400902  SÃO LUIZ DO ANAUÁ  RR
# 4  884.030/1997      1400902  SÃO LUIZ DO ANAUÁ  RR

# %% [markdown]
# Agora sim vamos iniciar o merge com a base de dados de processos! E vamos filtrar por processos ativos!

# %%
del processo['Unnamed: 0']
processo_amazlgl = processo.merge(amaz_lgl,on='DSProcesso',how='inner')
processo_amazlgl_ativos = processo_amazlgl.query("BTAtivo=='S'")
processo_amazlgl_ativos.head()
# Out:
#       DSProcesso  NRProcesso  NRAnoProcesso BTAtivo                 NRNUP  \
# 11  850.308/1991      850308           1991       S  27205.850308/1991-15
# 14  850.308/1994      850308           1994       S  27205.850308/1994-68
# 21  850.308/2001      850308           2001       S  27205.850308/2001-48
# 23  850.308/2003      850308           2003       S  27205.850308/2003-18
# 26  850.308/2006      850308           2006       S  48405.850308/2006-76
#
#     IDTipoRequerimento  IDFaseProcesso  IDUnidadeAdministrativaRegional  \
# 11                 1.0               1                                5
# 14                 2.0               5                                5
# 21                 1.0               3                                5
# 23                 1.0               2                                5
# 26                 1.0               2                                5
#
#     IDUnidadeProtocolizadora          DTProtocolo         DTPrioridade  \
# 11                   27205.0  1991-05-07 00:00:00  1991-05-07 00:00:00
# 14                   27205.0  1994-01-14 00:00:00  1994-01-14 00:00:00
# 21                   27205.0  2001-08-03 00:00:00  2001-08-03 00:00:00
# 23                   27205.0  2003-07-14 00:00:00  2003-07-14 00:00:00
# 26                   48405.0  2006-05-18 16:56:00  2006-05-18 16:56:00
#
#    QTAreaHA                        Tipo_Requerimento  \
# 11   992,25  Requerimento de Autorização de Pesquisa
# 14    50,00         Requerimento de Lavra Garimpeira
# 21  3525,40  Requerimento de Autorização de Pesquisa
# 23  1542,64  Requerimento de Autorização de Pesquisa
# 26  9337,05  Requerimento de Autorização de Pesquisa
#
#                        Fase_Processo             Unidade_ADM  \
# 11          Requerimento de Pesquisa  Gerência Regional / PA
# 14  Requerimento de Lavra Garimpeira  Gerência Regional / PA
# 21             Requerimento de Lavra  Gerência Regional / PA
# 23           Autorização de Pesquisa  Gerência Regional / PA
# 26           Autorização de Pesquisa  Gerência Regional / PA
#
#     Unidade_Protocolizadora  IDMunicipio            Municipios  UF
# 11  Unid. Protocolizadora 5      1507508  SÃO JOÃO DO ARAGUAIA  PA
# 14  Unid. Protocolizadora 5      1503606              ITAITUBA  PA
# 21  Unid. Protocolizadora 5      1508126           ULIANÓPOLIS  PA
# 23  Unid. Protocolizadora 5      1505064     NOVO REPARTIMENTO  PA
# 26                     PARÁ      1505502           PARAGOMINAS  PA

# %% [markdown]
# Ficou acordado que vamos retroceder um pouco na análise no tempo. Vamos pegar processos de 2015 até 2022. Seguindo o comentário da Gaia, vamos também dar uma atenção maior aos processos que foram autorizados em 2023. Portanto, nós queremos apenas processos da data de 2015-2022 e também que passaram por autorização anterior a 2023!Ah, alem de ser para ouro, é claro

# %%
ouro = processo_sub.query('Substancia.str.contains("OURO")',engine='python')
processo_amazlgl_ativos_ouro = processo_amazlgl_ativos.merge(ouro,on='DSProcesso',how='inner')
processo_amazlgl_ativos_ouro = processo_amazlgl_ativos_ouro.query('NRAnoProcesso >= 2015 & NRAnoProcesso < 2023')#Retendo processos entre 2015 e 2022
#Vamos deletar colunas que não sao importantes para nossa análise:
colunas_keep =['DSProcesso' ,'NRProcesso','NRAnoProcesso','NRNUP','IDTipoRequerimento','IDFaseProcesso','QTAreaHA','Tipo_Requerimento','Fase_Processo','Municipios','UF','Substancia',
               'Tipo_Uso_Substancia']
processo_amazlgl_ativos_ouro = processo_amazlgl_ativos_ouro[colunas_keep]
processo_amazlgl_ativos_ouro.head()
# Out:
#         DSProcesso  NRProcesso  NRAnoProcesso                 NRNUP  \
# 4     850.308/2017      850308           2017  48405.850308/2017-29
# 5     850.308/2018      850308           2018  48405.850308/2018-18
# 6     850.308/2020      850308           2020  48059.850308/2020-10
# 7     850.308/2021      850308           2021  48059.850308/2021-92
# 2814  806.001/2015      806001           2015  48422.806001/2015-11
#
#       IDTipoRequerimento  IDFaseProcesso QTAreaHA  \
# 4                    2.0               5    49,66
# 5                    2.0               5    48,72
# 6                    2.0               5  8687,90
# 7                    1.0               1   352,58
# 2814                 1.0               2  2372,15
#
#                             Tipo_Requerimento  \
# 4            Requerimento de Lavra Garimpeira
# 5            Requerimento de Lavra Garimpeira
# 6            Requerimento de Lavra Garimpeira
# 7     Requerimento de Autorização de Pesquisa
# 2814  Requerimento de Autorização de Pesquisa
#
#                          Fase_Processo          Municipios  UF  \
# 4     Requerimento de Lavra Garimpeira            ITAITUBA  PA
# 5     Requerimento de Lavra Garimpeira            ITAITUBA  PA
# 6     Requerimento de Lavra Garimpeira        JACAREACANGA  PA
# 7             Requerimento de Pesquisa         BRASIL NOVO  PA
# 2814           Autorização de Pesquisa  CACHOEIRA DO PIRIÁ  PA
#
#            Substancia Tipo_Uso_Substancia
# 4     MINÉRIO DE OURO          Industrial
# 5     MINÉRIO DE OURO          Industrial
# 6     MINÉRIO DE OURO          Industrial
# 7                OURO          Industrial
# 2814  MINÉRIO DE OURO          Industrial

# %%
#Check das substânticas
sub = processo_amazlgl_ativos_ouro['Substancia'].unique()
f' Os tipos de substâncias nos processos filtrados são: {sub}'
# Out:
# " Os tipos de substâncias nos processos filtrados são: ['MINÉRIO DE OURO' 'OURO' 'OURO NATIVO']"

# %%
#Check de estados:

f' Os estados nos processos filtrados são: {processo_amazlgl_ativos_ouro.UF.unique()}'
# Out:
# " Os estados nos processos filtrados são: ['PA' 'MA' 'TO' 'AM' 'MT' 'AP' 'RO' 'RR' 'AC']"

# %% [markdown]
# Beleza, nós já temos nossa base de dados para os estados da amazonia legal, para os anos de 2015 ate 22 e para as substâncias de ouro

# %% [markdown]
# Primeiro momento: buscar todos os processos de PLG que incluam a publicação de PLG para os estados listados (ou seja, que supostamente autoriza publicamente a Lavra Garimpeira). Os marcadores de busca de eventos devem ser o 333 e o 513.

# %%
#Célula do codigo para filtrar os processos que são 333 e 513.
evento_333 = evento.query('IDEvento==333')
evento_513 = evento.query('IDEvento==513')
evento_333_513 = evento_333.merge(evento_513,on='DSProcesso',how='inner')
colunas_keep =['DSProcesso' ,'IDEvento_x','DTEvento_x','Evento__x','IDEvento_y','DTEvento_y','Evento__y']
evento_333_513 = evento_333_513[colunas_keep]
nome_colunas={'IDEvento_x':'IDEvento_333','DTEvento_x':'DTEvento_333','Evento__x':'Evento_333','IDEvento_y':'IDEvento_513','DTEvento_y':'DTEvento_513','Evento__y':'Evento_513'}
evento_333_513.rename(columns=nome_colunas,
          inplace=True)
evento_333_513
processo_amzlgl_ativos_ouro_333_513 = processo_amazlgl_ativos_ouro.merge(evento_333_513,on='DSProcesso',how='inner')
processo_amzlgl_ativos_ouro_333_513.head()
# Out:
#      DSProcesso  NRProcesso  NRAnoProcesso                 NRNUP  \
# 0  806.127/2015      806127           2015  48422.806127/2015-95
# 1  806.127/2015      806127           2015  48422.806127/2015-95
# 2  850.002/2020      850002           2020  48059.850002/2020-55
# 3  850.004/2017      850004           2017  48405.850004/2017-61
# 4  850.004/2017      850004           2017  48405.850004/2017-61
#
#    IDTipoRequerimento  IDFaseProcesso QTAreaHA  \
# 0                24.0               6   600,01
# 1                24.0               6   600,01
# 2                24.0               6    15,82
# 3                 2.0               6  1753,79
# 4                 2.0               6  1753,79
#
#                             Tipo_Requerimento     Fase_Processo  \
# 0  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 1  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 2  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 3            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 4            Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#             Municipios  UF       Substancia Tipo_Uso_Substancia  IDEvento_333  \
# 0       CÂNDIDO MENDES  MA  MINÉRIO DE OURO          Industrial           333
# 1              TURIAÇU  MA  MINÉRIO DE OURO          Industrial           333
# 2             ITAITUBA  PA  MINÉRIO DE OURO          Industrial           333
# 3  OURILÂNDIA DO NORTE  PA  MINÉRIO DE OURO          Industrial           333
# 4               TUCUMÃ  PA  MINÉRIO DE OURO          Industrial           333
#
#   DTEvento_333                                         Evento_333  \
# 0   2015-09-15  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 1   2015-09-15  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 2   2020-01-02  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 3   2017-01-03  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 4   2017-01-03  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
#
#    IDEvento_513 DTEvento_513                           Evento_513
# 0           513   2018-03-01  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1           513   2018-03-01  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2           513   2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 3           513   2021-07-14  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 4           513   2021-07-14  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL

# %%
#check Estados:

f' Os estados nos processos filtrados são: {processo_amzlgl_ativos_ouro_333_513.UF.unique()}'
# Out:
# " Os estados nos processos filtrados são: ['MA' 'PA' 'AP' 'TO' 'MT' 'RR' 'RO']"

# %%
#Temos processos repetidos
processo_amzlgl_ativos_ouro_333_513[processo_amzlgl_ativos_ouro_333_513['DSProcesso'].duplicated()]#86 processos repetidos
# Out:
#        DSProcesso  NRProcesso  NRAnoProcesso                 NRNUP  \
# 1    806.127/2015      806127           2015  48422.806127/2015-95
# 4    850.004/2017      850004           2017  48405.850004/2017-61
# 54   850.091/2016      850091           2016  48405.850091/2016-76
# 60   850.101/2015      850101           2015  48405.850101/2015-92
# 96   850.227/2017      850227           2017  48405.850227/2017-29
# ..            ...         ...            ...                   ...
# 873  867.092/2019      867092           2019  48068.867092/2019-71
# 875  867.101/2019      867101           2019  48068.867101/2019-23
# 879  867.141/2021      867141           2021  48068.867141/2021-90
# 881  867.174/2017      867174           2017  48412.867174/2017-96
# 887  867.240/2017      867240           2017  48412.867240/2017-28
#
#      IDTipoRequerimento  IDFaseProcesso QTAreaHA  \
# 1                  24.0               6   600,01
# 4                   2.0               6  1753,79
# 54                  2.0               6    50,00
# 60                  2.0               6  9917,91
# 96                  2.0               6     9,48
# ..                  ...             ...      ...
# 873                 2.0               6    31,15
# 875                 2.0               6    15,03
# 879                 2.0               6  9894,59
# 881                 2.0               6    41,39
# 887                24.0               6   141,59
#
#                               Tipo_Requerimento     Fase_Processo  \
# 1    Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 4              Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 54             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 60             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 96             Requerimento de Lavra Garimpeira  Lavra Garimpeira
# ..                                          ...               ...
# 873            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 875            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 879            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 881            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 887  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
#
#               Municipios  UF       Substancia Tipo_Uso_Substancia  \
# 1                TURIAÇU  MA  MINÉRIO DE OURO          Industrial
# 4                 TUCUMÃ  PA  MINÉRIO DE OURO          Industrial
# 54          JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 60             RURÓPOLIS  PA  MINÉRIO DE OURO          Industrial
# 96          JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# ..                   ...  ..              ...                 ...
# 873  TERRA NOVA DO NORTE  MT  MINÉRIO DE OURO          Industrial
# 875  TERRA NOVA DO NORTE  MT  MINÉRIO DE OURO          Industrial
# 879    NOVA SANTA HELENA  MT  MINÉRIO DE OURO          Industrial
# 881   PEIXOTO DE AZEVEDO  MT  MINÉRIO DE OURO          Industrial
# 887   PEIXOTO DE AZEVEDO  MT  MINÉRIO DE OURO          Industrial
#
#      IDEvento_333 DTEvento_333  \
# 1             333   2015-09-15
# 4             333   2017-01-03
# 54            333   2016-03-01
# 60            333   2015-02-11
# 96            333   2017-03-31
# ..            ...          ...
# 873           333   2019-11-22
# 875           333   2019-11-25
# 879           333   2021-08-17
# 881           333   2017-10-13
# 887           333   2017-11-17
#
#                                             Evento_333  IDEvento_513  \
# 1    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 4    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 54   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 60   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 96   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# ..                                                 ...           ...
# 873  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 875  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 879  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 881  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 887  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
#
#     DTEvento_513                           Evento_513
# 1     2018-03-01  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 4     2021-07-14  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 54    2017-06-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 60    2019-06-12  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 96    2017-09-20  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# ..           ...                                  ...
# 873   2021-09-24  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 875   2021-09-24  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 879   2022-05-19  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 881   2021-09-24  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 887   2018-10-31  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
#
# [86 rows x 19 columns]

# %% [markdown]
# Analisando no Arcgis, comparando a malha espacial dos projetos de mineração com malha municipal, percebi que os processo repetidos, eles são  pois o mesmo processo cruza 2 municipios. Portanto, não podemos reter um processo visto que ele contem infos relevantes. FOI ACORDADO, EM REUNIÃO, NO DIA 07/03/2023 QUE PARA FINS DA ANÁLISE JURIDICA DO PROJETO NÃO OLHAREMOS COMO PROCESSOS SEPARADOS ESSES QUE CRUZAM MAIS DE UM MUNICÍPIO. VAMOS CRIAR SIM UM DATAFRAME SEPARADO PARA TÍTULO DE ORGANIZAÇÃO MAS A ANALISE FINAL SERA COM TODOS!!!

# %%
repetidos = processo_amzlgl_ativos_ouro_333_513[processo_amzlgl_ativos_ouro_333_513["DSProcesso"].isin(processo_amzlgl_ativos_ouro_333_513[processo_amzlgl_ativos_ouro_333_513['DSProcesso'].duplicated()]['DSProcesso'])]
repetidos.to_csv('processos_multimunicipais.csv')

# %% [markdown]
# Essa linha abaixo é apenas um exemplo de processos que foram pedidos muito no passado e foram aprovados recentemente. Info interessante para projetos futuros

# %%
#Evidência de processos antigos que foram aprovados recentemente!
evento_333_513.query('DSProcesso=="650.677/1999" | DSProcesso=="650.004/2000" |DSProcesso=="650.005/2000" | DSProcesso=="650.692/1999" | DSProcesso=="50.682/1999" | DSProcesso=="50.683/1999"')
# Out:
#       DSProcesso  IDEvento_333 DTEvento_333  \
# 0   650.004/2000           333   2000-03-21
# 1   650.005/2000           333   2000-03-21
# 8   650.677/1999           333   1999-12-01
# 12  650.692/1999           333   1999-12-01
#
#                                            Evento_333  IDEvento_513  \
# 0   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 1   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 8   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 12  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
#
#    DTEvento_513                           Evento_513
# 0    2018-04-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1    2018-04-26  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 8    2022-08-11  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 12   2022-08-11  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL

# %% [markdown]
# Vamos agora, filtrar na nossa base principal os processos que não cruzam mais de um município. Para isso vamos reter os processos que não fazem parte da query: processo_amzlgl_ativos_ouro_333_513[processo_amzlgl_ativos_ouro_333_513["DSProcesso"].isin(processo_amzlgl_ativos_ouro_333_513[processo_amzlgl_ativos_ouro_333_513['DSProcesso'].duplicated()]['DSProcesso'])]
#
# * Ignorar esse passo pois foi acordado que usaremos tudo. Portanto todas essas linhas de código eu irei botar um comentario (#) para inutiliza-las

# %%
#processo_amzlgl_ativos_ouro_333_513_norep = processo_amzlgl_ativos_ouro_333_513[-processo_amzlgl_ativos_ouro_333_513['DSProcesso'].isin(processo_amzlgl_ativos_ouro_333_513[processo_amzlgl_ativos_ouro_333_513['DSProcesso'].duplicated()]['DSProcesso'])]
#processo_amzlgl_ativos_ouro_333_513_norep

# %% [markdown]
# ##### Criando a base de dados de processos de mineração únicos!

# %%
processo_amzlgl_ativos_ouro_333_513_unique = processo_amzlgl_ativos_ouro_333_513.drop_duplicates(subset='DSProcesso')
#Check quantidade de registros antes e depois de "dropar" os duplicados:
f'A quantidade de processos (linhas) na nossa base antes de tirar os duplicados eram de {processo_amzlgl_ativos_ouro_333_513.shape[0]} e depois de tirar foi para {processo_amzlgl_ativos_ouro_333_513_unique.shape[0]}'
# Out:
# 'A quantidade de processos (linhas) na nossa base antes de tirar os duplicados eram de 920 e depois de tirar foi para 834'

# %% [markdown]
# O primeiro passo já foi feito, que era de :
# * Primeiro momento: buscar todos os processos de PLG que incluam a publicação de PLG para os estados listados (ou seja, que supostamente autoriza publicamente a Lavra Garimpeira). Os marcadores de busca de eventos devem ser o 333 e o 513.
#
# Agora, vamos para o segundo passo:
# * Segundo momento: buscar, para todos os estados listados, os processos de PLG que incluam a publicação de PLG e que constem apresentação de Licença Ambiental no sistema. Os marcadores de busca de eventos devem ser o 333, o 1402 e o 513.

# %%
processo_amzlgl_ativos_ouro_333_513_unique # Essa é a base que tem o 333 para o 513
#Vamos filtrar agora os que, no meio dos trâmites, apresentaram licença ambiental:
#Pegando marcador 1402
evento_1402 = evento.query('IDEvento==1402')
processo_amzlgl_ativos_ouro_333_513_unique_1402= processo_amzlgl_ativos_ouro_333_513_unique.merge(evento_1402,on='DSProcesso',how='inner')
processo_amzlgl_ativos_ouro_333_513_unique_1402
colunas_keep =['DSProcesso' ,'NRAnoProcesso','IDTipoRequerimento','IDFaseProcesso','QTAreaHA','Tipo_Requerimento','Fase_Processo','Municipios',
              'UF','Substancia','Tipo_Uso_Substancia','IDEvento_333','DTEvento_333','Evento_333','IDEvento','DTEvento','Evento_','IDEvento_513','DTEvento_513','Evento_513']
processo_amzlgl_ativos_ouro_333_513_unique_1402 = processo_amzlgl_ativos_ouro_333_513_unique_1402[colunas_keep]
nome_colunas={'IDEvento':'IDEvento_1402','DTEvento':'DTEvento_1402','Evento_':'Evento_1402'}
processo_amzlgl_ativos_ouro_333_513_unique_1402.rename(columns=nome_colunas,
          inplace=True)
processo_amzlgl_ativos_ouro_333_513_unique_1402
# Out:
#         DSProcesso  NRAnoProcesso  IDTipoRequerimento  IDFaseProcesso  \
# 0     806.127/2015           2015                24.0               6
# 1     850.002/2020           2020                24.0               6
# 2     850.004/2017           2017                 2.0               6
# 3     850.004/2020           2020                 2.0               6
# 4     850.006/2017           2017                 2.0               6
# ...            ...            ...                 ...             ...
# 998   886.246/2018           2018                 2.0               6
# 999   850.949/2016           2016                 2.0               6
# 1000  866.953/2018           2018                 2.0               6
# 1001  850.992/2019           2019                 2.0               6
# 1002  850.992/2019           2019                 2.0               6
#
#      QTAreaHA                           Tipo_Requerimento     Fase_Processo  \
# 0      600,01  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 1       15,82  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 2     1753,79            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 3       49,62            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 4      117,98            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# ...       ...                                         ...               ...
# 998      9,60            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 999     47,25            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 1000     1,60            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 1001  3135,01            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 1002  3135,01            Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                Municipios  UF       Substancia Tipo_Uso_Substancia  \
# 0          CÂNDIDO MENDES  MA  MINÉRIO DE OURO          Industrial
# 1                ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 2     OURILÂNDIA DO NORTE  PA  MINÉRIO DE OURO          Industrial
# 3                ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 4                ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# ...                   ...  ..              ...                 ...
# 998           PORTO VELHO  RO  MINÉRIO DE OURO          Industrial
# 999              ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 1000               POCONÉ  MT  MINÉRIO DE OURO          Industrial
# 1001             ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 1002             ITAITUBA  PA  MINÉRIO DE OURO          Industrial
#
#       IDEvento_333 DTEvento_333  \
# 0              333   2015-09-15
# 1              333   2020-01-02
# 2              333   2017-01-03
# 3              333   2020-01-03
# 4              333   2017-01-04
# ...            ...          ...
# 998            333   2018-11-29
# 999            333   2016-11-07
# 1000           333   2018-11-30
# 1001           333   2019-12-17
# 1002           333   2019-12-17
#
#                                              Evento_333  IDEvento_1402  \
# 0     REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 1     REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 2     REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 3     REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 4     REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# ...                                                 ...            ...
# 998   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 999   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 1000  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 1001  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 1002  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
#
#      DTEvento_1402                              Evento_1402  IDEvento_513  \
# 0       2018-02-16  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 1       2020-03-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 2       2020-08-07  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 3       2020-04-22  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 4       2018-09-18  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# ...            ...                                      ...           ...
# 998     2019-05-21  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 999     2018-05-07  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 1000    2020-08-17  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 1001    2020-04-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 1002    2021-09-02  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
#
#      DTEvento_513                           Evento_513
# 0      2018-03-01  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2      2021-07-14  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 3      2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 4      2019-04-03  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# ...           ...                                  ...
# 998    2021-11-11  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 999    2018-08-17  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1000   2021-09-24  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1001   2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1002   2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
#
# [1003 rows x 20 columns]

# %%
#Analisando os processos repetidos depois desse merge!
processo_amzlgl_ativos_ouro_333_513_unique_1402[processo_amzlgl_ativos_ouro_333_513_unique_1402.DSProcesso.duplicated()]

#Ao pegar alguns exemplos de processos repetidos pude observar, analisando esses processos direto no site da ANM, que um mesmo processo "pediu" 2x ou mais o evento 1402 pois entre um pedido de 1402 e outro, ele teve outros eventos (que não estão vislumbrados em nossa análise)
# Out:
#         DSProcesso  NRAnoProcesso  IDTipoRequerimento  IDFaseProcesso  \
# 32    850.062/2021           2021                 2.0               6
# 34    850.063/2021           2021                 2.0               6
# 78    850.183/2018           2018                 2.0               6
# 79    850.183/2018           2018                 2.0               6
# 87    850.206/2019           2019                 2.0               6
# ...            ...            ...                 ...             ...
# 971   867.300/2020           2020                24.0               6
# 974   867.301/2020           2020                24.0               6
# 986   867.372/2021           2021                 2.0               6
# 996   884.033/2020           2020                 2.0               6
# 1002  850.992/2019           2019                 2.0               6
#
#      QTAreaHA                           Tipo_Requerimento     Fase_Processo  \
# 32      50,00            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 34      50,00            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 78      49,30            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 79      49,30            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 87      50,00            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# ...       ...                                         ...               ...
# 971     19,56  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 974     17,92  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 986     29,34            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 996     48,69            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 1002  3135,01            Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                        Municipios  UF       Substancia Tipo_Uso_Substancia  \
# 32                       ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 34                       ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 78                       ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 79                       ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 87                       ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# ...                           ...  ..              ...                 ...
# 971   NOSSA SENHORA DO LIVRAMENTO  MT  MINÉRIO DE OURO          Industrial
# 974   NOSSA SENHORA DO LIVRAMENTO  MT  MINÉRIO DE OURO          Industrial
# 986                    NOVO MUNDO  MT  MINÉRIO DE OURO          Industrial
# 996                     CARACARAÍ  RR  MINÉRIO DE OURO          Industrial
# 1002                     ITAITUBA  PA  MINÉRIO DE OURO          Industrial
#
#       IDEvento_333 DTEvento_333  \
# 32             333   2021-01-19
# 34             333   2021-01-19
# 78             333   2018-03-06
# 79             333   2018-03-06
# 87             333   2019-04-11
# ...            ...          ...
# 971            333   2020-12-04
# 974            333   2020-12-04
# 986            333   2021-10-04
# 996            333   2020-05-11
# 1002           333   2019-12-17
#
#                                              Evento_333  IDEvento_1402  \
# 32    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 34    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 78    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 79    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 87    REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# ...                                                 ...            ...
# 971   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 974   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 986   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 996   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
# 1002  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           1402
#
#      DTEvento_1402                              Evento_1402  IDEvento_513  \
# 32      2022-08-09  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 34      2022-08-09  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 78      2021-03-16  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 79      2021-04-09  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 87      2019-12-17  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# ...            ...                                      ...           ...
# 971     2021-11-29  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 974     2021-11-29  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 986     2022-04-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 996     2022-07-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
# 1002    2021-09-02  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA           513
#
#      DTEvento_513                           Evento_513
# 32     2022-10-17  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 34     2022-10-17  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 78     2021-09-08  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 79     2021-09-08  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 87     2020-02-12  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# ...           ...                                  ...
# 971    2022-05-05  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 974    2022-05-05  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 986    2022-08-22  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 996    2022-08-19  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1002   2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
#
# [181 rows x 20 columns]

# %% [markdown]
# Baseado na célula acima, vamos reter apenas os processos unicos em que o evento 1402 é o mais recente:

# %%
df_final = processo_amzlgl_ativos_ouro_333_513_unique_1402.drop_duplicates(subset='DSProcesso')
df_final
f'Antes de reter os processos únicos nós tinhamos {processo_amzlgl_ativos_ouro_333_513_unique_1402.shape[0]} processos e depois passamos a ter {df_final.shape[0]}'
# Out:
# 'Antes de reter os processos únicos nós tinhamos 1003 processos e depois passamos a ter 822'

# %% [markdown]
# Como nós filtramos processos que chegaram até o evento 513, iniciando pelo 333 e que passa OU NÃO pelo 1402, a base final pode haver conflito de dados. Esse conflito se da muito parecido como uma operação de conjuntos(figura abaixo). Para a base final, os processos que tem o marcador 513 CONTEM os processos que tem o marcador 1402 e 513. Em outras palavras, os processos 1402 estão contidos no 513. Dessa maneira, vou filtrar da base final (df_final) os processos que não CONTEM o 1402, que seria toda a área do conjunto hachurada(figura 2). PS:IGNORAR MEUS DOTES ARTÍSTICOS
#
# ![title](C:/Users/User/Downloads/asd.png)
#
# ![title](C:/Users/User/Downloads/asd222.png)

# %%
processos_sem1402 = processo_amzlgl_ativos_ouro_333_513_unique[-processo_amzlgl_ativos_ouro_333_513_unique["DSProcesso"].isin(df_final.DSProcesso)]
processos_sem1402#12 PROCESSOS
# Out:
#        DSProcesso  NRProcesso  NRAnoProcesso                 NRNUP  \
# 420  850.956/2020      850956           2020  48059.850956/2020-68
# 423  850.959/2020      850959           2020  48059.850959/2020-00
# 426  850.961/2020      850961           2020  48059.850961/2020-71
# 427  850.963/2020      850963           2020  48059.850963/2020-60
# 428  850.964/2020      850964           2020  48059.850964/2020-12
# 501  851.346/2017      851346           2017  48405.851346/2017-07
# 506  851.393/2021      851393           2021  48059.851393/2021-14
# 528  864.259/2015      864259           2015  48417.864259/2015-19
# 588  866.106/2015      866106           2015  48412.866106/2015-48
# 710  866.466/2015      866466           2015  48412.866466/2015-40
# 814  866.778/2018      866778           2018  48412.866778/2018-04
# 913  867.551/2021      867551           2021  48068.867551/2021-31
#
#      IDTipoRequerimento  IDFaseProcesso QTAreaHA  \
# 420                24.0               6    47,54
# 423                24.0               6    48,79
# 426                24.0               6    49,19
# 427                24.0               6    49,46
# 428                24.0               6    49,15
# 501                 2.0               6    96,77
# 506                 2.0               6    17,02
# 528                 2.0               6    28,92
# 588                25.0               6   252,85
# 710                 2.0               6   135,73
# 814                24.0               6    49,80
# 913                 2.0               6    29,27
#
#                                      Tipo_Requerimento     Fase_Processo  \
# 420         Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 423         Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 426         Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 427         Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 428         Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 501                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 506                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 528                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 588  Requerimento de Disponibilidade para Lavra Gar...  Lavra Garimpeira
# 710                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 814         Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 913                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#                       Municipios  UF       Substancia Tipo_Uso_Substancia  \
# 420                 JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 423                 JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 426                 JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 427                 JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 428                 JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 501               NOVO PROGRESSO  PA  MINÉRIO DE OURO          Industrial
# 506                     ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 528       BOM JESUS DO TOCANTINS  TO  MINÉRIO DE OURO          Industrial
# 588           PEIXOTO DE AZEVEDO  MT  MINÉRIO DE OURO          Industrial
# 710                       MATUPÁ  MT  MINÉRIO DE OURO          Industrial
# 814  NOSSA SENHORA DO LIVRAMENTO  MT             OURO          Industrial
# 913          TERRA NOVA DO NORTE  MT  MINÉRIO DE OURO          Industrial
#
#      IDEvento_333 DTEvento_333  \
# 420           333   2020-08-10
# 423           333   2020-08-10
# 426           333   2020-08-10
# 427           333   2020-08-10
# 428           333   2020-08-10
# 501           333   2017-12-11
# 506           333   2021-08-24
# 528           333   2015-10-06
# 588           333   2015-02-26
# 710           333   2015-09-16
# 814           333   2018-09-13
# 913           333   2021-11-25
#
#                                             Evento_333  IDEvento_513  \
# 420  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 423  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 426  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 427  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 428  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 501  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 506  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 528  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 588  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 710  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 814  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 913  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
#
#     DTEvento_513                           Evento_513
# 420   2022-02-21  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 423   2022-02-21  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 426   2022-10-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 427   2022-10-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 428   2022-10-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 501   2019-07-17  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 506   2022-05-11  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 528   2017-11-30  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 588   2021-10-05  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 710   2021-11-17  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 814   2019-08-14  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 913   2022-09-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL

# %% [markdown]
# # Beleza, nós temos os processos que foram de 333 para 1402 até 513 (df_final) e os processos que foram de 333 para 513 sem passar pelo 1402 (processos_sem1402).

# %% [markdown]
# As linhas abaixo estão comentadas pois se trata dos processos que ocorrem em mais de um município. Não vamos tratar disso agora!

# %%
#Como são muitos processos para os repetidos, eu vou criar uma planilha de consulta para ver quais os municipios esses processos ficam:
#consulta_multimunicipais = repetidos['DSProcesso']
#consulta_multimunicipais.to_csv('consulta_multimunicipais.csv')

# %% [markdown]
# Vamos agora analizar os processo repetidos que tem 1402 e que nao tem 1402!

# %%
#multimun_unique = repetidos.drop_duplicates('DSProcesso')
#evento_1402 = evento.query('IDEvento==1402')

#multimun_unique_1402= multimun_unique.merge(evento_1402,on='DSProcesso',how='inner')

#colunas_keep =['DSProcesso' ,'NRAnoProcesso','IDTipoRequerimento','IDFaseProcesso','QTAreaHA','Tipo_Requerimento','Fase_Processo','Municipios',
              #'UF','Substancia','Tipo_Uso_Substancia','IDEvento_333','DTEvento_333','Evento_333','IDEvento','DTEvento','Evento_','IDEvento_513','DTEvento_513','Evento_513']
#multimun_unique_1402 = multimun_unique_1402[colunas_keep]
#nome_colunas={'IDEvento':'IDEvento_1402','DTEvento':'DTEvento_1402','Evento_':'Evento_1402'}
#multimun_unique_1402.rename(columns=nome_colunas,
          #inplace=True)
#multimun_unique_1402[multimun_unique_1402['DSProcesso'].duplicated()]
#Ao pegar alguns exemplos de processos repetidos pude observar, analisando esses processos direto no site da ANM, que um mesmo processo "pediu" 2x o evento 1402 pois entre um pedido de 1402 e outro, ele teve outros eventos (que não estão vislumbrados em nossa análise)

# %% [markdown]
# Partindo da metodologia aplicada nas células anteriores, vou reter os eventos 1402 mais recentes!

# %%
#df_final_multimunicipal = multimun_unique_1402.drop_duplicates(subset='DSProcesso')
#df_final_multimunicipal
#75 processos

# %%
#multimunicipal_sem1402 = multimun_unique[-multimun_unique["DSProcesso"].isin(df_final_multimunicipal.DSProcesso)]
#multimunicipal_sem1402#2 processos

# %% [markdown]
# # Terminamos nossa criação de dataframes: Ao todo nós  temos:
# * df_final -> Processos unicos que tem os eventos 333, 1402 e 513
# * processos_sem1402 -> Processos unicos que tem os eventos 333 e 513

# %% [markdown]
# Agora vamos unir esses processos as pessoas e dropar os duplicados!

# %%
df_final_pessoa = df_final.merge(pessoa,on='DSProcesso',how='inner')

processos_sem1402_pessoa = processos_sem1402.merge(pessoa,on='DSProcesso',how='inner')
# Out:
#         DSProcesso  NRAnoProcesso  IDTipoRequerimento  IDFaseProcesso  \
# 0     806.127/2015           2015                24.0               6
# 1     806.127/2015           2015                24.0               6
# 2     850.002/2020           2020                24.0               6
# 3     850.002/2020           2020                24.0               6
# 4     850.002/2020           2020                24.0               6
# ...            ...            ...                 ...             ...
# 2566  866.953/2018           2018                 2.0               6
# 2567  866.953/2018           2018                 2.0               6
# 2568  850.992/2019           2019                 2.0               6
# 2569  850.992/2019           2019                 2.0               6
# 2570  850.992/2019           2019                 2.0               6
#
#      QTAreaHA                           Tipo_Requerimento     Fase_Processo  \
# 0      600,01  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 1      600,01  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 2       15,82  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 3       15,82  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 4       15,82  Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# ...       ...                                         ...               ...
# 2566     1,60            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2567     1,60            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2568  3135,01            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2569  3135,01            Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 2570  3135,01            Requerimento de Lavra Garimpeira  Lavra Garimpeira
#
#           Municipios  UF       Substancia Tipo_Uso_Substancia  IDEvento_333  \
# 0     CÂNDIDO MENDES  MA  MINÉRIO DE OURO          Industrial           333
# 1     CÂNDIDO MENDES  MA  MINÉRIO DE OURO          Industrial           333
# 2           ITAITUBA  PA  MINÉRIO DE OURO          Industrial           333
# 3           ITAITUBA  PA  MINÉRIO DE OURO          Industrial           333
# 4           ITAITUBA  PA  MINÉRIO DE OURO          Industrial           333
# ...              ...  ..              ...                 ...           ...
# 2566          POCONÉ  MT  MINÉRIO DE OURO          Industrial           333
# 2567          POCONÉ  MT  MINÉRIO DE OURO          Industrial           333
# 2568        ITAITUBA  PA  MINÉRIO DE OURO          Industrial           333
# 2569        ITAITUBA  PA  MINÉRIO DE OURO          Industrial           333
# 2570        ITAITUBA  PA  MINÉRIO DE OURO          Industrial           333
#
#      DTEvento_333                                         Evento_333  \
# 0      2015-09-15  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 1      2015-09-15  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 2      2020-01-02  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 3      2020-01-02  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 4      2020-01-02  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# ...           ...                                                ...
# 2566   2018-11-30  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 2567   2018-11-30  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 2568   2019-12-17  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 2569   2019-12-17  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
# 2570   2019-12-17  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...
#
#       IDEvento_1402 DTEvento_1402                              Evento_1402  \
# 0              1402    2018-02-16  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# 1              1402    2018-02-16  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# 2              1402    2020-03-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# 3              1402    2020-03-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# 4              1402    2020-03-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# ...             ...           ...                                      ...
# 2566           1402    2020-08-17  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# 2567           1402    2020-08-17  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# 2568           1402    2020-04-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# 2569           1402    2020-04-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
# 2570           1402    2020-04-27  REQ PLG/LICENÇA AMBIENTAL PROTOCOLIZADA
#
#       IDEvento_513 DTEvento_513                           Evento_513  \
# 0              513   2018-03-01  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 1              513   2018-03-01  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2              513   2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 3              513   2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 4              513   2020-05-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# ...            ...          ...                                  ...
# 2566           513   2021-09-24  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2567           513   2021-09-24  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2568           513   2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2569           513   2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
# 2570           513   2021-11-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL
#
#       Unnamed: 0  IDPessoa  IDTipoRelacao  IDTipoResponsabilidadeTecnica  \
# 0         206081    188251              9                            NaN
# 1         206082   8988649              1                            NaN
# 2        1062213     77928              9                            0.0
# 3        1062214     84065              1                            0.0
# 4        1062215     84065              4                            0.0
# ...          ...       ...            ...                            ...
# 2566     1555280   2200228              4                            NaN
# 2567     1555281   8974963              1                            NaN
# 2568     1157057     72926              4                            0.0
# 2569     1157058     72926              9                            0.0
# 2570     1157059   8971555              1                            0.0
#
#       IDTipoRepresentacaoLegal DTPrazoArrendamento DTInicioVigencia  \
# 0                          NaN                 NaN       2015-09-15
# 1                          NaN                 NaN       2015-09-15
# 2                          NaN                 NaN       2020-01-02
# 3                          NaN                 NaN       2020-01-02
# 4                          NaN                 NaN       2020-01-02
# ...                        ...                 ...              ...
# 2566                       NaN                 NaN       2018-11-30
# 2567                       NaN                 NaN       2018-11-30
# 2568                       NaN                 NaN       2019-12-17
# 2569                       NaN                 NaN       2019-12-17
# 2570                       NaN                 NaN       2019-12-17
#
#      DTFimVigencia Pessoa                                        Pessoa_NOME  \
# 0              NaN      F                                   Hercules Guionis
# 1              NaN      J  Cooperativa de Mineração Minas do Brasil - Min...
# 2              NaN      F                               Ewerton Reis Pereira
# 3              NaN      F                    Paulo Henrique Martins Carneiro
# 4              NaN      F                    Paulo Henrique Martins Carneiro
# ...            ...    ...                                                ...
# 2566           NaN      J            Geologia Mineração e Assessoria Ltda Me
# 2567           NaN      J             Frederico Augusto de Arruda Gimenez Me
# 2568           NaN      F                        Claudio Jorge Chaker Sadala
# 2569           NaN      F                        Claudio Jorge Chaker Sadala
# 2570           NaN      J  COOPERATIVA DOS GARIMPEIROS MINERADORES E PROD...
#
#               TipoRelacao Responsa_tecnica Representacao_Legal
# 0     Responsável Técnico              NaN                 NaN
# 1      Titular\Requerente              NaN                 NaN
# 2     Responsável Técnico              NaN                 NaN
# 3      Titular\Requerente              NaN                 NaN
# 4     Representante Legal              NaN                 NaN
# ...                   ...              ...                 ...
# 2566  Representante Legal              NaN                 NaN
# 2567   Titular\Requerente              NaN                 NaN
# 2568  Representante Legal              NaN                 NaN
# 2569  Responsável Técnico              NaN                 NaN
# 2570   Titular\Requerente              NaN                 NaN
#
# [2571 rows x 33 columns]

# %% [markdown]
# Separando em PJ e PF

# %%
df_final_pessoa_pj = df_final_pessoa.query('Pessoa =="J"')
df_final_pessoa_pf = df_final_pessoa.query('Pessoa =="F"')


processos_sem1402_pessoa_pj = processos_sem1402_pessoa.query('Pessoa =="J"')
processos_sem1402_pessoa_pf = processos_sem1402_pessoa.query('Pessoa =="F"')

# %%
#Retendo processos unicos e uni-los novamente:
df_final_pessoa_pj_unique = df_final_pessoa_pj.drop_duplicates(subset='DSProcesso')
df_final_pessoa_pj_unique

df_final_pessoa_pf_unique = df_final_pessoa_pf.drop_duplicates(subset='DSProcesso')
df_final_pessoa_pf_unique

df_final_concat =  pd.concat([df_final_pessoa_pj_unique, df_final_pessoa_pf_unique])
df_final_concat.drop_duplicates(subset='DSProcesso',inplace=True)
df_final_concat


processos_sem1402_final_concat =  pd.concat([processos_sem1402_pessoa_pj, processos_sem1402_pessoa_pf])
processos_sem1402_final_concat.drop_duplicates(subset='DSProcesso',inplace=True)
processos_sem1402_final_concat
# Out:
#       DSProcesso  NRProcesso  NRAnoProcesso                 NRNUP  \
# 16  851.346/2017      851346           2017  48405.851346/2017-07
# 20  851.393/2021      851393           2021  48059.851393/2021-14
# 22  864.259/2015      864259           2015  48417.864259/2015-19
# 24  866.106/2015      866106           2015  48412.866106/2015-48
# 27  866.466/2015      866466           2015  48412.866466/2015-40
# 33  867.551/2021      867551           2021  48068.867551/2021-31
# 0   850.956/2020      850956           2020  48059.850956/2020-68
# 3   850.959/2020      850959           2020  48059.850959/2020-00
# 6   850.961/2020      850961           2020  48059.850961/2020-71
# 9   850.963/2020      850963           2020  48059.850963/2020-60
# 12  850.964/2020      850964           2020  48059.850964/2020-12
# 30  866.778/2018      866778           2018  48412.866778/2018-04
#
#     IDTipoRequerimento  IDFaseProcesso QTAreaHA  \
# 16                 2.0               6    96,77
# 20                 2.0               6    17,02
# 22                 2.0               6    28,92
# 24                25.0               6   252,85
# 27                 2.0               6   135,73
# 33                 2.0               6    29,27
# 0                 24.0               6    47,54
# 3                 24.0               6    48,79
# 6                 24.0               6    49,19
# 9                 24.0               6    49,46
# 12                24.0               6    49,15
# 30                24.0               6    49,80
#
#                                     Tipo_Requerimento     Fase_Processo  \
# 16                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 20                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 22                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 24  Requerimento de Disponibilidade para Lavra Gar...  Lavra Garimpeira
# 27                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 33                   Requerimento de Lavra Garimpeira  Lavra Garimpeira
# 0          Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 3          Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 6          Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 9          Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 12         Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
# 30         Requerimento de Mudança de Regime para PLG  Lavra Garimpeira
#
#                      Municipios  UF       Substancia Tipo_Uso_Substancia  \
# 16               NOVO PROGRESSO  PA  MINÉRIO DE OURO          Industrial
# 20                     ITAITUBA  PA  MINÉRIO DE OURO          Industrial
# 22       BOM JESUS DO TOCANTINS  TO  MINÉRIO DE OURO          Industrial
# 24           PEIXOTO DE AZEVEDO  MT  MINÉRIO DE OURO          Industrial
# 27                       MATUPÁ  MT  MINÉRIO DE OURO          Industrial
# 33          TERRA NOVA DO NORTE  MT  MINÉRIO DE OURO          Industrial
# 0                  JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 3                  JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 6                  JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 9                  JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 12                 JACAREACANGA  PA  MINÉRIO DE OURO          Industrial
# 30  NOSSA SENHORA DO LIVRAMENTO  MT             OURO          Industrial
#
#     IDEvento_333 DTEvento_333  \
# 16           333   2017-12-11
# 20           333   2021-08-24
# 22           333   2015-10-06
# 24           333   2015-02-26
# 27           333   2015-09-16
# 33           333   2021-11-25
# 0            333   2020-08-10
# 3            333   2020-08-10
# 6            333   2020-08-10
# 9            333   2020-08-10
# 12           333   2020-08-10
# 30           333   2018-09-13
#
#                                            Evento_333  IDEvento_513  \
# 16  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 20  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 22  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 24  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 27  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 33  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 0   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 3   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 6   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 9   REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 12  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
# 30  REQ PLG/REQUERIMENTO LAVRA GARIMPEIRA PROTOCOL...           513
#
#    DTEvento_513                           Evento_513  Unnamed: 0  IDPessoa  \
# 16   2019-07-17  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1175554   8951064
# 20   2022-05-11  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1177519   9023779
# 22   2017-11-30  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1459074   8972714
# 24   2021-10-05  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1485453   8921648
# 27   2021-11-17  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1520516   8921648
# 33   2022-09-29  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1575854   8921648
# 0    2022-02-21  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1154715    113825
# 3    2022-02-21  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1154939    113825
# 6    2022-10-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1155083    113825
# 9    2022-10-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1155231    113825
# 12   2022-10-25  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     2084587    113825
# 30   2019-08-14  PLG/PERMISSÃO LAVRA GARIMPEIRA PUBL     1546060     82402
#
#     IDTipoRelacao  IDTipoResponsabilidadeTecnica  IDTipoRepresentacaoLegal  \
# 16              1                            NaN                       NaN
# 20              1                            0.0                       NaN
# 22              1                            NaN                       NaN
# 24              1                            NaN                       NaN
# 27              1                            NaN                       NaN
# 33              1                            0.0                       NaN
# 0               9                            0.0                       NaN
# 3               9                            0.0                       NaN
# 6               9                            0.0                       NaN
# 9               9                            0.0                       NaN
# 12              9                            0.0                       NaN
# 30              1                            NaN                       NaN
#
#    DTPrazoArrendamento DTInicioVigencia DTFimVigencia Pessoa  \
# 16                 NaN       2017-12-11           NaN      J
# 20                 NaN       2021-08-24           NaN      J
# 22                 NaN       2015-10-06           NaN      J
# 24                 NaN       2015-02-26           NaN      J
# 27                 NaN       2015-09-16           NaN      J
# 33                 NaN       2021-11-25           NaN      J
# 0                  NaN       2020-08-10           NaN      F
# 3                  NaN       2020-08-10           NaN      F
# 6                  NaN       2020-08-10           NaN      F
# 9                  NaN       2020-08-10           NaN      F
# 12                 NaN       2020-08-10           NaN      F
# 30                 NaN       2018-09-13           NaN      F
#
#                                           Pessoa_NOME          TipoRelacao  \
# 16  Cooperminerios Cooper. Mista de Exp. Mineral e...   Titular\Requerente
# 20  COOPERATIVA DE GARIMPEIROS E MINERADORES SUSTENTA   Titular\Requerente
# 22                                  A V CORDEIRO - ME   Titular\Requerente
# 24  COOPERATIVA DOS GARIMPEIROS DO VALE DO RIO PEI...   Titular\Requerente
# 27  COOPERATIVA DOS GARIMPEIROS DO VALE DO RIO PEI...   Titular\Requerente
# 33  COOPERATIVA DOS GARIMPEIROS DO VALE DO RIO PEI...   Titular\Requerente
# 0                                 WAGNER LOPES GHELER  Responsável Técnico
# 3                                 WAGNER LOPES GHELER  Responsável Técnico
# 6                                 WAGNER LOPES GHELER  Responsável Técnico
# 9                                 WAGNER LOPES GHELER  Responsável Técnico
# 12                                WAGNER LOPES GHELER  Responsável Técnico
# 30                                  Marcio Nascimento   Titular\Requerente
#
#    Responsa_tecnica Representacao_Legal
# 16              NaN                 NaN
# 20              NaN                 NaN
# 22              NaN                 NaN
# 24              NaN                 NaN
# 27              NaN                 NaN
# 33              NaN                 NaN
# 0               NaN                 NaN
# 3               NaN                 NaN
# 6               NaN                 NaN
# 9               NaN                 NaN
# 12              NaN                 NaN
# 30              NaN                 NaN

# %%
#Salvando essa galera:
df_final_concat.to_csv('db_333_1402_513_uniMUNI.csv')
processos_sem1402_final_concat.to_csv('db_333_513_uniMUNI.csv')
#df_final_multimunicipal_pessoa.to_csv('db_333_1402_513_multiMUNI.csv')
#multimunicipal_sem1402_pessoa.to_csv('db_333_513_multiMUNI.csv')
#Salvando tbm um arquivo de consulta para consultar os outros requerentes de um mesmo processo
consulta_pessoa = pessoa[['DSProcesso','Pessoa_NOME','Pessoa']]
consulta_pessoa.to_csv('consulta_pessoa.csv')

# %% [markdown]
# # Show de bola, agora vamos começar o processo de exploração de dados!!!

# %% [markdown]
# Terceiro momento: comparar os números que retornam dessas buscas para verificar se há a publicação de PLGs em processos em que não foram apresentadas as licenças.

# %%
#Processos que apresentaram licença:
f'Os processos que apresentaram licença foram:{df_final_concat.shape[0]} e os que não apresentam licença foram: {processos_sem1402_final_concat.shape[0]}'
# Out:
# 'Os processos que apresentaram licença foram:822 e os que não apresentam licença foram: 12'

# %% [markdown]
# Quantos processos apresentaram licença para cada estado?
# E quantos não apresentaram?

# %%
#Apresentaram processo para cada estado:
df_final_concat.groupby(by=['UF']).agg(count_col=pd.NamedAgg(column='UF',aggfunc="count"))
# Out:
#     count_col
# UF
# AP          3
# MA          1
# MT        314
# PA        492
# RO          2
# RR          1
# TO          9

# %%
#Não Apresentaram processo para cada estado:
processos_sem1402_final_concat.groupby(by=['UF']).agg(count_col=pd.NamedAgg(column='UF',aggfunc="count"))
# Out:
#     count_col
# UF
# MT          4
# PA          7
# TO          1

# %% [markdown]
# * Ranquear os processos para cada estado de acordo com a área, para verificar quais padrões de distribuição de processos/área ocorrem na região como um todo e nos estados individualmente.
# * Ranquear por área para ver se há concentração geográfica das maiores áreas e se há destaque para algum estado.

# %%
#PAssando as colunas de area de string para number
df_final_concat['QTAreaHA']=df_final_concat['QTAreaHA'].str.replace(',', '.').astype(float)

processos_sem1402_final_concat['QTAreaHA']=processos_sem1402_final_concat['QTAreaHA'].str.replace(',', '.').astype(float)

# %%
df_final_concat.groupby(by=['UF']).agg(count_col=pd.NamedAgg(column='QTAreaHA',aggfunc="sum"))
# Out:
#     count_col
# UF
# AP     149.85
# MA     600.01
# MT  327325.14
# PA  145311.57
# RO      23.96
# RR      48.69
# TO     413.09

# %%
processos_sem1402_final_concat.groupby(by=['UF']).agg(count_col=pd.NamedAgg(column='QTAreaHA',aggfunc="sum"))
# Out:
#     count_col
# UF
# MT     467.65
# PA     357.92
# TO      28.92

# %% [markdown]
# Analisando quantils:

# %%
#Vamos achar a mediana da área, min e max e média:
median_df = df_final_concat['QTAreaHA'].median()
min_df = df_final_concat['QTAreaHA'].min()
max_df = df_final_concat['QTAreaHA'].max()
mean_df = df_final_concat['QTAreaHA'].mean()

df_sem1402_median = processos_sem1402_final_concat['QTAreaHA'].median()
df_sem1402_min = processos_sem1402_final_concat['QTAreaHA'].min()
df_sem1402_max = processos_sem1402_final_concat['QTAreaHA'].max()
df_sem1402_mean = processos_sem1402_final_concat['QTAreaHA'].mean()

# %%
f'A mediana da area dos processos que tem 1402  é:{median_df}, mínimo de {min_df},máximo de {max_df} e média de {mean_df}'
# Out:
# 'A mediana da area dos processos que tem 1402  é:49.69, mínimo de 0.7,máximo de 10000.0 e média de 576.4869951338193'

# %%
f'A mediana da area dos processos que NÃO tem 1402 é:{df_sem1402_median}, mínimo de {df_sem1402_min},máximo de {df_sem1402_max} e média de {df_sem1402_mean}'
# Out:
# 'A mediana da area dos processos que NÃO tem 1402 é:49.17, mínimo de 17.02,máximo de 252.85 e média de 71.2075'

# %%
#Vamos achar q1 q3 e q95 e q90 e q80
quantis_df_final = df_final_concat['QTAreaHA'].quantile([0.25,0.75,0.95,0.90,0.80])

quantis_sem1402_final = processos_sem1402_final_concat['QTAreaHA'].quantile([0.25,0.75,0.95,0.90,0.80])

# %%
f'Os quantils da area dos processos que tem 1402  são [0.25]{ df_final_concat["QTAreaHA"].quantile(0.25)}, [0.75]{df_final_concat["QTAreaHA"].quantile(0.75)}, [0.90]{df_final_concat["QTAreaHA"].quantile(0.90)},[0.95] {df_final_concat["QTAreaHA"].quantile(0.95)} e [0.80]{df_final_concat["QTAreaHA"].quantile(0.80)} '
# Out:
# 'Os quantils da area dos processos que tem 1402  são [0.25]43.5925, [0.75]50.0, [0.90]541.0179999999996,[0.95] 5027.773999999994 e [0.80]99.89800000000002 '

# %%
f'Os quantils da area dos processos que NÃO tem 1402  são [0.25]{ processos_sem1402_final_concat["QTAreaHA"].quantile(0.25)}, [0.75]{processos_sem1402_final_concat["QTAreaHA"].quantile(0.75)}, [0.90]{processos_sem1402_final_concat["QTAreaHA"].quantile(0.90)},[0.95] {processos_sem1402_final_concat["QTAreaHA"].quantile(0.95)} e [0.80]{processos_sem1402_final_concat["QTAreaHA"].quantile(0.80)} '
# Out:
# 'Os quantils da area dos processos que NÃO tem 1402  são [0.25]42.9725, [0.75]61.5425, [0.90]131.834,[0.95] 188.4339999999999 e [0.80]87.37600000000003 '

# %%
#Vendo quanto de área soma para os top 5% PARA TODOS OS ESTADOS DA AMAZ LEGAL e quantos processos são (SÃO OS QUE APRESENTAM LICENÇA - 1402):
df_final_concat.query('QTAreaHA>5027.773999999994')['QTAreaHA'].sum() #352,878.89 de soma de área
df_final_concat.query('QTAreaHA>5027.773999999994')['QTAreaHA'].count()#SÃO 42 PROCESSOS

#Vendo quanto de área soma para os restantes (95%) PARA TODOS OS ESTADOS DA AMAZ LEGAL e quantos processos são (SÃO OS QUE APRESENTAM LICENÇA - 1402):
df_final_concat.query('QTAreaHA<5027.773999999994')['QTAreaHA'].sum() #120,993.42 de soma de área
df_final_concat.query('QTAreaHA<5027.773999999994')['QTAreaHA'].count() # 780 processos

#Vendo quanto de área soma para os top 5% PARA TODOS OS ESTADOS DA AMAZ LEGAL e quantos processos são PARA OS QUE NÃO APRESENTAM LICENÇA:
processos_sem1402_final_concat.query('QTAreaHA>188.4339999999999')['QTAreaHA'].sum()#252.85 de área
processos_sem1402_final_concat.query('QTAreaHA>188.4339999999999')['QTAreaHA'].count() #um processo

#Vendo quanto de área somapara os restantes (95%) PARA TODOS OS ESTADOS DA AMAZ LEGAL e quantos processos são PARA OS QUE NÃO APRESENTAM LICENÇA:
processos_sem1402_final_concat.query('QTAreaHA<188.4339999999999')['QTAreaHA'].sum()#601.64 de área
processos_sem1402_final_concat.query('QTAreaHA<188.4339999999999')['QTAreaHA'].count() #11 processos
# Out:
# 11

# %% [markdown]
#  Em relação a esses 5%, como eles se distribuem por estado

# %%
df_final_concat.query('QTAreaHA>5027.773999999994').groupby(by=['UF']).agg(count_col=pd.NamedAgg(column='QTAreaHA',aggfunc="sum"))
# Out:
#     count_col
# UF
# MT  275729.12
# PA   77149.77

# %%
df_final_concat.query('QTAreaHA>5027.773999999994').groupby(by=['UF']).agg(count_col=pd.NamedAgg(column='DSProcesso',aggfunc="count"))
# Out:
#     count_col
# UF
# MT         34
# PA          8

# %% [markdown]
# ## FICOU ACORDADO DE PASSAR 3 DATAFRAMES PARA A GAIA:
# * UM CONTENDO AS INFOS APENAS DO PARÁ (ISSO JA TEM MAS VOU REFAZER SOMENTE PARA CONTROLE)
# * UM PARA AMAZONIA LEGAL(SÓ IRÁ RETORNAR PROCESSOS DE PARA E MT, COMO VIMOS)
# * UM APENAS PARA O MT

# %%
#Criando o dataframe para o Para de top 5%, 10% e 20%
#Primeiro vamos filtrar o que é Pará:
processos_para = df_final_concat.query('UF=="PA"')
#Calculando, agora, os quartis de 95,90 e 80:
quantis_para = processos_para['QTAreaHA'].quantile([0.95,0.90,0.80])
quantis_para
# Out:
# 0.95    562.669
# 0.90    358.076
# 0.80     50.000
# Name: QTAreaHA, dtype: float64

# %%
#Salvando esses databases para 95%:
processos_para.query("QTAreaHA>562.669").to_excel("DB_Para_95%.xlsx")
#Para 90%
processos_para.query("QTAreaHA>358.076").to_excel("DB_Para_90%.xlsx")
#Para 80%
processos_para.query("QTAreaHA>50.000").to_excel("DB_Para_80%.xlsx")

# %%
#Criando o dataframe para o MT de top 5%, 10% e 20%
#Primeiro vamos filtrar o que é Pará:
processos_mt = df_final_concat.query('UF=="MT"')
#Calculando, agora, os quartis de 95,90 e 80:
quantis_mt = processos_mt['QTAreaHA'].quantile([0.95,0.90,0.80])
quantis_mt
# Out:
# 0.95    8549.3905
# 0.90    5345.8340
# 0.80     309.4680
# Name: QTAreaHA, dtype: float64

# %%
#Salvando esses databases para 95%:
processos_mt.query("QTAreaHA>8549.3905").to_excel("DB_MT_95%.xlsx")
#Para 90%
processos_mt.query("QTAreaHA>5345.8340").to_excel("DB_MT_90%.xlsx")
#Para 80%
processos_mt.query("QTAreaHA>309.4680").to_excel("DB_MT_80%.xlsx")

# %%
#Salvando para a planilha toda!!
#95%
df_final_concat.query("QTAreaHA>5027.773999999994").to_excel("DB_AMAZLGL_95%.xlsx")
#90%
df_final_concat.query("QTAreaHA>541.0179999999996").to_excel("DB_AMAZLGL_90%.xlsx")
#80%
df_final_concat.query("QTAreaHA>99.89800000000002").to_excel("DB_AMAZLGL_80%.xlsx")
